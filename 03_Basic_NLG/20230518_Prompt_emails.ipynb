# %% [markdown]
# ----
# ### **Adding Prompt**

# %%
#pip install pandarallel
import multiprocessing

num_processors = multiprocessing.cpu_count()
print(f'Available CPUs: {num_processors}')

import pandarallel
from pandarallel import pandarallel
pandarallel.initialize(nb_workers=num_processors-1, use_memory_fs=False)
# Out:
# Available CPUs: 8
# INFO: Pandarallel will run on 7 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
import pandas as pd

# %%
df_messages=pd.read_csv('/Users/kshitijmittal/Documents/UChicago Acad/Hedwig_AI/Hedwig/00_Data/data_message_reply_pairs_cleaned.csv')
df_messages.head(3)
# Out:
#    Unnamed: 0                       time   subject  thread  sender recipient  \
# 0           0  1999-06-09 04:18:00-07:00  RE: test       2    5552   [40034]
# 1           1  1999-06-09 08:06:00-07:00  RE: test       2   40034    [5552]
# 2           2  1999-06-09 08:06:00-07:00  RE: test       2   40034    [5552]
#
#                                              message  \
# 0  How about this Friday ? Julie has not left yet...
# 1  when? how are you and your family? is julie go...
# 2  when? how are you and your family? is julie go...
#
#                   reply_time  reply_sender reply_recipient  \
# 0  1999-06-09 08:06:00-07:00         40034          [5552]
# 1  1999-06-10 03:54:00-07:00          5552         [40034]
# 2  1999-11-23 01:38:00-08:00          5552         [40034]
#
#                                        reply_message
# 0  when? how are you and your family? is julie go...
# 1           Today is bad. Tommorrow I will call you.
# ...

# %%
df_messages['time']=pd.to_datetime(df_messages['time'], utc=True)
# df_messages=df_messages.sort_values(by='time')

# %%
df_messages.sample(5)
# Out:
#        Unnamed: 0                      time                   subject  thread  \
# 22948       25444 2001-03-01 16:20:00+00:00  Re: Need Contact Info...  123759
# 18492       20753 2002-04-30 14:33:55+00:00      Re: man night again?   94898
# 1843         1862 2001-11-26 14:43:02+00:00                       RE:     208
# 6311         7128 2001-04-13 14:46:00+00:00              RE: Netscape   20436
# 12874       14303 2000-06-21 17:08:00+00:00                Wednesdsay   58344
#
#        sender                                          recipient  \
# 22948   13209                                             [1497]
# 18492   36220  [36205, 36165, 36167, 36184, 36169, 36224, 173...
# 1843    32599                                             [1660]
# 6311    10099                                     [10067, 10095]
# 12874   22270                                             [1721]
#
#                                                  message  \
# ...
