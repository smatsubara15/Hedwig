# %% [markdown]
# # Chroma DB

# %% [markdown]
# %pip install chromadb

# %%
import pandas as pd
import numpy as np
import chromadb

# %%
import os
import getpass

# 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
# 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

os.environ['OPENAI_API_KEY'] = getpass.getpass('OpenAI API Key:')
# Out:
# OpenAI API Key: ········

# %%
# Loading the emails data 

df_messages=pd.read_csv('gs://user-scripts-msca310019-capstone-49b3/data/20231006_Emails_with_identical_users.csv', parse_dates=['time'])
df_messages.head()
df_messages.recipient.value_counts()
# Out:
# recipient
# [151]                  837
# [414]                  592
# [1721]                 587
# [1706]                 420
# [1691]                 419
#                       ...
# [1158, 51, 5409]         1
# [51, 5409]               1
# [17028]                  1
# [5411, 5431, 17026]      1
# [13306, 9868, 322]       1
# Name: count, Length: 6745, dtype: int64

# %%
# Importing relevant langchain libraries
# %pip install langchain

import langchain
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma

# %%
df_messages.head()
# Out:
#    Unnamed: 0  Email_ID                       time   subject  thread  sender  \
# 0           0         0  1999-06-09 04:18:00-07:00  RE: test       2    5552
# 1           1         1  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 2           2         2  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 3           3         3  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 4           4         4  1999-06-09 08:06:00-07:00  RE: test       2   40034
#
#   recipient                                            message  \
# 0   [40034]  How about this Friday ? Julie has not left yet...
# 1    [5552]  when? how are you and your family? is julie go...
# 2    [5552]  when? how are you and your family? is julie go...
# 3    [5552]  when? how are you and your family? is julie go...
# 4    [5552]  when? how are you and your family? is julie go...
#
#                   reply_time  reply_sender reply_recipient  \
# 0  1999-06-09 08:06:00-07:00         40034          [5552]
# 1  1999-06-10 03:54:00-07:00          5552         [40034]
# 2  1999-11-23 01:38:00-08:00          5552         [40034]
# 3  1999-11-23 03:13:00-08:00          5552         [40034]
# 4  1999-11-23 03:58:00-08:00          5552         [40034]
#
#                                        reply_message  \
# 0  when? how are you and your family? is julie go...
# 1           Today is bad. Tommorrow I will call you.
# 2                     Do you have lunch plans today?
# 3  Really? I'd feel like a mooch. Lets have lunch...
# 4                       Tues.is good. I'll call you.
#
#                                      Relevent_Emails
# 0                                                NaN
# 1  when? how are you and your family? is julie go...
# 2  when? how are you and your family? is julie go...
# 3  when? how are you and your family? is julie go...
# 4  when? how are you and your family? is julie go...

# %%
# Filtering on the user ID of our user whose persona is being mimicked

df_filtered= list(df_messages[df_messages.reply_sender == 1721].reply_message)
df_filtered[:10]
# Out:
# ['Yes, everything. ',
#  ' Sharon, did one of the Canadian lawyers look at the list for the things you could not identify? ',
#  'You (as usual) are the best! ',
#  "Edmund Cooper is the only person that has keyword access to add legal people, credit people, companies, or change other drop downs in the database. I have key word access on this side of the Atlantic and Edmund has it there. If you need London Credit people added that aren't listed already you need to have Edmund go add them, or the company as a new key word. ",
#  'Yes. "Louis Fernandez Company" <lofeco@ev1.net 04/10/2001 08:53 AM   ',
#  "It was a pleasure having you as a houseguest! Anytime  The current issue of Texas Monthly is only the beginning right after we announced our current earnings last week, The Wall Street Journal originated a story about a partnership our CFO invested in that made questionable statements about conflicts of interests with the shareholders, non disclosure of profits, etc., and have kept up with this story since last week, we have had shareholder lawsuits, SEC inquiries, our stock has taken a dive down to $15 today, down from $33 when the story first ran, and $87 since the beginning of the year. Right now it is beat up Enron time with no end in sight. Anyway, you may to check the WSJ website and catch up  Also, I have a new boyfriend, my old biking buddy I mentioned we've been dating now for a few months, that seems to be going well. So that's all my news  XXOO ",
#  'This will get you access to Livelink ',
#  'I think yes. ',
#  '1. If we have a US counterparty we insert the appropriate choice. =20 2. Revisions to the CFTC Rules have done away with the "Eligible Swap=20 Participant" rules for energy commodities (they would still apply to=20 agricultural products). The rules are still pretty similar however, and th= e=20 current lingo is now "Eligible Contract Participants". See our revised for= m,=20 attached. =09Karen A Cordova@EES =0904/04/2001 04:33 PM =09=09=20 =09=09 ',
#  'Anytime! =09Karen A Cordova@EES =0904/09/2001 09:25 AM =09=09 =09=09 ']

# %%
# Convert emails to document list

df_filtered_documents = langchain.document_loaders.telegram.text_to_docs(df_filtered)
#db = Chroma.from_documents(df_filtered_documents, OpenAIEmbeddings())

# %%
df_filtered_documents
# Out:
# [Document(page_content='Yes, everything.', metadata={'page': 1, 'chunk': 0, 'source': '1-0'}),
#  Document(page_content='Sharon, did one of the Canadian lawyers look at the list for the things you could not identify?', metadata={'page': 2, 'chunk': 0, 'source': '2-0'}),
#  Document(page_content='You (as usual) are the best!', metadata={'page': 3, 'chunk': 0, 'source': '3-0'}),
#  Document(page_content="Edmund Cooper is the only person that has keyword access to add legal people, credit people, companies, or change other drop downs in the database. I have key word access on this side of the Atlantic and Edmund has it there. If you need London Credit people added that aren't listed already you need to have Edmund go add them, or the company as a new key word.", metadata={'page': 4, 'chunk': 0, 'source': '4-0'}),
#  Document(page_content='Yes. "Louis Fernandez Company" <lofeco@ev1.net 04/10/2001 08:53 AM', metadata={'page': 5, 'chunk': 0, 'source': '5-0'}),
#  Document(page_content='It was a pleasure having you as a houseguest! Anytime  The current issue of Texas Monthly is only the beginning right after we announced our current earnings last week, The Wall Street Journal originated a story about a partnership our CFO invested in that made questionable statements about conflicts of interests with the shareholders, non disclosure of profits, etc., and have kept up with this story since last week, we have had shareholder lawsuits, SEC inquiries, our stock has taken a dive down to $15 today, down from $33 when the story first ran, and $87 since the beginning of the year. Right now it is beat up Enron time with no end in sight', metadata={'page': 6, 'chunk': 0, 'source': '6-0'}),
#  Document(page_content=". Anyway, you may to check the WSJ website and catch up  Also, I have a new boyfriend, my old biking buddy I mentioned we've been dating now for a few months, that seems to be going well. So that's all my news  XXOO", metadata={'page': 6, 'chunk': 1, 'source': '6-1'}),
#  Document(page_content='This will get you access to Livelink', metadata={'page': 7, 'chunk': 0, 'source': '7-0'}),
#  Document(page_content='I think yes.', metadata={'page': 8, 'chunk': 0, 'source': '8-0'}),
#  Document(page_content='1. If we have a US counterparty we insert the appropriate choice. =20 2. Revisions to the CFTC Rules have done away with the "Eligible Swap=20 Participant" rules for energy commodities (they would still apply to=20 agricultural products). The rules are still pretty similar however, and th= e=20 current lingo is now "Eligible Contract Participants". See our revised for= m,=20 attached. =09Karen A Cordova@EES =0904/04/2001 04:33 PM =09=09=20 =09=09', metadata={'page': 9, 'chunk': 0, 'source': '9-0'}),
#  Document(page_content='Anytime! =09Karen A Cordova@EES =0904/09/2001 09:25 AM =09=09 =09=09', metadata={'page': 10, 'chunk': 0, 'source': '10-0'}),
#  Document(page_content='It is OK to sign the copy I emailed to you. Just return the signed copy to me via fax 713/646 3490 and I will get is signed by an authorized officer here and return it to you. In your fax please tell me who you would like me to send the return fax to. Thanks for your prompt attention with this!', metadata={'page': 11, 'chunk': 0, 'source': '11-0'}),
#  Document(page_content='I have already responded to the counterparty. Savita Puthigai@ENRON 07/26/2000 03:37 PM', metadata={'page': 12, 'chunk': 0, 'source': '12-0'}),
#  Document(page_content="As a general matter, you need to use the forms of Confidentiality Agreements contained in the atty.fms bank, not the Swap Group's forms. We have developed a few of our own forms for special purposes, one, which is in the swap forms database/current forms, protects the counterparty only, and is used when Credit wants to get copies of financal statements from a counterparty and protects the financial information being provided by the counterparty. I have developed forms for use by the EnronOnline team, but those should not be used for any Enron company except EnronOnline and Enron Net Works. For any other types of matters/projects, we would also use the forms contained in the atty.fms bank. Genia FitzGerald 02/26/2001 03:44 PM", metadata={'page': 13, 'chunk': 0, 'source': '13-0'}),
#  Document(page_content='The 1100 series. Frequently I use 1100 3, the Bilateral form. Genia FitzGerald 02/27/2001 09:34 AM', metadata={'page': 14, 'chunk': 0, 'source': '14-0'}),
#  Document(page_content="Where are y'll moving to? Rhonda L Denton 08/31/2000 03:59 PM", metadata={'page': 15, 'chunk': 0, 'source': '15-0'}),
#  Document(page_content='Yup, FX & Currency Option provisions added. ! I hope to have our database open to you soon so you can look and see what definitions are included. Laurel Adams 06/01/2000 03:38 PM', metadata={'page': 16, 'chunk': 0, 'source': '16-0'}),
#  Document(page_content='What group did you go to? Julie Meyers 06/01/2000 04:01 PM', metadata={'page': 17, 'chunk': 0, 'source': '17-0'}),
#  Document(page_content='We have received the executed First Amendment to ISDA Master Agreement dated as of July 5, 2000. This amendment changes the Material Adverse Change Clause in the Agreement. Copies will be distributed.', metadata={'page': 18, 'chunk': 0, 'source': '18-0'}),
#  Document(page_content='Mary Solmonson is a Senior Director with ENA. Business purpose was to discuss online issues. Taffy Milligan 06/01/2000 02:19 PM', metadata={'page': 19, 'chunk': 0, 'source': '19-0'}),
#  Document(page_content="Looks good to me. I'm putting it on my calendar  Mary Cook 02/21/2001 05:11 PM", metadata={'page': 20, 'chunk': 0, 'source': '20-0'}),
#  Document(page_content='It is always a pleasure working with the online team, You all keep me busy but you are always kind and thankful, and believe me, those thanks are always appreciated! Lisa Gillette 06/07/2000 04:08 PM', metadata={'page': 21, 'chunk': 0, 'source': '21-0'}),
#  Document(page_content='Breakfast at 10:00 sounds great! Wherever you want to go also, I need to get my bike back from you, I might be doing some biking. I\'ve been thinking about you. Hope all is going well. "Patti Young" <pyoung@cliverunnells.com 05/17/2001 05:33 PM', metadata={'page': 22, 'chunk': 0, 'source': '22-0'}),
#  Document(page_content='Please call Carol. How about the Buffalo Grille, or is that too busy? "Patti Young" <pyoung@cliverunnells.com 05/17/2001 05:53 PM', metadata={'page': 23, 'chunk': 0, 'source': '23-0'}),
#  Document(page_content='Lucinda will be joining us. I havent heard back from Holly. Maybe you might want to give her a call too. I\'m sure she\'s a little stressed out right now! Maybe you could bring my bike & helmet when you come. "Patti Young" <pyoung@cliverunnells.com 05/18/2001 12:14 PM', metadata={'page': 24, 'chunk': 0, 'source': '24-0'}),
#  Document(page_content='Let\'s just keep it at 10 so we don\'t have to re coordinate things. "Patti Young" <pyoung@cliverunnells.com 05/18/2001 12:34 PM', metadata={'page': 25, 'chunk': 0, 'source': '25-0'}),
#  Document(page_content='I don\'t have Holly\'s email address, I always call her. "Patti Young" <pyoung@cliverunnells.com 05/18/2001 01:05 PM', metadata={'page': 26, 'chunk': 0, 'source': '26-0'}),
#  Document(page_content='281/364 5207 "Patti Young" <pyoung@cliverunnells.com 05/18/2001 03:06 PM', metadata={'page': 27, 'chunk': 0, 'source': '27-0'}),
#  Document(page_content='I got your company number on my own, so now we just have to wait to have the erequest approved. I hope it will be today. Edmund Cooper 03/21/2001 10:42 AM', metadata={'page': 28, 'chunk': 0, 'source': '28-0'}),
#  Document(page_content='I live to Swap! Edmund Cooper 03/22/2001 10:52 AM', metadata={'page': 29, 'chunk': 0, 'source': '29-0'}),
#  Document(page_content='I forwarded your resume last week onto my last contact that might have a jo= b=20 in London. The London Legal Dept. just seconded two outside lawyers, so th= ey=20 are properly staffed for the moment. Then I spoke to the Global Contracts= =20 people, and they didn\'t need anyone in London, but might have been interest= ed=20 if you wanted to go to Japan. The last Group is the online trading group. = I=20 forwarded your resume to the head of that groupp last week. We\'ll see this= =20 week  =09"Matthew Shaddock" <shaddilack@hotmail.com =0906/13/2000 04:57 PM =09=09=20 =09=09', metadata={'page': 30, 'chunk': 0, 'source': '30-0'}),
#  Document(page_content='thanks for your help! Justin Boyd 05/01/2001 07:30 AM', metadata={'page': 31, 'chunk': 0, 'source': '31-0'}),
#  Document(page_content='It is in my "forms" subdirectory, called "questionnaire umbrella re internet trading1.doc. Brent Hendry@ENRON 07/24/2000 06:05 PM', metadata={'page': 32, 'chunk': 0, 'source': '32-0'}),
#  Document(page_content="We also have lots of agreements between internal counterparties. I also owe you more comments I haven't forgotten", metadata={'page': 33, 'chunk': 0, 'source': '33-0'}),
#  Document(page_content='I am sorry, but I checked with the lawyer, and we are going to need that executed Agreement and we are going to need it as fast as you can track it down sorry to keep being such a pest!', metadata={'page': 34, 'chunk': 0, 'source': '34-0'}),
#  Document(page_content='Yes, we will be having it at Pastor Beth\'s. Do you need directions? It\'s at 7:00 pm. "Preisinger, Andrea" <PREISINGER@tmh.tmc.edu 05/09/2000 03:55 PM', metadata={'page': 35, 'chunk': 0, 'source': '35-0'}),
#  Document(page_content='We will have 14 people. "Preisinger, Andrea" <PREISINGER@tmh.tmc.edu 05/10/2000 08:03 AM', metadata={'page': 36, 'chunk': 0, 'source': '36-0'}),
#  Document(page_content='We have this down for signature right now. We hope to get it out today. John Pavetto@ENRON 07/31/2000 03:00 PM', metadata={'page': 37, 'chunk': 0, 'source': '37-0'}),
#  Document(page_content='No problema! Robert Bruce@ENRON Sent by: Robert Bruce@ENRON 08/17/2000 09:14 AM', metadata={'page': 38, 'chunk': 0, 'source': '38-0'}),
#  Document(page_content='76 0318139 "JASON PETERS" <PETEJ@andrews kurth.com 10/13/2000 10:07 AM', metadata={'page': 39, 'chunk': 0, 'source': '39-0'}),
#  Document(page_content='Always happy to hear from my favorite outside counsel! "JASON PETERS" <PETEJ@andrews kurth.com 10/13/2000 10:31 AM', metadata={'page': 40, 'chunk': 0, 'source': '40-0'}),
#  Document(page_content='Thanks, I forgot! Marianne Wilkins/ENRON@enronXgate 03/01/2001 11:51 AM', metadata={'page': 41, 'chunk': 0, 'source': '41-0'}),
#  Document(page_content='I think my bicycle is 52 centimeters. I hope you have a tire pump, because I don\'t and I haven\'t ridden the bike in about a year and I know the tires are totally flat. "Patti Young" <pyoung@cliverunnells.com 02/28/2001 12:44 PM', metadata={'page': 42, 'chunk': 0, 'source': '42-0'}),
#  Document(page_content='I don\'t think I need new tires, unless I\'m surprised. You might want to buy an extra tire in case you get a flat. I think I loaned Harry my old spare tire. Anytime Saturday is fine  "Patti Young" <pyoung@cliverunnells.com 02/28/2001 01:12 PM', metadata={'page': 43, 'chunk': 0, 'source': '43-0'}),
#  Document(page_content='Good! I thought I just had a checkup with Bikesport shortly before I stopped riding. I was just a little afraid I might need grease. "Patti Young" <pyoung@cliverunnells.com 03/06/2001 02:46 PM', metadata={'page': 44, 'chunk': 0, 'source': '44-0'}),
#  Document(page_content='Keep me posted have fun! "Patti Young" <pyoung@cliverunnells.com 03/06/2001 04:27 PM', metadata={'page': 45, 'chunk': 0, 'source': '45-0'}),
#  Document(page_content='I hope Carol will come! Holly was going to call her. "Patti Young" <pyoung@cliverunnells.com 03/22/2001 01:35 PM', metadata={'page': 46, 'chunk': 0, 'source': '46-0'}),
#  Document(page_content="So far I'm on if I don't have to work. Harry and I broke up on Monday.", metadata={'page': 47, 'chunk': 0, 'source': '47-0'}),
#  Document(page_content='Attached is the form of Confidentiality Agreement. Please call me at (713) 853 3399 if I can be of further service.', metadata={'page': 48, 'chunk': 0, 'source': '48-0'}),
#  Document(page_content='Lisa, I was returning your phone call to Carol St. Clair about the agreement and deleted the message by mistake before I got to your phone no. Can you give me a call at (713) 853 3399. Thanks!', metadata={'page': 49, 'chunk': 0, 'source': '49-0'}),
#  Document(page_content='I\'ll wait to hear from you tommorow. "Lisa Taylor" <ltaylor@Cysive.com 05/08/2000 02:39 PM', metadata={'page': 50, 'chunk': 0, 'source': '50-0'}),
#  Document(page_content='Attached is our bilateral form of Confidentiality Agreement when both parties are providing Confidential Information.', metadata={'page': 51, 'chunk': 0, 'source': '51-0'}),
#  Document(page_content='Mike Haney with EBS. Louise Kitchen 10/17/2000 05:58 PM', metadata={'page': 52, 'chunk': 0, 'source': '52-0'}),
#  Document(page_content="I checked w/the Corp. Secretary's office, and they were unaware that Rex and Dave were appointed as MD's, so the corporate paralegal is getting the board resolution passed adding them on, as well as adding Mark Palmer as a VP. Louise Kitchen 10/18/2000 10:34 AM", metadata={'page': 53, 'chunk': 0, 'source': '53-0'}),
#  Document(page_content='Will do! Paul Finken@ENRON COMMUNICATIONS 11/29/2000 10:29 AM', metadata={'page': 54, 'chunk': 0, 'source': '54-0'}),
#  Document(page_content='TFS was sent out but has not came back in signed. I was out yesterday, so Spectron has not gone out. I have that on my list to do today. Daniel Diamond 03/27/2001 10:48 AM', metadata={'page': 55, 'chunk': 0, 'source': '55-0'}),
#  Document(page_content='Heard anything on that amendment to the ISDA?', metadata={'page': 56, 'chunk': 0, 'source': '56-0'}),
#  Document(page_content='Thanks! Mark Powell\\CAL\\ECT Sent by: Mark Powell 08/15/2000 03:17 PM', metadata={'page': 57, 'chunk': 0, 'source': '57-0'}),
#  Document(page_content='Attached is our proposed form of agreement. If the counterparty has any questions, please have them call me. Gillian Johnson@ENRON 10/23/2000 11:28 AM', metadata={'page': 58, 'chunk': 0, 'source': '58-0'}),
#  Document(page_content='I faxed you the alcoa ISDA immediately after we spoke. It should be in NY right now.', metadata={'page': 59, 'chunk': 0, 'source': '59-0'}),
#  Document(page_content="Will do, I'll send you a copy too. I'm just waiting to get Sara's direction on one comment to the Legal Opinion, then I'll be ready to send it out. Janelle Scheuer 10/03/2000 09:57 AM", metadata={'page': 60, 'chunk': 0, 'source': '60-0'}),
#  Document(page_content='Yes to both questions', metadata={'page': 61, 'chunk': 0, 'source': '61-0'}),
#  Document(page_content="I don't think you can bird dog her too much. She receives in the emails and forwards them on to the relevant job group. The person with the job then decides who they do or do not want to interview. I don't think Gretchen will have much to do with that.", metadata={'page': 62, 'chunk': 0, 'source': '62-0'}),
#  Document(page_content='I just got in from Aspen. This Sunday looks good for me for Carol\'s birthday. Is Holly going, she might like to ? In terms of a townhome, I think that would be nice, also Garden Oaks. It seems like you are kinda all over the place, though, and you might want to be careful making "emotional" home buying decisions  As far as not hearing back from Enron. I wouldn\'t think anything of it. They told me they absolutely wanted me and then I didn\'t hear back from them for two months. Big companies have lots of layers to get anything done. Just keep plugging on  "Patti Young" <pyoung@pdq.net 08/15/2000 02:59 PM', metadata={'page': 63, 'chunk': 0, 'source': '63-0'}),
#  Document(page_content='Holly would be a good one to invite. She and Carol are real good friends. Lucinda really doesn\'t know Carol all that well, so I think I\'d skip her. Holly\'s work # is (281) 364 5207. "Patti Young" <pyoung@pdq.net 08/15/2000 05:12 PM', metadata={'page': 64, 'chunk': 0, 'source': '64-0'}),
#  Document(page_content='At a ratio of 10:1, you should have your 4th one signed and have the fifth one on the way  Marie Heard@ENRON COMMUNICATIONS 09/19/2000 05:40 PM', metadata={'page': 65, 'chunk': 0, 'source': '65-0'}),
#  Document(page_content='Perfect! Julia Murray@ECT 05/15/2001 04:49 PM', metadata={'page': 66, 'chunk': 0, 'source': '66-0'}),
#  Document(page_content='Janet, Would you like me to fax it to you? If so, what is your fax no?', metadata={'page': 67, 'chunk': 0, 'source': '67-0'}),
#  Document(page_content='Janet, I also thought it would save you alot of time if you are going to draft a document if you had the word version, so I am attaching it.', metadata={'page': 68, 'chunk': 0, 'source': '68-0'}),
#  Document(page_content="Mary, All those traps with security were worked out 4 years ago. London can get into the o: drive from there, the only directory they have access to in the o: drive is the atty.fms bank. If we put the swap forms back there, they can get at them. I know, because I've pulled them up myself from London. Mary Cook 03/13/01 09:39 AM", metadata={'page': 69, 'chunk': 0, 'source': '69-0'}),
#  Document(page_content='We appreciate all Credit does for us!', metadata={'page': 70, 'chunk': 0, 'source': '70-0'}),
#  Document(page_content="We are waiting for Mark Greenberg to finalize the negotiations on the amendment to the online ETA for DB. We would like to shut down BT from all financial trading. However, what we found was that DB will not execute the online ETA without some revisions. Mark is negotiating an amendment to the ETA with DB. Meanwhile, BT had already been trading online. Since that cat was already out of the bag so to speak, DB didn't want to shut them down from trading without having another avenue to trade, so we are continuing to trade as BT. We do not want to do this FOREVER, HOWEVER, so we do need to get BT SHUT DOWN. HOW GOES IT MARK", metadata={'page': 71, 'chunk': 0, 'source': '71-0'}),
#  Document(page_content="They are settled, but not executed. We have sent the ETA amendment out to the DB lawyer for signature, but we have not gotten it back signed. I'll give here a call.", metadata={'page': 72, 'chunk': 0, 'source': '72-0'}),
#  Document(page_content="We'll have to wait til Mark Greenberg gets in tomorrow. Adriane Schultea/ENRON@enronXgate 05/17/2001 11:15 AM", metadata={'page': 73, 'chunk': 0, 'source': '73-0'}),
#  Document(page_content='With respect to Deutsche Bank (""DB"), we have one credit issue remaining, DB would like us to add all the Enron trading entities DB trades with as Specified Entities under the ISDA Master Agreement and we are somewhat hesitant to do so, as this could potentially roll up swaps under structured loan transactions into a default under the ISDA Agreement. Sara and Bill Bradford in Credit are supposed to talk to the DB Credit people about this remaining issue. With respect to First Union National Bank, the draft we were working from was so old that they agreed to look at our current form of agreement which was sent to them on 11/8/00 for review. Sara is working on that with Susan Bailey, another paralegal in our Group. Denis O\'Connell 11/22/2000 06:05 AM', metadata={'page': 74, 'chunk': 0, 'source': '74-0'}),
#  Document(page_content='Holly, I already mailed the documents out to meet the Fedex deadline. Can you substitute these pages out later, or hand write the changes? "Mitchell, Holly" <hollymitchell@dwt.com 07/28/2000 05:31 PM', metadata={'page': 75, 'chunk': 0, 'source': '75-0'}),
#  Document(page_content="Thanks, I know I've been a pest to you today! Shari Stack 03/06/2001 02:45 PM", metadata={'page': 76, 'chunk': 0, 'source': '76-0'}),
#  Document(page_content="Yes, except for weather, the financial GTC's are designed to cover all energy commodities. Dianne Seib 09/25/2000 03:34 PM", metadata={'page': 77, 'chunk': 0, 'source': '77-0'}),
#  Document(page_content='Thanks! Sara Davidson/ENRON@enronXgate 03/29/2001 03:04 PM', metadata={'page': 78, 'chunk': 0, 'source': '78-0'}),
#  Document(page_content='It only shows a draft sent, no executed contract.', metadata={'page': 79, 'chunk': 0, 'source': '79-0'}),
#  Document(page_content='Good luck with the next stage of your life. It has been a pleasure working with you! Tobin Carlson 05/30/2000 09:52 AM', metadata={'page': 80, 'chunk': 0, 'source': '80-0'}),
#  Document(page_content='Please return our original copy of the agreement to me along with the copy of the cover letter evidencing that you sent the copy to Dynegy. Thanks. Judy Thorne/ENRON@enronXgate 06/05/2001 06:11 PM', metadata={'page': 81, 'chunk': 0, 'source': '81-0'}),
#  Document(page_content='No, please send to me and I will handle. Judy Thorne/ENRON@enronXgate 06/06/2001 09:06 AM', metadata={'page': 82, 'chunk': 0, 'source': '82-0'}),
#  Document(page_content="I just spoke to Mike Garred and John Raineri w/The New Power Company. Per this conv. it appears that ENA has master agreements in place to trade financial and physical gas. I directed him to Shari Stack, a lawyer in the power group, to discuss getting a master agreement in place with EPMI to trade physical power. They are aware that Credit is working on getting them some headroom, and as soon as they counterparty comes out of Credit, we'll get them approved to trade (pending resolution of physical power approval from Shari). If Credit could verbally let me know when they are approved I'd appreciate it, so I'll know to look for them. I will be traveling to Calgary Tuesday, so I may be incommunicado while the plane's in flight, so that could possibly hold things up", metadata={'page': 83, 'chunk': 0, 'source': '83-0'}),
#  Document(page_content='. Mary Griff Gray 03/09/2001 01:47 PM', metadata={'page': 83, 'chunk': 1, 'source': '83-1'}),
#  Document(page_content='Larry Joe Hunter 03/12/2001 08:31 AM', metadata={'page': 84, 'chunk': 0, 'source': '84-0'}),
#  Document(page_content='Thanks Mercy! Mercy Gil/ENRON@enronXgate 03/12/2001 02:51 PM', metadata={'page': 85, 'chunk': 0, 'source': '85-0'}),
#  Document(page_content='I wanted to let you know that the form of Enron Corp. Guaranty has been agreed to with BNP Paribas and has been sent up to Enron Corp. for signature today. I will send you a copy of the Guaranty once it is fully executed.', metadata={'page': 86, 'chunk': 0, 'source': '86-0'}),
#  Document(page_content='I hope we can do more than meet, if possible, let me buy you dinner! Matthew Dawson 03/22/2001 01:24 PM', metadata={'page': 87, 'chunk': 0, 'source': '87-0'}),
#  Document(page_content="I'm not showing I looked at this list at all. Isn't that right? Nicole Hunter@ENRON 03/28/2001 08:55 AM", metadata={'page': 88, 'chunk': 0, 'source': '88-0'}),
#  Document(page_content='Sorry about not getting back to you sooner. I am in Calgary this week. Stephanie and I met with Mark Taylor about this on Monday, and he said to go ahead and confirm this under the Houston master with Hess Energy Trading Company LLC. Julie Brewer@ENRON 03/14/01 01:52 PM', metadata={'page': 89, 'chunk': 0, 'source': '89-0'}),
#  Document(page_content='It has been my understanding that the first section is supposed to be for master swap agreements only. Having other documents listed in that section may be misleading to some parties who may misconstrue their use for general trading purposes, such as Global Contracts. That is why we created the "Other Agreements" section, to house these other agreements. My understanding isthat the only reason other agreements has been listed in the Master Swap Agreements Section is that they have been done so erroneously. The drop down were not created too artfully created, allowing wrong agreements to be put in Master Swap Agreements, which has been proliferating', metadata={'page': 90, 'chunk': 0, 'source': '90-0'}),
#  Document(page_content='. If my understanding is not correct, than when did the intentional use of that first section change? I think putting all agreement is a very bad idea. Sara Shackleton 03/14/01 05:35 PM', metadata={'page': 90, 'chunk': 1, 'source': '90-1'}),
#  Document(page_content='Done. Cheryl Nelson@ENRON Sent by: Cheryl Nelson@ENRON 03/21/2001 01:30 PM', metadata={'page': 92, 'chunk': 0, 'source': '92-0'}),
#  Document(page_content='Attached is the proposed form of LOI. Please let me know if it meets with your approval, and I will email it to the customer. I kept the language in the term sheet in the back pretty broad as it references "energy commodities". Your language re "US crude and products" wasn\'t clear to me. Perhaps you meant US crude and crude derivative/refined products? Will energy commodities work, or do want to limit it to crude products and charge more for other products? Bob Shults 03/14/01 04:55 PM', metadata={'page': 93, 'chunk': 0, 'source': '93-0'}),
#  Document(page_content='I revised the language in the "Description of Transaction" section and where the fee is and just wanted to make sure you were Ok before I sent it to your customer. I\'ve already drafted my email, I just need your OK. Daniel Diamond 03/14/01 05:23 PM', metadata={'page': 94, 'chunk': 0, 'source': '94-0'}),
#  Document(page_content='You need to talk to Stephanie Sever at x33465. Mark Greenberg@ENRON 03/14/01 05:58 PM', metadata={'page': 95, 'chunk': 0, 'source': '95-0'}),
#  Document(page_content='Do you want a bilateral or one way, and what is the nature of your discussions? Daniel Diamond 03/15/01 03:24 PM', metadata={'page': 96, 'chunk': 0, 'source': '96-0'}),
#  Document(page_content="He can call any one of the attorneys in the Swap Group, Mary Cook does Canada, but she'll be out next week so it would have to be quick, or Sara Shackleton or Brent Hendry. Veronica Gonzalez/ENRON@enronXgate 03/15/01 04:37 PM", metadata={'page': 97, 'chunk': 0, 'source': '97-0'}),
#  Document(page_content='Sam, I think counterparty ID# 754 is Bonneville Power Administration, not Bonneville Power Association. Samuel Schott 03/08/01 05:32 PM', metadata={'page': 98, 'chunk': 0, 'source': '98-0'}),
#  Document(page_content="Yeah, see if Mark T. will initial it. Tell him it's for a broker relationship and there we no changes to the form.", metadata={'page': 100, 'chunk': 0, 'source': '100-0'}),
#  Document(page_content='Thanks for the info, I appreciate it!', metadata={'page': 101, 'chunk': 0, 'source': '101-0'}),
#  Document(page_content="Can someone call me at x33399. I'm in the middle of doing these again and it won't let me submit the form. Enron Messaging Security@ENRON 03/20/2001 01:08 PM", metadata={'page': 102, 'chunk': 0, 'source': '102-0'}),
#  Document(page_content='OK by me! Lisa Lees 03/20/2001 04:15 PM', metadata={'page': 103, 'chunk': 0, 'source': '103-0'}),
#  Document(page_content='Are these physical transactions? Kimberly Hundl@ENRON 03/20/2001 04:12 PM', metadata={'page': 104, 'chunk': 0, 'source': '104-0'}),
#  Document(page_content="Your access to the Financial Trading Agreement has been completed. Why don't you take a look and make sure you now have edit capability.", metadata={'page': 105, 'chunk': 0, 'source': '105-0'}),
#  Document(page_content='Link   Sharon Crawford 03/21/2001 10:08 AM', metadata={'page': 106, 'chunk': 0, 'source': '106-0'}),
#  Document(page_content='Sam & Stephanie, Re: Cargill Ferrous International It was my understanding with the EOL Team that all divisions would have the legal incorporated entity as part of the name. Stephanie, I my preference is to kick their Password Application back and get them to change it to read something like "Cargill Ferrous International, a division of Cargill, Inc." or "Cargill, Inc. acting through its Cargill Ferrous International Division". Samuel Schott 03/21/2001 01:58 PM', metadata={'page': 107, 'chunk': 0, 'source': '107-0'}),
#  Document(page_content='Any updates on adding the correct legal name to this counterparty name?', metadata={'page': 108, 'chunk': 0, 'source': '108-0'}),
#  Document(page_content='Why do you say OK for weather? What restrictions do you have for counterparties trading weather? Justin Boyd 03/23/2001 02:20 AM', metadata={'page': 109, 'chunk': 0, 'source': '109-0'}),
#  Document(page_content="It's only a reflection of our high regard for you that we pass on this matter for your adept handling. Russell Diamond/ENRON@enronXgate 03/22/2001 05:22 PM", metadata={'page': 110, 'chunk': 0, 'source': '110-0'}),
#  Document(page_content="You're a machine! Marcus Nettelton@ENRON 03/22/2001 05:38 PM", metadata={'page': 111, 'chunk': 0, 'source': '111-0'}),
#  Document(page_content='No. Carol St Clair 03/29/2001 12:00 PM', metadata={'page': 112, 'chunk': 0, 'source': '112-0'}),
#  Document(page_content='You, as counsel, can agree to any form of NDA you think is acceptable. I will print it out and bring it around for signature Mark Greenberg@ENRON 03/23/2001 12:38 PM', metadata={'page': 113, 'chunk': 0, 'source': '113-0'}),
#  Document(page_content='Sharon, Per the email below, I looked in the financial trading agreement database and saw that Stephanie Panus, a paralegal in our group prepared an Annex B for this counterparty in January of this year. I would just confirm that the credit is the same and then use the same Annex B as before. I am going to fax the credit worksheet that Credit send Stephanie in January so you can check the credit. Below is the Annex B Stephanie prepared.', metadata={'page': 114, 'chunk': 0, 'source': '114-0'}),
#  Document(page_content="Sharon, There are some hanky things going on in these confirms I don't like. I've just spoken to Russell and I'm going to talk to a swap attorney and then get back to you. Sharon Crawford 03/23/2001 03:48 PM", metadata={'page': 115, 'chunk': 0, 'source': '115-0'}),
#  Document(page_content='I spoke to Stephanie and anytime between 9 11 am or after 3:30 pm would be fine for us. Just let us know. Esmeralda Gonzalez/ENRON@enronXgate 03/23/2001 04:36 PM', metadata={'page': 116, 'chunk': 0, 'source': '116-0'}),
#  Document(page_content="I don't know what you're talking about, so I must not be the right person. Noveena Mathew Joy/ENRON@enronXgate 03/26/2001 07:17 AM", metadata={'page': 117, 'chunk': 0, 'source': '117-0'}),
#  Document(page_content='I tracked down the culprit who worked on this master and it was Mark Taylor. I know he called Jon McKay and had a conversation with him about it and is looking at the master for particular issues in response to his conversation with Jon. Linda Sietzema 03/26/2001 11:11 AM', metadata={'page': 118, 'chunk': 0, 'source': '118-0'}),
#  Document(page_content='Any update yet?', metadata={'page': 119, 'chunk': 0, 'source': '119-0'}),
#  Document(page_content='Brant, please do not put me on emails for day to day business, drafts of masters and confirms. Thanks. Brant Reves/ENRON@enronXgate 03/27/2001 08:26 AM', metadata={'page': 120, 'chunk': 0, 'source': '120-0'}),
#  Document(page_content="Things are looking better. We tracked down the documents and it appears that Samantha sent them to counterparty's outside counsel on 3/15/01. I just spoke to Maureen Donley Hoopes at outside counsel and asked her to fax me the signature pages of the ISDA and counterparty's guaranty to me ASAP. Once we get those Russell will be a happy man and we can send a confirm out under the ISDA. I'll let you know as soon as we get the fax in.", metadata={'page': 121, 'chunk': 0, 'source': '121-0'}),
#  Document(page_content='Those are negotiated changes. The only was to tell what is a "Canadian" thing is by looking at the form. It is color coded with different colors for different countries or other special legal issues. I believe Canada is a purplely pink color in the form, the footnotes should tell you. Christina Finelli@EES 04/02/2001 03:48 PM', metadata={'page': 122, 'chunk': 0, 'source': '122-0'}),
#  Document(page_content='I take it all the other counterparties on this list cannot transact power since they are restricted by Credit  Marcus Nettelton@ENRON 03/27/2001 02:39 PM', metadata={'page': 123, 'chunk': 0, 'source': '123-0'}),
#  Document(page_content='I am OK with what Credit say, which is if the counterparties are already approved for trading those pulp & lumber products theyan trade the new products, except for the following counterparties which we need to be careful about becuase they could only tansact newsprint: The Bakersfield Californian: can transact only newsprint E.W. Scripps Company (The) can only transact 48.8 gram newsprint swaps Stephanie Sever 03/27/2001 03:08 PM', metadata={'page': 124, 'chunk': 0, 'source': '124-0'}),
#  Document(page_content='OK for me. Stephanie Sever 03/27/2001 03:40 PM', metadata={'page': 125, 'chunk': 0, 'source': '125-0'}),
#  Document(page_content="Well, I guess we could. since we needed to do it immediately, only Stepanie can only do it immediately. Do you want me to change it, or, Stephanie, since you've already changed it will it be already changed tomorrow so we don't need to do anything. I'm so confused?  Tom Moran/ENRON@enronXgate 03/28/2001 03:29 PM", metadata={'page': 126, 'chunk': 0, 'source': '126-0'}),
#  Document(page_content='Thanks Kay! Kay Young 11/02/2000 03:16 PM', metadata={'page': 127, 'chunk': 0, 'source': '127-0'}),
#  Document(page_content='What is the nature of the confidential information being discussed? Will our standard language " furnished in connection with a possible transaction or other business relationship " suffice, or do you want to be more specific? Also, do you want the bilateral form? Paul Finken/ENRON@enronXgate 02/21/2001 11:18 AM', metadata={'page': 128, 'chunk': 0, 'source': '128-0'}),
#  Document(page_content='Paul, Attached are the 3 NDAs you requested. Please let me know if they meet with your approval, and I will email them to your customers. Paul Finken/ENRON@enronXgate 02/21/2001 01:10 PM', metadata={'page': 129, 'chunk': 0, 'source': '129-0'}),
#  Document(page_content="I'm working on Samantha's IMC Canada. It was signed by faxed signatures yesterday and I am expecting the originally signed documents to come in by Federal Express today. Esmeralda Gonzalez/ENRON@enronXgate 03/29/2001 07:48 AM", metadata={'page': 130, 'chunk': 0, 'source': '130-0'}),
#  Document(page_content='My notes show that this is a governmental. It is the utility for the Town of Colorado Springs, Colorado. Samuel Schott 03/29/2001 10:13 AM', metadata={'page': 131, 'chunk': 0, 'source': '131-0'}),
#  Document(page_content="Strictly informational. I need to know everytime we have a governmental entity, so since there was no note in the side that this was connected a governmental I had to research that. I was sharing the information I gathered with you so as to save you some time in case you didn't already know this. Obviously, you did. Samuel Schott 04/02/2001 06:01 PM", metadata={'page': 132, 'chunk': 0, 'source': '132-0'}),
#  Document(page_content='OK for me. =09Lisa Lees =0903/29/2001 04:49 PM =09=09=20 =09=09', metadata={'page': 133, 'chunk': 0, 'source': '133-0'}),
#  Document(page_content="You're wearing me down, you're relentless  Daniel Diamond 03/30/2001 03:04 PM", metadata={'page': 134, 'chunk': 0, 'source': '134-0'}),
#  Document(page_content='Thanks. I seem to be keeping you busy today! Kay Young 03/30/2001 03:27 PM', metadata={'page': 135, 'chunk': 0, 'source': '135-0'}),
#  Document(page_content='It makes me feel so wanted not! Kay Young 03/30/2001 03:31 PM', metadata={'page': 136, 'chunk': 0, 'source': '136-0'}),
#  Document(page_content="I have complete faith in you! By the way, the guy from Star already called with corrections to their company name, it's Starsupply Petroleum Inc. He said he passed the agreement on to his legal and he would be getting us comments back on Monday. Daniel Diamond 03/30/2001 04:22 PM", metadata={'page': 137, 'chunk': 0, 'source': '137-0'}),
#  Document(page_content="I'm sorry about not turning this around sooner. I thought I might be getting other comments from you. If it meets with your approval, please sign it and return it via fax no. (713) 646 3490 and I will have it signed by Enron and return a copy to you by fax. robr@starsupply.com 04/16/2001 06:27 PM", metadata={'page': 138, 'chunk': 0, 'source': '138-0'}),
#  Document(page_content='Please talk to Mark Greenberg, an attorney in our group, at (713) 345 8897. I am a paralegal. robr@starsupply.com 04/18/2001 03:19 PM', metadata={'page': 139, 'chunk': 0, 'source': '139-0'}),
#  Document(page_content='Thanks for your help this week, I appreciate it  Stephanie Panus@ENRON 04/06/2001 05:01 PM', metadata={'page': 140, 'chunk': 0, 'source': '140-0'}),
#  Document(page_content='No! Daniel Diamond 04/09/2001 02:34 PM', metadata={'page': 141, 'chunk': 0, 'source': '141-0'}),
#  Document(page_content='The ISDA Agreement is not in electronic form. I will send you over a clean version. Karen A Cordova@EES 04/10/2001 10:12 AM', metadata={'page': 142, 'chunk': 0, 'source': '142-0'}),
#  Document(page_content="That's a deal! Karen A Cordova@EES 04/10/2001 01:22 PM", metadata={'page': 143, 'chunk': 0, 'source': '143-0'}),
#  Document(page_content='Ken Curry is following up with the woman from NBC on this. Bob Crane/ENRON@enronXgate 04/10/2001 04:32 PM', metadata={'page': 144, 'chunk': 0, 'source': '144-0'}),
#  Document(page_content='You are the Best! Dianne Seib 04/11/2001 09:37 AM', metadata={'page': 145, 'chunk': 0, 'source': '145-0'}),
#  Document(page_content='Obviously Frank, you are trying to kill me !', metadata={'page': 146, 'chunk': 0, 'source': '146-0'}),
#  Document(page_content='Mark, We emailed an Enron One Way NDA to Global Crossing, Ltd. 11/22/00 at the request of Peter Feltman. Was there something the matter with that form or is this for something totally different? Mark Greenberg@ENRON 04/11/2001 04:41 PM', metadata={'page': 147, 'chunk': 0, 'source': '147-0'}),
#  Document(page_content='Do you have an address for them? Daniel Diamond/ENRON@enronXgate 04/17/2001 11:35 AM', metadata={'page': 148, 'chunk': 0, 'source': '148-0'}),
#  Document(page_content='What is the nature of your discussions? Bob Shults/ENRON@enronXgate 04/17/2001 03:27 PM', metadata={'page': 149, 'chunk': 0, 'source': '149-0'}),
#  Document(page_content='I continue to say "no" for financial because they are not an eligible swap participant. For a counterparty to become an eligible swap participant if they are not one in their own right, they would have to post an up front letter of credit fully covering their trading PRIOR to doing any trades. So this ball is in Credit\'s court.', metadata={'page': 150, 'chunk': 0, 'source': '150-0'}),
#  Document(page_content='Ditto Credit. Lisa Lees 04/18/2001 08:38 AM', metadata={'page': 151, 'chunk': 0, 'source': '151-0'}),
#  Document(page_content='You are the best! Marcus Nettelton@ENRON 04/19/2001 03:25 PM', metadata={'page': 152, 'chunk': 0, 'source': '152-0'}),
#  Document(page_content='Sounds good to me! Saturday, 8:00 am at Buffalo Grille it is!', metadata={'page': 153, 'chunk': 0, 'source': '153-0'}),
#  Document(page_content="I'm just going to have to call you Quick Draw McGraw! I Can't print the lists out before I get a response from you! Marcus Nettelton@ENRON 04/20/2001 04:08 PM", metadata={'page': 154, 'chunk': 0, 'source': '154-0'}),
#  Document(page_content='My closing is set for June 5, move in date for my new house is June 9, so there should be no problem.', metadata={'page': 155, 'chunk': 0, 'source': '155-0'}),
#  Document(page_content='I am available Saturday after my morning run. If you would like some help I would be happy to help out!', metadata={'page': 156, 'chunk': 0, 'source': '156-0'}),
#  Document(page_content='Things have come up w/Mark & Sara and there is a clear indication from their front that we need to retain the green files. Maybe we need to discuss this with the whole group ? Mary Cook 04/23/2001 09:50 AM', metadata={'page': 157, 'chunk': 0, 'source': '157-0'}),
#  Document(page_content='I havent heard anything back from them, Mark, have you? Daniel Diamond/ENRON@enronXgate 04/23/2001 02:46 PM', metadata={'page': 158, 'chunk': 0, 'source': '158-0'}),
#  Document(page_content='thanks Taffy! Taffy Milligan 04/23/2001 04:20 PM', metadata={'page': 159, 'chunk': 0, 'source': '159-0'}),
#  Document(page_content='I am sorry I am just getting back to you, but I had to check with my whole= =20 legal team around the world, and I just heard back from the final critical= =20 one. We are OK with them trading the products below. However, on physical= =20 power, they can only trade west power. Stephanie, will you need to open th= em=20 up so they can trade immediately? =09Walter Guidroz/ENRON@enronXgate =0904/23/2001 05:35 PM =09=09=20 =09=09', metadata={'page': 160, 'chunk': 0, 'source': '160-0'}),
#  Document(page_content='You are the best! =09Stephanie Sever/ENRON@enronXgate =0904/24/2001 11:08 AM =09=09=20 =09=09', metadata={'page': 161, 'chunk': 0, 'source': '161-0'}),
#  Document(page_content="I really don't know. Maybe the icon, which is just a shortcut to the database, won't work because of outlook. I haven't had this problem with any other people on outlook before. You might want to talk to your computer person. He can probably find the database the long way. It is just a misc. Lotus Notes application. Angela Chen/ENRON@enronXgate 04/25/2001 10:16 AM", metadata={'page': 162, 'chunk': 0, 'source': '162-0'}),
#  Document(page_content='OK for me! =09Stephanie Sever/ENRON@enronXgate =0904/24/2001 03:28 PM =09=09=20 =09=09', metadata={'page': 163, 'chunk': 0, 'source': '163-0'}),
#  Document(page_content='Do you want me to call Steve Kessler re: Enron Corp.?', metadata={'page': 164, 'chunk': 0, 'source': '164-0'}),
#  Document(page_content='OK for me. Stephanie Sever/ENRON@enronXgate 04/24/2001 04:23 PM', metadata={'page': 165, 'chunk': 0, 'source': '165-0'}),
#  Document(page_content='Rob, can I get the four deal nos. so I can get the information I need from the confirm desk to prepare the termination letters? I will contact Steve South to get the name & phone nos. of the contacts at the counterparty I can send the letters to. Robert B Cass/ENRON@enronXgate 04/24/2001 06:28 PM', metadata={'page': 166, 'chunk': 0, 'source': '166-0'}),
#  Document(page_content='Rob Cass sent me the deal nos., and I have made a request to the confirm desk to get the trade terms. Thanks for your help. Sheri Thomas/ENRON@enronXgate 04/25/2001 08:50 AM', metadata={'page': 167, 'chunk': 0, 'source': '167-0'}),
#  Document(page_content='You are bad to the bones ! Bob Bowen 04/25/2001 11:42 AM', metadata={'page': 168, 'chunk': 0, 'source': '168-0'}),
#  Document(page_content='Yes. Bob Bowen 04/25/2001 12:31 PM', metadata={'page': 169, 'chunk': 0, 'source': '169-0'}),
#  Document(page_content='Yes, I never got the signed NDA faxed to me. Mark Greenberg@ENRON 04/25/2001 11:55 AM', metadata={'page': 170, 'chunk': 0, 'source': '170-0'}),
#  Document(page_content='Thank you Kay, I really appreciate all your help! Kay Young 04/25/2001 02:49 PM', metadata={'page': 171, 'chunk': 0, 'source': '171-0'}),
#  Document(page_content="Sounds like an Indian chief! Of course, the name on this LOI I just got is Finn Swarting, which isn't much better! Kay Young 04/25/2001 04:52 PM", metadata={'page': 172, 'chunk': 0, 'source': '172-0'}),
#  Document(page_content='Fred Philipson/ENRON@enronXgate 03/01/2001 01:31 PM', metadata={'page': 173, 'chunk': 0, 'source': '173-0'}),
#  Document(page_content='Fred Philipson/ENRON@enronXgate 03/01/2001 03:39 PM', metadata={'page': 174, 'chunk': 0, 'source': '174-0'}),
#  Document(page_content='Same type of discussions as those other two we sent out for auditors? Michael Bridges@ENRON 03/07/2001 06:11 PM', metadata={'page': 175, 'chunk': 0, 'source': '175-0'}),
#  Document(page_content='Do you have the address for the counterparty? Fred Philipson/ENRON@enronXgate 04/25/2001 04:17 PM', metadata={'page': 176, 'chunk': 0, 'source': '176-0'}),
#  Document(page_content='Attached is the NDA you requested. Fred Philipson/ENRON@enronXgate 04/25/2001 04:29 PM', metadata={'page': 177, 'chunk': 0, 'source': '177-0'}),
#  Document(page_content='The list of new phone numbers will be sent to my usual distribution for documentation, which includes Connie Sutton from Global Contracts. As to what numbers they are replacing, they are replacing all the phone numbers we might have had across the board with this counterparty. If you would like to see the numbers, obtain a copy of the notice from Connie Sutton. As I just mailed it, it should get there in a few days.', metadata={'page': 178, 'chunk': 0, 'source': '178-0'}),
#  Document(page_content='Quick Draw   Marcus Nettelton@ENRON 04/25/2001 05:25 PM', metadata={'page': 179, 'chunk': 0, 'source': '179-0'}),
#  Document(page_content='Link   The link is above. I have to do your request for edit capability. You will not be able to see comments or make Credit comments until your request is completed. I will let you know when that is done. Randy Otto 04/27/2001 09:13 AM', metadata={'page': 180, 'chunk': 0, 'source': '180-0'}),
#  Document(page_content='She seemed to have more initiative than the average temp. Was nice. I would be fine with having her work for me again. Becky Spencer 04/27/2001 11:28 AM', metadata={'page': 181, 'chunk': 0, 'source': '181-0'}),
#  Document(page_content="Thanks, you're the best! Samuel Schott 04/27/2001 03:47 PM", metadata={'page': 182, 'chunk': 0, 'source': '182-0'}),
#  Document(page_content="Danm that doesn't sound like a full legal name ? Daniel Diamond/ENRON@enronXgate 04/30/2001 03:03 PM", metadata={'page': 183, 'chunk': 0, 'source': '183-0'}),
#  Document(page_content="It won't let me open the document. Can you ressend it? Carlos Alatorre/ENRON@enronXgate 05/01/2001 04:14 PM", metadata={'page': 184, 'chunk': 0, 'source': '184-0'}),
#  Document(page_content='Ok to copy. Lisa Lees/ENRON@enronXgate 05/01/2001 04:32 PM', metadata={'page': 185, 'chunk': 0, 'source': '185-0'}),
#  Document(page_content="Yao, you're a bum, we will miss you at dinner tonight! Yao Apasu@ENRON DEVELOPMENT 05/01/2001 06:11 PM", metadata={'page': 186, 'chunk': 0, 'source': '186-0'}),
#  Document(page_content='Sheri, I need to know the nature of the discussions we will be having with this company so I know how to word the decription in the agreement. Also, usually I email the agreements directly to the counterparty, so unless he will be delivering this in another manner, I will need an email address. Sheri L Cromwell/ENRON@enronXgate 05/02/2001 04:34 PM', metadata={'page': 187, 'chunk': 0, 'source': '187-0'}),
#  Document(page_content='nan', metadata={'page': 188, 'chunk': 0, 'source': '188-0'}),
#  Document(page_content='Pursuant to the documentation the counterparty provided when they entered into the power EEI, and at the direction of Marcus Nettelton, a lawyer in the power group, the counterparty name for the Port of Oakland should set up in GCP as follows: The City of Oakland, a municipal corporation acting by and through its Board of Port Commissioners GCP, if you could please redo the counterparty name, and Stephanie, if you could please resubmit the PA to match the counterparty name, then we can get this one done  Samuel Schott 05/03/2001 09:24 AM', metadata={'page': 189, 'chunk': 0, 'source': '189-0'}),
#  Document(page_content='Joe, I need the deal specifics so I can prepare an exhibit. Larry Joe Hunter 05/09/2001 11:33 AM', metadata={'page': 190, 'chunk': 0, 'source': '190-0'}),
#  Document(page_content='I would love to pick up you and Henry! Alicia Goodrow/ENRON@enronXgate 05/07/2001 09:21 AM', metadata={'page': 191, 'chunk': 0, 'source': '191-0'}),
#  Document(page_content='OK for me. Lisa Lees/ENRON@enronXgate 05/08/2001 08:29 AM', metadata={'page': 192, 'chunk': 0, 'source': '192-0'}),
#  Document(page_content="Thanks for the info. I'll direct it to her the next time. Samuel Schott 05/08/2001 05:24 PM", metadata={'page': 193, 'chunk': 0, 'source': '193-0'}),
# ...
#  Document(page_content="!. I'll be trying to do that big request, and will let you know if it doesn't go right. Enron Messaging Security@ENRON 02/27/2001 01:12 PM", metadata={'page': 634, 'chunk': 0, 'source': '634-0'}),
#  Document(page_content='How do I do more than one request at a time. Can you call me a x33399? Enron Messaging Security@ENRON 02/27/2001 01:12 PM', metadata={'page': 635, 'chunk': 0, 'source': '635-0'}),
#  Document(page_content="They must not let her take time off anymore. It is quite disruptive to all our business to have her our of the office, don't you think?  Bob Bowen 02/27/2001 12:29 PM", metadata={'page': 636, 'chunk': 0, 'source': '636-0'}),
#  Document(page_content='OK with me! Stephanie Sever 02/27/2001 01:30 PM', metadata={'page': 637, 'chunk': 0, 'source': '637-0'}),
#  Document(page_content="I tried to get you access yesterday, there are three Angela Davis's in the System, what's your email address? Angela Davis@ENRON 02/28/2001 06:59 AM", metadata={'page': 638, 'chunk': 0, 'source': '638-0'}),
#  Document(page_content='I just sent the request. I put a rush on it, so hopefully it should get approved today. Angela Davis@ENRON 02/28/2001 08:49 AM', metadata={'page': 639, 'chunk': 0, 'source': '639-0'}),
#  Document(page_content='You are the best!', metadata={'page': 640, 'chunk': 0, 'source': '640-0'}),
#  Document(page_content="Here's the list with the missing counterparties.", metadata={'page': 641, 'chunk': 0, 'source': '641-0'}),
#  Document(page_content='Mark Taylor Carol St. Clair Mary Cook Brent Hendry Sara Shackleton Frank Sayre Francisco Pinto Leite Cheryl Nelson Bob Bruce Susan Bailey Samantha Boyd Stephanie Panus Tana Jones Marie Heard Mercy Gil/ENRON@enronXgate 03/01/2001 01:22 PM', metadata={'page': 642, 'chunk': 0, 'source': '642-0'}),
#  Document(page_content="So, I should expect to get my future clickpaper approvals from her. I just don't want to look at any lists but what Credit sends to me. Walter Guidroz/ENRON@enronXgate 03/05/2001 10:06 AM", metadata={'page': 643, 'chunk': 0, 'source': '643-0'}),
#  Document(page_content='Probably', metadata={'page': 644, 'chunk': 0, 'source': '644-0'}),
#  Document(page_content="I'm with you on Montana. I checked the files in the big file room, and it is a Montana corporation. Walter Guidroz/ENRON@enronXgate 03/06/2001 11:19 AM", metadata={'page': 645, 'chunk': 0, 'source': '645-0'}),
#  Document(page_content='It sound good to me. Shall we meet at your house or mine and at what time? Alicia Goodrow/ENRON@enronXgate 03/06/2001 05:13 PM', metadata={'page': 646, 'chunk': 0, 'source': '646-0'}),
#  Document(page_content="Sounds like a good plan! I'm at 1920 Banks Street, the last street off=20 Shepherd before you hit the Swest Fwy. So, when you leave church, go down= =20 Shepherd, then make a right on the last street before the fwy. Go past the= =20 1st stop sign and then I'll be about the 3rd or 4th house on the left, a=20 taupe colored cottage with a pointy roof and vines growing halfway up the= =20 side of the house. My home # is 529 1038. See you at 12:45! =09Alicia Goodrow/ENRON@enronXgate =0903/09/2001 08:24 AM =09=09=20 =09=09", metadata={'page': 647, 'chunk': 0, 'source': '647-0'}),
#  Document(page_content="Nope, not yet. I'm absolutely swamped   I haven't forgotten about it tho. My short agenda is Day 1: Go over basics of financial documentation w/confirm desk team & your assistants (maybe 2 4 hours depending on level of detail we go into) (spend rest of day approving online counterparties), Day 2: Go over specifics of confirmations with your assistants so they can prepare the Special Legal/Credit Annex for a confirm and review how to read a credit worksheet and what the credit issues mean (spend rest of day approving online counterparties), Day 3: Spend time with you & Peter going over what I went over with assistants & confirm people, then maybe spend time letting any of your dealmakers quiz me as they desire about swap issues (spend free time approving online counterparties)", metadata={'page': 648, 'chunk': 0, 'source': '648-0'}),
#  Document(page_content=". Don't add a lot of people on, I get really nervous speaking in front of large groups I am a shy girl, you know! My thoughts are Greg Johnston 03/07/2001 02:36 PM", metadata={'page': 648, 'chunk': 1, 'source': '648-1'}),
#  Document(page_content='Is Credit aware of this? Mark Taylor 03/08/2001 05:10 PM', metadata={'page': 649, 'chunk': 0, 'source': '649-0'}),
#  Document(page_content="I spoke to the woman at Sask and she's ok on everything. Matilda Machado 03/09/2001 08:33 AM", metadata={'page': 650, 'chunk': 0, 'source': '650-0'}),
#  Document(page_content='For you, anything! Mark Greenberg@ENRON 03/09/2001 08:54 AM', metadata={'page': 651, 'chunk': 0, 'source': '651-0'}),
#  Document(page_content='Our project is a little different, so I think I am OK. Thanks, as usual for your help! Kay Young 03/09/2001 09:55 AM', metadata={'page': 652, 'chunk': 0, 'source': '652-0'}),
#  Document(page_content='I feel the power  Shari Stack 03/09/2001 11:21 AM', metadata={'page': 653, 'chunk': 0, 'source': '653-0'}),
#  Document(page_content='OK for me.', metadata={'page': 654, 'chunk': 0, 'source': '654-0'}),
#  Document(page_content='At the request of Kim Detiveaux, I am attaching our proposed form of Non Disclosure Agreement. If the enclosed meets with your approval, please execute the agreement and return it to me via fax no. (713) 646 3490. I will then have it executed by Enron. If you have any comments or questions please call Mark Greenberg, Senior Counsel, at (713) 345 8897 or me at (713) 853 3399. We look forward to hearing from you.', metadata={'page': 655, 'chunk': 0, 'source': '655-0'}),
#  Document(page_content='Already done. See you tonight!', metadata={'page': 656, 'chunk': 0, 'source': '656-0'}),
#  Document(page_content='Mark and I were just discussing the project yesterday. I am out for Thanksgiving vacation all next week, but when I get back the week after that we definitely want to get it back on track!', metadata={'page': 657, 'chunk': 0, 'source': '657-0'}),
#  Document(page_content='Sure thing!', metadata={'page': 658, 'chunk': 0, 'source': '658-0'}),
#  Document(page_content='Do you have a full legal name for Equiva Trading?', metadata={'page': 659, 'chunk': 0, 'source': '659-0'}),
#  Document(page_content='Attached please find the NDA you requested.', metadata={'page': 660, 'chunk': 0, 'source': '660-0'}),
#  Document(page_content='No, the last note I have is proving the revised NDA for you to send to them. No word since then.', metadata={'page': 661, 'chunk': 0, 'source': '661-0'}),
#  Document(page_content='I just agreed to the changes on the phone with Bob Klein and am going to finalize the agreement and fax it to him tomorrow and then follow up with originals.', metadata={'page': 662, 'chunk': 0, 'source': '662-0'}),
#  Document(page_content='As you requested:', metadata={'page': 663, 'chunk': 0, 'source': '663-0'}),
#  Document(page_content='Today.', metadata={'page': 664, 'chunk': 0, 'source': '664-0'}),
#  Document(page_content='Ran it by Leslie, OK for us!', metadata={'page': 665, 'chunk': 0, 'source': '665-0'}),
#  Document(page_content='Thanks for the kind word!', metadata={'page': 666, 'chunk': 0, 'source': '666-0'}),
#  Document(page_content='As you requested, attached is the form of NDA for transmittal to your customer:', metadata={'page': 667, 'chunk': 0, 'source': '667-0'}),
#  Document(page_content='Anytime!', metadata={'page': 668, 'chunk': 0, 'source': '668-0'}),
#  Document(page_content='Are you having our copy walked up to me?', metadata={'page': 669, 'chunk': 0, 'source': '669-0'}),
#  Document(page_content="Justy, thanks for your quick response. I heard back from Edmund too, and he gave me the name of a V&E lawyer he has used in London for Russian law and Anne Koehler and I gave him a quick call. Doug Glass. So we switched it to NY law and ICC arbitration rules and are giving it a go. Thanks for your help! I can't believe our business guy call 2 hours before a lunch meeting with a Russian company and think it's business as usual!", metadata={'page': 670, 'chunk': 0, 'source': '670-0'}),
#  Document(page_content='Done. I was waiting for the EOL team to get in a new Password Application and no one told me they got it in. I just went in and approved them.', metadata={'page': 671, 'chunk': 0, 'source': '671-0'}),
#  Document(page_content="I'll put you down too!", metadata={'page': 672, 'chunk': 0, 'source': '672-0'}),
#  Document(page_content='What is the nature of the business you are discussing? Also, do you want me to send this by email? If so, I will need thir email address.', metadata={'page': 673, 'chunk': 0, 'source': '673-0'}),
#  Document(page_content="He's already signed for our side. We're done.", metadata={'page': 674, 'chunk': 0, 'source': '674-0'}),
#  Document(page_content='How can we find out who has a clue?', metadata={'page': 676, 'chunk': 0, 'source': '676-0'}),
#  Document(page_content='Patrick, Can we track down who/how these trades are getting entered into the system? Is there someone entering the trades into the system? Is this just an old counterparty/book set up in GCP that needs to get renamed. Legal (me) has no idea why trades are being done out of EGM. Can we find out who is doing them?', metadata={'page': 677, 'chunk': 0, 'source': '677-0'}),
#  Document(page_content='It sounds ok to me.', metadata={'page': 678, 'chunk': 0, 'source': '678-0'}),
#  Document(page_content='I will get them done today.', metadata={'page': 679, 'chunk': 0, 'source': '679-0'}),
#  Document(page_content='I will get them done today.', metadata={'page': 680, 'chunk': 0, 'source': '680-0'}),
#  Document(page_content='This counterparty has been updated.', metadata={'page': 681, 'chunk': 0, 'source': '681-0'}),
#  Document(page_content='Pretty funny! If we could only do it for real!', metadata={'page': 682, 'chunk': 0, 'source': '682-0'}),
#  Document(page_content='Just an FYI, my notes in my database reflect that Tri State Generation is a Colorado Cooperative', metadata={'page': 683, 'chunk': 0, 'source': '683-0'}),
#  Document(page_content="I also got an email back from Bill Bradford, head of Credit that siad this doesn't make sense. Maybe you need to prepare a print out of the trades and send to debbie, me & bill.", metadata={'page': 684, 'chunk': 0, 'source': '684-0'}),
#  Document(page_content='This counterparty was approved by Legal on Friday.', metadata={'page': 685, 'chunk': 0, 'source': '685-0'}),
#  Document(page_content='De nada', metadata={'page': 686, 'chunk': 0, 'source': '686-0'}),
#  Document(page_content='Let me know if I can be of further help.', metadata={'page': 687, 'chunk': 0, 'source': '687-0'}),
#  Document(page_content='Thanks for your help!', metadata={'page': 688, 'chunk': 0, 'source': '688-0'}),
#  Document(page_content='I just got handed another list  Can I get the datasheets for the following companies: Enron Global Markets LLC Enron Liquids Fuels, Inc. Enron Fuels Caribbean L.P. Enron Petrochemicals Company Enron Gas Liquids, Inc. Enron Clean Fuels Company Enron Reserve Acquisition Corp. Enron Capital & Trade Resources Singapore Pte Ltd Enron Capital & Trade Global Resources Corp. Enron Capital & Trade International Corp. Enron Capital & Trade International Corp.   Singapore Branch Thanks!', metadata={'page': 689, 'chunk': 0, 'source': '689-0'}),
#  Document(page_content='Taria, Thanks for your help, I really appreciate it!', metadata={'page': 690, 'chunk': 0, 'source': '690-0'}),
#  Document(page_content='No, only executed amendments.', metadata={'page': 691, 'chunk': 0, 'source': '691-0'}),
#  Document(page_content='Please send originals to me for handling. I will give a copy to you.', metadata={'page': 692, 'chunk': 0, 'source': '692-0'}),
#  Document(page_content="Weren't we also going to get a printer in the area?", metadata={'page': 693, 'chunk': 0, 'source': '693-0'}),
#  Document(page_content='Lance, Can you have your install people mark with a yellow sticky or something where the analog lines for the PCs are located. Much thanks!', metadata={'page': 694, 'chunk': 0, 'source': '694-0'}),
#  Document(page_content='You are the best!', metadata={'page': 695, 'chunk': 0, 'source': '695-0'}),
#  Document(page_content='Lance, I just spoke to Mary Cook and she would like all four areas done by the end of today. Is that doable?', metadata={'page': 696, 'chunk': 0, 'source': '696-0'}),
#  Document(page_content="Mary Cook wants me to put together a list of people's home ph, cell no's/pagers, in case we need to call in help during the holidays. Can you provide me with your info in case we get surprised and have to set up additonal data rooms. Much thanks!", metadata={'page': 697, 'chunk': 0, 'source': '697-0'}),
#  Document(page_content='Thanks Lance!', metadata={'page': 698, 'chunk': 0, 'source': '698-0'}),
#  Document(page_content="I can't tell the fax numbers on some of the faxes and where the analog lines are. Can you meet with me?", metadata={'page': 699, 'chunk': 0, 'source': '699-0'}),
#  Document(page_content='It appears that the fax you moved in on the 33rd floor was actively being used by Scott Tholan and his assistant on that floor (x58889). Can your people please move it back ASAP and find us another one. Thanks.', metadata={'page': 700, 'chunk': 0, 'source': '700-0'}),
#  Document(page_content='Any update on these faxes? I have to get my list to Louise Kitchen today.', metadata={'page': 701, 'chunk': 0, 'source': '701-0'}),
#  Document(page_content='Lance, Did we replace the fax machine we erroneously took on the 33rd floor?', metadata={'page': 702, 'chunk': 0, 'source': '702-0'}),
#  Document(page_content="Teresa, By copy of this email, I am asking Stephanie Panus, another Paralegal in our group, to handle this for you as I am on working on a special project this week. Stephanie, per Teresa's voicemail, Cinergy is very interested in getting a financial master in place to trade with us ASAP. Can you please give their attorney a call. Teresa, you forgot Mr. Gollomp's phone number.", metadata={'page': 703, 'chunk': 0, 'source': '703-0'}),
#  Document(page_content='I am still using the list. I have to circulate the list to the team from time to time.', metadata={'page': 704, 'chunk': 0, 'source': '704-0'}),
#  Document(page_content='I need to know what group Nekesha is in.', metadata={'page': 706, 'chunk': 0, 'source': '706-0'}),
#  Document(page_content='You do not have to grant Nakesha access. She already has view only access as does any Enron employee. If you show her how to set up an icon to get into the database, she should be able to get view access to the database. All Enron employees have view access. Only employees of Legal and Credit can have edit access access. Does that help?', metadata={'page': 707, 'chunk': 0, 'source': '707-0'}),
#  Document(page_content="I don't have any record or receiving any such assignment and I checked with the other paralegals and they don't have a record of receiving it. Can you have Mirant resend it to Samantha Boyd, as she is the paralegal handling the paralegal assignment rotation right now. Sorry about that!", metadata={'page': 708, 'chunk': 0, 'source': '708-0'}),
#  Document(page_content="I'll give him a call.", metadata={'page': 709, 'chunk': 0, 'source': '709-0'}),
#  Document(page_content='Nothing from Legal.', metadata={'page': 710, 'chunk': 0, 'source': '710-0'})]

# %%
type(df_filtered_documents)
# Out:
# list

# %% [markdown]
# One of the most common ways to store and search over unstructured data is to embed it and store the resulting embedding vectors, and then at query time to embed the unstructured query and retrieve the embedding vectors that are 'most similar' to the embedded query. A vector store takes care of storing embedded data and performing vector search for you.

# %% [markdown]
# ![image.png](attachment:c9c3f90b-da18-4d96-adfc-b0a5bceb0747.png)

# %% [markdown]
# Vector stores are usually run as a separate service that requires some IO operations, and therefore they might be called asynchronously. That gives performance benefits as you don't waste time waiting for responses from external services. That might also be important if you work with an asynchronous framework, such as FastAPI.
#
# LangChain supports async operation on vector stores. All the methods might be called using their async counterparts, with the prefix a, meaning async.
#
# Qdrant is a vector store, which supports all the async operations, thus it will be used in this walkthrough.

# %%
embeddings = OpenAIEmbeddings()
new_client = chromadb.EphemeralClient()

# %%
new_client.heartbeat() # returns a nanosecond heartbeat. Useful for making sure the client remains connected.
# Out:
# 1697402286008620337

# %%
## Create a vector store 
chroma_db = Chroma.from_documents(df_filtered_documents, OpenAIEmbeddings())

# %%
chroma_db

# %%
chroma_db_2 = Chroma.from_documents(df_filtered_documents, OpenAIEmbeddings(),client=new_client, collection_name="openai_collection")

# %%
chroma_db_2

# %%
#Similarity search by vector
query='How are you?'
embedding_vector = OpenAIEmbeddings().embed_query(query)

docs = chroma_db_2.similarity_search_by_vector(embedding_vector)
print(docs[0].page_content)
# Out:
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# ?

# %%
docs
# Out:
# [Document(page_content='?', metadata={'chunk': 0, 'page': 546, 'source': '546-0'}),
#  Document(page_content='You are the best!', metadata={'chunk': 0, 'page': 695, 'source': '695-0'}),
#  Document(page_content='You are the best!', metadata={'chunk': 0, 'page': 640, 'source': '640-0'}),
#  Document(page_content='O.K.', metadata={'chunk': 0, 'page': 586, 'source': '586-0'})]

# %% [markdown]
# ### _____________________________________________________________________________
#
#
# ## Select by maximal marginal relevance (MMR)
#
#
# The MaxMarginalRelevanceExampleSelector selects examples based on a combination of which examples are most similar to the inputs, while also optimizing for diversity. It does this by finding the examples with the embeddings that have the greatest cosine similarity with the inputs, and then iteratively adding them while penalizing them for closeness to already selected examples.

# %% [markdown]
# ### Here, query is the immediate context/ the mail that needs to be replied to
#
# ### db is the vector store object which has the past emails stored as vector embeddings,
# ### we are searching for relevant documents similar query within the vector store
#
# ### found_docs are the 10 relevant emails from the past emails ranked according to their relevance

# %%
# Calculating relevance of past docs with immediate context/ email using 

query = "How have you been?"
found_docs = await chroma_db_2.amax_marginal_relevance_search(query, k=10, fetch_k=10)
for i, doc in enumerate(found_docs):
    print(f"{i + 1}.", doc.page_content, "\n")
# Out:
# 1. ?
#
# 2. Are you having our copy walked up to me?
#
# 3. Thank you.
#
# 4. Sounds like your world is a little up in the air right now. Best wishes for success in whatever you decide to do. It has been a pleasure working with you over these years! Mary G Gosnell 02/27/2001 01:28 PM
#
# 5. Tana, ? Hope you had a good weekend.? I missed your breakfast call, so I figured you had other plans.? ? I did e mail Gretchen on Friday and she sent back 2 different responses:?   "The job is still open."  &  "I did receive your resume." ? And, yesterday I received a blanket letter from Enron thanking me for my interest, etc., etc., etc. ? I know you said things move slowly around there.? What suggestions do you have at this point as to pursuing an interview  ? Any good news on your new house and/or your present one? ? ?
#
# 6. Any update yet?
#
# 7. Today.
#
# 8. Yes, I'm here finally. What a fiasco! I got here yesterday morning and no phone, computer or boxes. Karen, my assistant had put in all the work requests, and Robin had come right behind her and cancelled them. Go figure! Anyway, Robin was out yesterday and today, so Karen had to start getting everything in place for me. I got my computer at 5:00 and my phone right before lunch today. I started to call Mark and ask if I could come back. I guess eventually, it will all work out. Let's do lunch! Marie Tana Jones 04/24/00 05:28 PM
#
# 9. Nothing like a little guilt. Have you been speaking with my mother? I'll keep my fingers crossed. Thanks.
#
# 10. Yes to both questions

# %% [markdown]
# --------
# ## Adding Collections

# %%
import chromadb

persistent_client = chromadb.PersistentClient()
collection = persistent_client.get_or_create_collection("test_collection_1")
collection.add(ids=["1", "2", "3"], documents=["a", "b", "c"])

langchain_chroma = Chroma(
    client=persistent_client,
    collection_name="collection_name",
    embedding_function=OpenAIEmbeddings(),
)

print("There are", langchain_chroma._collection.count(), "in the collection")
langchain_chroma._collection.name
# Out:
# There are 3 in the collection
# 'collection_name'

# %% [markdown]
# **Client Settings**

# %%
persistent_client.heartbeat()
# Out:
# 1697401352906932847

# %%
persistent_client.list_collections()
# Out:
# [Collection(name=test_collection_1), Collection(name=collection_name)]

# %%
persistent_client.get_settings()
# Out:
# Settings(environment='', chroma_db_impl=None, chroma_api_impl='chromadb.api.segment.SegmentAPI', chroma_telemetry_impl='chromadb.telemetry.posthog.Posthog', chroma_sysdb_impl='chromadb.db.impl.sqlite.SqliteDB', chroma_producer_impl='chromadb.db.impl.sqlite.SqliteDB', chroma_consumer_impl='chromadb.db.impl.sqlite.SqliteDB', chroma_segment_manager_impl='chromadb.segment.impl.manager.local.LocalSegmentManager', chroma_segment_directory_impl='chromadb.segment.impl.manager.segment_directory.DockerComposeSegmentDirectory', tenant_id='default', topic_namespace='default', is_persistent=True, persist_directory='./chroma', chroma_server_host=None, chroma_server_headers=None, chroma_server_http_port=None, chroma_server_ssl_enabled=False, chroma_server_api_default_path='/api/v1', chroma_server_grpc_port=None, chroma_server_cors_allow_origins=[], pulsar_broker_url=None, pulsar_admin_port=None, pulsar_broker_port=None, chroma_server_auth_provider=None, chroma_server_auth_configuration_provider=None, chroma_server_auth_configuration_file=None, chroma_server_auth_credentials_provider=None, chroma_server_auth_credentials_file=None, chroma_server_auth_credentials=None, chroma_client_auth_provider=None, chroma_server_auth_ignore_paths={'/api/v1': ['GET'], '/api/v1/heartbeat': ['GET'], '/api/v1/version': ['GET']}, chroma_client_auth_credentials_provider='chromadb.auth.providers.ConfigurationClientAuthCredentialsProvider', chroma_client_auth_protocol_adapter='chromadb.auth.providers.RequestsClientAuthProtocolAdapter', chroma_client_auth_credentials_file=None, chroma_client_auth_credentials=None, chroma_client_auth_token_transport_header=None, chroma_server_auth_token_transport_header=None, anonymized_telemetry=True, allow_reset=False, migrations='apply')

# %% [markdown]
# **Collection Settings**

# %%
# Number of Embeddings Added to the Database
persistent_client.get_collection("test_collection_1").count()
# Out:
# 3

# %% [markdown]
# ----
# ## GCP Client

# %%
gcp_client = chromadb.PersistentClient(path="vector_database")

# %%
gcp_client.heartbeat()
# Out:
# 1697405316222391912

# %%
chroma_test_db = Chroma.from_documents(df_filtered_documents, OpenAIEmbeddings(),client=gcp_client, collection_name="test_1")

# %%
chroma_test_db

# %%
gcp_client.get_collection("test_1").count()
# Out:
# 727

# %%
chroma_test_db.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1
#   {'chunk': 0, 'page': 3, 'source': '3-0'},
#   {'chunk': 0, 'page': 4, 'source': '4-0'},
#   {'chunk': 0, 'page': 5, 'source': '5-0'},
#   {'chunk': 0, 'page': 6, 'source': '6-0'},
#   {'chunk': 1, 'page': 6, 'source': '6-1'},
#   {'chunk': 0, 'page': 7, 'source': '7-0'},
#   {'chunk': 0, 'page': 8, 'source': '8-0'},
#   {'chunk': 0, 'page': 9, 'source': '9-0'}],
#  'documents': ['Yes, everything.',
#   'Sharon, did one of the Canadian lawyers look at the list for the things you could not identify?',
#   'You (as usual) are the best!',
#   "Edmund Cooper is the only person that has keyword access to add legal people, credit people, companies, or change other drop downs in the database. I have key word access on this side of the Atlantic and Edmund has it there. If you need London Credit people added that aren't listed already you need to have Edmund go add them, or the company as a new key word.",
#   'Yes. "Louis Fernandez Company" <lofeco@ev1.net 04/10/2001 08:53 AM',
#   'It was a pleasure having you as a houseguest! Anytime  The current issue of Texas Monthly is only the beginning right after we announced our current earnings last week, The Wall Street Journal originated a story about a partnership our CFO invested in that made questionable statements about conflicts of interests with the shareholders, non disclosure of profits, etc., and have kept up with this story since last week, we have had shareholder lawsuits, SEC inquiries, our stock has taken a dive down to $15 today, down from $33 when the story first ran, and $87 since the beginning of the year. Right now it is beat up Enron time with no end in sight',
#   ". Anyway, you may to check the WSJ website and catch up  Also, I have a new boyfriend, my old biking buddy I mentioned we've been dating now for a few months, that seems to be going well. So that's all my news  XXOO",
#   'This will get you access to Livelink',
#   'I think yes.',
#   '1. If we have a US counterparty we insert the appropriate choice. =20 2. Revisions to the CFTC Rules have done away with the "Eligible Swap=20 Participant" rules for energy commodities (they would still apply to=20 agricultural products). The rules are still pretty similar however, and th= e=20 current lingo is now "Eligible Contract Participants". See our revised for= m,=20 attached. =09Karen A Cordova@EES =0904/04/2001 04:33 PM =09=09=20 =09=09']}

# %%
## Retrive

#Similarity search by vector
query='How are you?'
embedding_vector = OpenAIEmbeddings().embed_query(query)

rel_docs = chroma_test_db.similarity_search_by_vector(embedding_vector)
print(rel_docs[0].page_content)

rel_docs
# Out:
# ?
# [Document(page_content='?', metadata={'chunk': 0, 'page': 546, 'source': '546-0'}),
#  Document(page_content='You are the best!', metadata={'chunk': 0, 'page': 695, 'source': '695-0'}),
#  Document(page_content='You are the best!', metadata={'chunk': 0, 'page': 640, 'source': '640-0'}),
#  Document(page_content='Today.', metadata={'chunk': 0, 'page': 664, 'source': '664-0'})]

# %%
chroma_test_db_retrival = Chroma(
    client=gcp_client,
    collection_name="test_1",
    embedding_function=OpenAIEmbeddings(),
)

# %%
rel_docs_retr =chroma_test_db_retrival.similarity_search_by_vector(embedding_vector)
rel_docs_retr
# Out:
# [Document(page_content='?', metadata={'chunk': 0, 'page': 546, 'source': '546-0'}),
#  Document(page_content='You are the best!', metadata={'chunk': 0, 'page': 695, 'source': '695-0'}),
#  Document(page_content='You are the best!', metadata={'chunk': 0, 'page': 640, 'source': '640-0'}),
#  Document(page_content='Today.', metadata={'chunk': 0, 'page': 664, 'source': '664-0'})]
