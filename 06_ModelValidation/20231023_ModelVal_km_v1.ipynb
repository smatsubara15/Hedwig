# %% [markdown]
# # **Model Validation**

# %%
import openai
import os
import getpass

os.environ['OPENAI_API_KEY'] = getpass.getpass('OpenAI API Key:')
# Out:
# OpenAI API Key: ········

# %%
if 'OPENAI_API_KEY' in os.environ:
    openai_api_key = os.environ['OPENAI_API_KEY']
    print("OpenAI API Key is set")
else:
    print("OPENAI_API_KEY environment variable is not set.")

# %%
# account for deprecation of LLM model
import datetime
# Get the current date
current_date = datetime.datetime.now().date()

# Define the date after which the model should be set to "gpt-3.5-turbo"
target_date = datetime.date(2024, 6, 12)

# Set the model variable based on the current date
if current_date > target_date:
    llm_model = "gpt-3.5-turbo"
else:
    llm_model = "gpt-3.5-turbo-0301"

# %%
import pandas as pd
import numpy as np
import ast  # Import the ast module for literal evaluation
import seaborn as sns

pd.set_option('display.max_colwidth', 100)
# %pip install pandarallel
import multiprocessing

num_processors = multiprocessing.cpu_count()
print(f'Available CPUs: {num_processors}')

import pandarallel
from pandarallel import pandarallel
pandarallel.initialize(nb_workers=num_processors-1, use_memory_fs=False)
# Out:
# Available CPUs: 8
# INFO: Pandarallel will run on 7 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %% [markdown]
# -----
# ## Retrieval Dataframe

# %%
df_messages=pd.read_csv('gs://user-scripts-msca310019-capstone-49b3/data/20231009_Emails_with_Previous_as_List.csv', parse_dates=['time'])
df_messages.head(5)
# Out:
#    Unnamed: 0  Email_ID                       time   subject  thread  sender  \
# 0           0         0  1999-06-09 04:18:00-07:00  RE: test       2    5552
# 1           1         1  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 2           2         2  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 3           3         3  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 4           4         4  1999-06-09 08:06:00-07:00  RE: test       2   40034
#
#   repliers  \
# 0  [40034]
# 1   [5552]
# 2   [5552]
# 3   [5552]
# 4   [5552]
#
#                                                                                                message  \
# 0  How about this Friday ? Julie has not left yet. She was 2 days away from leaving to start school...
# 1                                                   when? how are you and your family? is julie gone?
# 2                                                   when? how are you and your family? is julie gone?
# 3                                                   when? how are you and your family? is julie gone?
# 4                                                   when? how are you and your family? is julie gone?
#
#                   reply_time  replier reply_recipient  \
# 0  1999-06-09 08:06:00-07:00    40034          [5552]
# 1  1999-06-10 03:54:00-07:00     5552         [40034]
# 2  1999-11-23 01:38:00-08:00     5552         [40034]
# 3  1999-11-23 03:13:00-08:00     5552         [40034]
# 4  1999-11-23 03:58:00-08:00     5552         [40034]
#
#                                                                             reply_message  \
# 0                                      when? how are you and your family? is julie gone?
# 1                                                Today is bad. Tommorrow I will call you.
# 2                                                          Do you have lunch plans today?
# 3  Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs.
# 4                                                            Tues.is good. I'll call you.
#
#                                                                                 Sender_Receiver_Emails
# 0                                                                                                  NaN
# 1  ['Do you have lunch plans today?', "Really? I'd feel like a mooch. Lets have lunch next week. An...
# 2  ['Today is bad. Tommorrow I will call you.', "Really? I'd feel like a mooch. Lets have lunch nex...
# 3  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Tues.is good. I'...
# 4  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Really? I'd feel...

# %%
df_messages['Sender_Receiver_Emails_list'] = df_messages['Sender_Receiver_Emails'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])

# %%
# df_messages['num_relevant_emails']=df_messages['Sender_Receiver_Emails'].apply(lambda x: len(x))
df_messages['num_relevant_emails'] = df_messages['Sender_Receiver_Emails_list'].apply(lambda x: len(x) if isinstance(x, list) else np.nan)
df_messages.head()
# Out:
#    Unnamed: 0  Email_ID                       time   subject  thread  sender  \
# 0           0         0  1999-06-09 04:18:00-07:00  RE: test       2    5552
# 1           1         1  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 2           2         2  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 3           3         3  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 4           4         4  1999-06-09 08:06:00-07:00  RE: test       2   40034
#
#   repliers  \
# 0  [40034]
# 1   [5552]
# 2   [5552]
# 3   [5552]
# 4   [5552]
#
#                                                                                                message  \
# 0  How about this Friday ? Julie has not left yet. She was 2 days away from leaving to start school...
# 1                                                   when? how are you and your family? is julie gone?
# 2                                                   when? how are you and your family? is julie gone?
# 3                                                   when? how are you and your family? is julie gone?
# 4                                                   when? how are you and your family? is julie gone?
#
#                   reply_time  replier reply_recipient  \
# 0  1999-06-09 08:06:00-07:00    40034          [5552]
# 1  1999-06-10 03:54:00-07:00     5552         [40034]
# 2  1999-11-23 01:38:00-08:00     5552         [40034]
# 3  1999-11-23 03:13:00-08:00     5552         [40034]
# 4  1999-11-23 03:58:00-08:00     5552         [40034]
#
#                                                                             reply_message  \
# 0                                      when? how are you and your family? is julie gone?
# 1                                                Today is bad. Tommorrow I will call you.
# 2                                                          Do you have lunch plans today?
# 3  Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs.
# 4                                                            Tues.is good. I'll call you.
#
#                                                                                 Sender_Receiver_Emails  \
# 0                                                                                                  NaN
# 1  ['Do you have lunch plans today?', "Really? I'd feel like a mooch. Lets have lunch next week. An...
# 2  ['Today is bad. Tommorrow I will call you.', "Really? I'd feel like a mooch. Lets have lunch nex...
# 3  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Tues.is good. I'...
# 4  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Really? I'd feel...
#
#                                                                            Sender_Receiver_Emails_list  \
# 0                                                                                                   []
# 1  [Do you have lunch plans today?, Really? I'd feel like a mooch. Lets have lunch next week. Any d...
# 2  [Today is bad. Tommorrow I will call you., Really? I'd feel like a mooch. Lets have lunch next w...
# 3  [Today is bad. Tommorrow I will call you., Do you have lunch plans today?, Tues.is good. I'll ca...
# 4  [Today is bad. Tommorrow I will call you., Do you have lunch plans today?, Really? I'd feel like...
#
#    num_relevant_emails
# 0                    0
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %%
df_messages['sender']=df_messages['sender'].astype('str')
df_messages['replier']=df_messages['replier'].astype('str')

# %%
df_messages['sender_replier_thread'] = df_messages['sender'].str.cat(df_messages['replier'], sep='-')
# df_messages['sender_receiver_thread'] = df_messages['sender_receiver_thread'].str.cat(df_messages['thread'], sep='-')

# %%
pd.set_option('display.max_colwidth', 500)
df_messages.Sender_Receiver_Emails_list.head(30)
df_messages[['sender_replier_thread','Sender_Receiver_Emails','num_relevant_emails']].iloc[15]
# Out:
# sender_replier_thread                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                37911-43
# Sender_Receiver_Emails    ['try having no work to do for two months and then having to stick around and "appear" busy  i know what you mean, in some ways its harder when you\'re not used to not doing things. i\'ve gotten good at finding things to do with my time, but when i first had nothing to do, i was going crazy. fridays are always slow around here and i\'m guessing its the same there, although i don\'t know cnrl specifcally, oil and gas producer/marketer? in terms of what i do, before enron went under, i was the...
# num_relevant_emails                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         5
# Name: 15, dtype: object

# %% [markdown]
# ### De-Duplication for Retrieval ##

# %%
df_messages_deduped=df_messages.drop_duplicates(subset='sender_replier_thread', keep='last')

# %% [markdown]
# -----
# ## Ranking Framework

# %%
# Importing Packages
import chromadb
from chromadb.utils import embedding_functions

import langchain
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain

# %%
# Setting Up Client
chroma_client = chromadb.PersistentClient(path="vectorstores")
chroma_client.heartbeat()
# Out:
# 1698106661234455844

# %%
# Defining the Embedding Function
openai_ef = embedding_functions.OpenAIEmbeddingFunction(api_key = openai_api_key,
                                                        model_name="text-embedding-ada-002")
openai_ef

# %% [markdown]
# ----
# ## Langchain Function v2

# %%
# Email Environment
sender_id='171'
replier_id='414'
sender_email='Where is my gift?'
email_dataset=df_messages_deduped
vector_db_client=chroma_client

# %%
async def get_email_response_personalized(sender_id=sender_id,
                                    replier_id=replier_id,
                                    sender_email=sender_email,
                                    email_dataset=df_messages_deduped,
                                    api_key=openai_api_key,
                                    vector_db_client=chroma_client,
                                    embedding_function=OpenAIEmbeddings()):
    
    # First getting retrieved emails to understand conversation --------
    sender_replier_id='-'.join([sender_id, replier_id])
    previous_emails=(email_dataset[email_dataset.sender_replier_thread==sender_replier_id]['Sender_Receiver_Emails_list']).to_list()[0][-10:]
    previous_emails
    # Second, getting ranked responses as per context ------------------
        
        # Building the Langchain vectorstore using chroma collections
    user_vector_store = Chroma(
        client=vector_db_client, 
        collection_name='user'+str(replier_id),
        embedding_function=OpenAIEmbeddings())
        # Getting ranked responses using MMR
    found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
    list_rel_emails=[]
    for i, doc in enumerate(found_rel_emails):
        list_rel_emails.append(doc.page_content)
    list_rel_emails
        
    # Setting up LangChain
    llm=ChatOpenAI(temperature=0.1, model=llm_model, openai_api_key=openai_api_key)
    template_string="""Create a response to the following email {sender_email}, deriving context from these relevant emails {relevant_emails} ,using a conversation style similar to following past emails between these 2 users {prev_emails}"""
    prompt_template = ChatPromptTemplate.from_template(template=template_string)    
    llm_chain=LLMChain(llm=llm, prompt=prompt_template)
    print(llm_chain.run(sender_email=sender_email, prev_emails=previous_emails, relevant_emails=list_rel_emails))

# %%
# results = await get_email_response_personalized(sender_id=sender_id,
#                                     replier_id=replier_id,
#                                     sender_email=sender_email,
#                                     email_dataset=df_messages_deduped,
#                                     api_key=openai_api_key,
#                                     vector_db_client=chroma_client,
#                                     embedding_function=OpenAIEmbeddings())
# print(results)

# %%
import pandas as pd
import ast
import chromadb
from chromadb.utils import embedding_functions
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
import asyncio

# Load the data
df_messages=pd.read_csv('gs://user-scripts-msca310019-capstone-49b3/data/20231019_Emails_with_Sender_Reply.csv', parse_dates=['time']).head()
df_messages['Sender_Receiver_Emails_list'] = df_messages['Sender_Receiver_Emails'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])
df_messages['sender'] = df_messages['sender'].astype('str')
df_messages['replier'] = df_messages['replier'].astype('str')
df_messages['sender_replier_thread'] = df_messages['sender'].str.cat(df_messages['replier'], sep='-')
df_messages_deduped = df_messages.drop_duplicates(subset='sender_replier_thread', keep='last')

# Setting up the chroma client
chroma_client = chromadb.PersistentClient(path="vectorstores")
openai_api_key = openai_api_key

async def get_email_response_personalized(sender_id, replier_id, sender_email, email_dataset, api_key, vector_db_client):    
    # First getting retrieved emails to understand conversation --------
    sender_replier_id='-'.join([sender_id, replier_id])
    previous_emails=(email_dataset[email_dataset.sender_replier_thread==sender_replier_id]['Sender_Receiver_Emails_list']).to_list()[0][-10:]
    previous_emails
    # Second, getting ranked responses as per context ------------------
        
        # Building the Langchain vectorstore using chroma collections
    user_vector_store = Chroma(
        client=vector_db_client, 
        collection_name='user'+str(replier_id),
        embedding_function=OpenAIEmbeddings())
        # Getting ranked responses using MMR
    found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
    list_rel_emails=[]
    for i, doc in enumerate(found_rel_emails):
        list_rel_emails.append(doc.page_content)
    list_rel_emails
        
    # Setting up LangChain
    llm=ChatOpenAI(temperature=0.1, model=llm_model, openai_api_key=openai_api_key)
    template_string="""You are an employee of Enron and receiver of this email: {sender_email},
    Reply to the email as the receiver,
    deriving the context from these relevant emails : {relevant_emails}
    and copying the writing style of the receiver's past emails : {prev_emails}"""
    prompt_template = ChatPromptTemplate.from_template(template=template_string)    
    llm_chain=LLMChain(llm=llm, prompt=prompt_template)
    return (llm_chain.run(sender_email=sender_email, prev_emails=previous_emails, relevant_emails=list_rel_emails))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'replier'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 16
#      14 df_messages['Sender_Receiver_Emails_list'] = df_messages['Sender_Receiver_Emails'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])
#      15 df_messages['sender'] = df_messages['sender'].astype('str')
# ---> 16 df_messages['replier'] = df_messages['replier'].astype('str')
#      17 df_messages['sender_replier_thread'] = df_messages['sender'].str.cat(df_messages['replier'], sep='-')
#      18 df_messages_deduped = df_messages.drop_duplicates(subset='sender_replier_thread', keep='last')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'replier'

# %%
async def process_all_emails(df):
    responses = []
    for index, row in df.iterrows():
        response = await get_email_response_personalized(row['sender'], row['replier'], row['message'], df, openai_api_key, chroma_client)
        responses.append(response)
        sleep(60)
    return responses

# %%
# Run the asynchronous function and get all the responses
all_responses = await process_all_emails(df_messages_deduped.head(100))

# Append the responses to the original dataframe
df_messages_deduped['responses'] = all_responses
# Out:
# Add of existing embedding ID: 0
# Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Add of existing embedding ID: 1
# Add of existing embedding ID: 2
# Add of existing embedding ID: 3
# Add of existing embedding ID: 4
# Add of existing embedding ID: 4611
# Add of existing embedding ID: 7630
# Add of existing embedding ID: 7686
# Add of existing embedding ID: 8093
# Add of existing embedding ID: 9249
# Add of existing embedding ID: 9294
# Add of existing embedding ID: 9390
# Add of existing embedding ID: 9397
# Add of existing embedding ID: 12262
# Add of existing embedding ID: 12263
# Add of existing embedding ID: 12293
# Add of existing embedding ID: 12304
# Add of existing embedding ID: 12329
# Add of existing embedding ID: 12334
# Add of existing embedding ID: 13059
# Add of existing embedding ID: 16187
# Add of existing embedding ID: 16188
# Add of existing embedding ID: 18535
# Add of existing embedding ID: 19926
# Add of existing embedding ID: 19948
# Add of existing embedding ID: 19949
# Add of existing embedding ID: 22024
# Add of existing embedding ID: 22049
# Add of existing embedding ID: 22050
# Add of existing embedding ID: 22217
# Add of existing embedding ID: 22224
# Add of existing embedding ID: 22225
# Add of existing embedding ID: 22228
# Add of existing embedding ID: 22231
# Add of existing embedding ID: 22237
# Add of existing embedding ID: 22240
# Add of existing embedding ID: 22244
# Add of existing embedding ID: 22245
# Add of existing embedding ID: 22262
# Add of existing embedding ID: 22268
# Add of existing embedding ID: 22269
# Add of existing embedding ID: 22272
# Add of existing embedding ID: 22273
# Add of existing embedding ID: 22274
# Add of existing embedding ID: 22279
# Add of existing embedding ID: 22281
# Add of existing embedding ID: 22290
# Add of existing embedding ID: 22297
# Add of existing embedding ID: 22299
# Add of existing embedding ID: 22309
# Add of existing embedding ID: 22314
# Add of existing embedding ID: 1
# Add of existing embedding ID: 2
# Add of existing embedding ID: 3
# Add of existing embedding ID: 4
# Add of existing embedding ID: 4611
# Add of existing embedding ID: 7630
# Add of existing embedding ID: 7686
# Add of existing embedding ID: 8093
# Add of existing embedding ID: 9249
# Add of existing embedding ID: 9294
# Add of existing embedding ID: 9390
# Add of existing embedding ID: 9397
# Add of existing embedding ID: 12262
# Add of existing embedding ID: 12263
# Add of existing embedding ID: 12293
# Add of existing embedding ID: 12304
# Add of existing embedding ID: 12329
# Add of existing embedding ID: 12334
# Add of existing embedding ID: 13059
# Add of existing embedding ID: 16187
# Add of existing embedding ID: 16188
# Add of existing embedding ID: 18535
# Add of existing embedding ID: 19926
# Add of existing embedding ID: 19948
# Add of existing embedding ID: 19949
# Add of existing embedding ID: 22024
# Add of existing embedding ID: 22049
# Add of existing embedding ID: 22050
# Add of existing embedding ID: 22217
# Add of existing embedding ID: 22224
# Add of existing embedding ID: 22225
# Add of existing embedding ID: 22228
# Add of existing embedding ID: 22231
# Add of existing embedding ID: 22237
# Add of existing embedding ID: 22240
# Add of existing embedding ID: 22244
# Add of existing embedding ID: 22245
# Add of existing embedding ID: 22262
# Add of existing embedding ID: 22268
# Add of existing embedding ID: 22269
# Add of existing embedding ID: 22272
# Add of existing embedding ID: 22273
# Add of existing embedding ID: 22274
# Add of existing embedding ID: 22279
# Add of existing embedding ID: 22281
# Add of existing embedding ID: 22290
# Add of existing embedding ID: 22297
# Add of existing embedding ID: 22299
# Add of existing embedding ID: 22309
# Add of existing embedding ID: 22314
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 8.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 8.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 8.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 8.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 8.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Add of existing embedding ID: 60
# Add of existing embedding ID: 81
# Add of existing embedding ID: 96
# Add of existing embedding ID: 233
# Add of existing embedding ID: 2849
# Add of existing embedding ID: 3653
# Add of existing embedding ID: 3656
# Add of existing embedding ID: 3692
# Add of existing embedding ID: 3730
# Add of existing embedding ID: 3781
# Add of existing embedding ID: 3783
# Add of existing embedding ID: 3863
# Add of existing embedding ID: 3875
# Add of existing embedding ID: 3998
# Add of existing embedding ID: 4022
# Add of existing embedding ID: 4356
# Add of existing embedding ID: 4358
# Add of existing embedding ID: 4376
# Add of existing embedding ID: 4885
# Add of existing embedding ID: 5351
# Add of existing embedding ID: 6237
# Add of existing embedding ID: 6239
# Add of existing embedding ID: 6254
# Add of existing embedding ID: 6508
# Add of existing embedding ID: 6510
# Add of existing embedding ID: 6573
# Add of existing embedding ID: 6786
# Add of existing embedding ID: 9279
# Add of existing embedding ID: 9293
# Add of existing embedding ID: 9500
# Add of existing embedding ID: 9636
# Add of existing embedding ID: 9856
# Add of existing embedding ID: 10392
# Add of existing embedding ID: 10555
# Add of existing embedding ID: 11483
# Add of existing embedding ID: 11485
# Add of existing embedding ID: 11640
# Add of existing embedding ID: 12008
# Add of existing embedding ID: 12205
# Add of existing embedding ID: 12230
# Add of existing embedding ID: 12231
# Add of existing embedding ID: 12232
# Add of existing embedding ID: 12234
# Add of existing embedding ID: 12235
# Add of existing embedding ID: 12237
# Add of existing embedding ID: 12295
# Add of existing embedding ID: 12704
# Add of existing embedding ID: 12708
# Add of existing embedding ID: 12710
# Add of existing embedding ID: 12712
# Add of existing embedding ID: 12713
# Add of existing embedding ID: 12714
# Add of existing embedding ID: 12721
# Add of existing embedding ID: 12725
# Add of existing embedding ID: 12783
# Add of existing embedding ID: 12814
# Add of existing embedding ID: 12816
# Add of existing embedding ID: 12819
# Add of existing embedding ID: 12847
# Add of existing embedding ID: 12848
# Add of existing embedding ID: 12851
# Add of existing embedding ID: 12853
# Add of existing embedding ID: 12854
# Add of existing embedding ID: 12862
# Add of existing embedding ID: 12875
# Add of existing embedding ID: 12899
# Add of existing embedding ID: 12901
# Add of existing embedding ID: 12903
# Add of existing embedding ID: 12905
# Add of existing embedding ID: 12921
# Add of existing embedding ID: 12933
# Add of existing embedding ID: 13055
# Add of existing embedding ID: 13116
# Add of existing embedding ID: 13520
# Add of existing embedding ID: 13627
# Add of existing embedding ID: 13694
# Add of existing embedding ID: 13727
# Add of existing embedding ID: 13792
# Add of existing embedding ID: 13795
# Add of existing embedding ID: 13802
# Add of existing embedding ID: 13829
# Add of existing embedding ID: 13842
# Add of existing embedding ID: 13845
# Add of existing embedding ID: 13934
# Add of existing embedding ID: 13936
# Add of existing embedding ID: 13947
# Add of existing embedding ID: 13949
# Add of existing embedding ID: 13951
# Add of existing embedding ID: 13997
# Add of existing embedding ID: 14136
# Add of existing embedding ID: 14169
# Add of existing embedding ID: 14170
# Add of existing embedding ID: 14171
# Add of existing embedding ID: 14174
# Add of existing embedding ID: 14181
# Add of existing embedding ID: 14193
# Add of existing embedding ID: 14265
# Add of existing embedding ID: 14288
# Add of existing embedding ID: 14330
# Add of existing embedding ID: 14353
# Add of existing embedding ID: 14373
# Add of existing embedding ID: 14415
# Add of existing embedding ID: 14439
# Add of existing embedding ID: 14450
# Add of existing embedding ID: 14468
# Add of existing embedding ID: 14503
# Add of existing embedding ID: 14505
# Add of existing embedding ID: 14563
# Add of existing embedding ID: 14588
# Add of existing embedding ID: 14596
# Add of existing embedding ID: 14627
# Add of existing embedding ID: 14662
# Add of existing embedding ID: 14692
# Add of existing embedding ID: 14693
# Add of existing embedding ID: 14729
# Add of existing embedding ID: 14780
# Add of existing embedding ID: 14871
# Add of existing embedding ID: 14965
# Add of existing embedding ID: 14969
# Add of existing embedding ID: 15022
# Add of existing embedding ID: 15023
# Add of existing embedding ID: 15042
# Add of existing embedding ID: 15047
# Add of existing embedding ID: 15052
# Add of existing embedding ID: 15082
# Add of existing embedding ID: 15133
# Add of existing embedding ID: 15146
# Add of existing embedding ID: 15147
# Add of existing embedding ID: 15148
# Add of existing embedding ID: 15173
# Add of existing embedding ID: 15195
# Add of existing embedding ID: 15662
# Add of existing embedding ID: 16777
# Add of existing embedding ID: 16783
# Add of existing embedding ID: 17619
# Add of existing embedding ID: 18527
# Add of existing embedding ID: 20684
# Add of existing embedding ID: 21326
# Add of existing embedding ID: 21592
# Add of existing embedding ID: 22671
# Add of existing embedding ID: 22673
# Add of existing embedding ID: 22674
# Add of existing embedding ID: 22676
# Add of existing embedding ID: 22678
# Add of existing embedding ID: 22682
# Add of existing embedding ID: 22685
# Add of existing embedding ID: 22687
# Add of existing embedding ID: 22689
# Add of existing embedding ID: 22692
# Add of existing embedding ID: 22693
# Add of existing embedding ID: 22696
# Add of existing embedding ID: 22699
# Add of existing embedding ID: 22701
# Add of existing embedding ID: 22705
# Add of existing embedding ID: 22706
# Add of existing embedding ID: 22712
# Add of existing embedding ID: 22716
# Add of existing embedding ID: 22720
# Add of existing embedding ID: 22722
# Add of existing embedding ID: 22729
# Add of existing embedding ID: 22732
# Add of existing embedding ID: 22734
# Add of existing embedding ID: 22735
# Add of existing embedding ID: 22737
# Add of existing embedding ID: 22744
# Add of existing embedding ID: 22746
# Add of existing embedding ID: 22750
# Add of existing embedding ID: 22751
# Add of existing embedding ID: 22753
# Add of existing embedding ID: 22755
# Add of existing embedding ID: 22756
# Add of existing embedding ID: 22757
# Add of existing embedding ID: 22758
# Add of existing embedding ID: 22760
# Add of existing embedding ID: 22765
# Add of existing embedding ID: 22768
# Add of existing embedding ID: 22769
# Add of existing embedding ID: 22771
# Add of existing embedding ID: 22773
# Add of existing embedding ID: 22777
# Add of existing embedding ID: 22778
# Add of existing embedding ID: 22779
# Add of existing embedding ID: 22780
# Add of existing embedding ID: 22782
# Add of existing embedding ID: 22783
# Add of existing embedding ID: 22786
# Add of existing embedding ID: 22787
# Add of existing embedding ID: 22792
# Add of existing embedding ID: 22795
# Add of existing embedding ID: 22798
# Add of existing embedding ID: 22799
# Add of existing embedding ID: 22800
# Add of existing embedding ID: 22803
# Add of existing embedding ID: 22806
# Add of existing embedding ID: 22808
# Add of existing embedding ID: 22815
# Add of existing embedding ID: 22816
# Add of existing embedding ID: 22821
# Add of existing embedding ID: 22828
# Add of existing embedding ID: 22830
# Add of existing embedding ID: 22834
# Add of existing embedding ID: 22837
# Add of existing embedding ID: 22838
# Add of existing embedding ID: 22842
# Add of existing embedding ID: 22843
# Add of existing embedding ID: 22845
# Add of existing embedding ID: 22846
# Add of existing embedding ID: 22847
# Add of existing embedding ID: 22848
# Add of existing embedding ID: 22849
# Add of existing embedding ID: 22855
# Add of existing embedding ID: 22859
# Add of existing embedding ID: 22861
# Add of existing embedding ID: 22863
# Add of existing embedding ID: 22865
# Add of existing embedding ID: 22867
# Add of existing embedding ID: 22869
# Add of existing embedding ID: 22870
# Add of existing embedding ID: 22871
# Add of existing embedding ID: 22877
# Add of existing embedding ID: 22879
# Add of existing embedding ID: 22884
# Add of existing embedding ID: 22888
# Add of existing embedding ID: 22890
# Add of existing embedding ID: 22897
# Add of existing embedding ID: 22899
# Add of existing embedding ID: 22900
# Add of existing embedding ID: 22912
# Add of existing embedding ID: 22918
# Add of existing embedding ID: 22919
# Add of existing embedding ID: 22920
# Add of existing embedding ID: 22921
# Add of existing embedding ID: 22922
# Add of existing embedding ID: 22923
# Add of existing embedding ID: 22929
# Add of existing embedding ID: 22936
# Add of existing embedding ID: 22938
# Add of existing embedding ID: 22941
# Add of existing embedding ID: 22943
# Add of existing embedding ID: 22948
# Add of existing embedding ID: 22954
# Add of existing embedding ID: 22956
# Add of existing embedding ID: 22958
# Add of existing embedding ID: 22962
# Add of existing embedding ID: 22972
# Add of existing embedding ID: 22978
# Add of existing embedding ID: 22984
# Add of existing embedding ID: 22985
# Add of existing embedding ID: 22986
# Add of existing embedding ID: 22987
# Add of existing embedding ID: 22990
# Add of existing embedding ID: 22991
# Add of existing embedding ID: 22995
# Add of existing embedding ID: 22997
# Add of existing embedding ID: 23000
# Add of existing embedding ID: 23001
# Add of existing embedding ID: 23002
# Add of existing embedding ID: 23005
# Add of existing embedding ID: 23012
# Add of existing embedding ID: 23015
# Add of existing embedding ID: 23019
# Add of existing embedding ID: 23020
# Add of existing embedding ID: 23022
# Add of existing embedding ID: 23029
# Add of existing embedding ID: 23032
# Add of existing embedding ID: 23036
# Add of existing embedding ID: 23037
# Add of existing embedding ID: 23043
# Add of existing embedding ID: 23044
# Add of existing embedding ID: 23045
# Add of existing embedding ID: 23048
# Add of existing embedding ID: 23053
# Add of existing embedding ID: 23058
# Add of existing embedding ID: 23060
# Add of existing embedding ID: 23065
# Add of existing embedding ID: 23080
# Add of existing embedding ID: 23081
# Add of existing embedding ID: 23085
# Add of existing embedding ID: 23093
# Add of existing embedding ID: 23096
# Add of existing embedding ID: 23097
# Add of existing embedding ID: 23117
# Add of existing embedding ID: 23119
# Add of existing embedding ID: 23122
# Add of existing embedding ID: 23125
# Add of existing embedding ID: 23126
# Add of existing embedding ID: 23129
# Add of existing embedding ID: 23133
# Add of existing embedding ID: 23136
# Add of existing embedding ID: 23146
# Add of existing embedding ID: 23151
# Add of existing embedding ID: 23157
# Add of existing embedding ID: 23162
# Add of existing embedding ID: 23164
# Add of existing embedding ID: 23168
# Add of existing embedding ID: 23171
# Add of existing embedding ID: 23173
# Add of existing embedding ID: 23174
# Add of existing embedding ID: 23184
# Add of existing embedding ID: 23185
# Add of existing embedding ID: 23191
# Add of existing embedding ID: 23199
# Add of existing embedding ID: 23202
# Add of existing embedding ID: 23206
# Add of existing embedding ID: 23207
# Add of existing embedding ID: 23210
# Add of existing embedding ID: 23212
# Add of existing embedding ID: 23213
# Add of existing embedding ID: 23216
# Add of existing embedding ID: 23219
# Add of existing embedding ID: 23220
# Add of existing embedding ID: 23224
# Add of existing embedding ID: 23225
# Add of existing embedding ID: 23226
# Add of existing embedding ID: 23229
# Add of existing embedding ID: 23231
# Add of existing embedding ID: 23234
# Add of existing embedding ID: 23243
# Add of existing embedding ID: 23245
# Add of existing embedding ID: 23247
# Add of existing embedding ID: 23249
# Add of existing embedding ID: 23250
# Add of existing embedding ID: 23252
# Add of existing embedding ID: 23253
# Add of existing embedding ID: 23261
# Add of existing embedding ID: 23264
# Add of existing embedding ID: 23268
# Add of existing embedding ID: 23271
# Add of existing embedding ID: 23273
# Add of existing embedding ID: 23274
# Add of existing embedding ID: 23284
# Add of existing embedding ID: 23295
# Add of existing embedding ID: 23306
# Add of existing embedding ID: 23318
# Add of existing embedding ID: 23320
# Add of existing embedding ID: 23323
# Add of existing embedding ID: 23324
# Add of existing embedding ID: 23325
# Add of existing embedding ID: 23334
# Add of existing embedding ID: 23336
# Add of existing embedding ID: 23340
# Add of existing embedding ID: 23341
# Add of existing embedding ID: 23345
# Add of existing embedding ID: 23346
# Add of existing embedding ID: 23347
# Add of existing embedding ID: 23353
# Add of existing embedding ID: 23361
# Add of existing embedding ID: 23362
# Add of existing embedding ID: 23365
# Add of existing embedding ID: 23372
# Add of existing embedding ID: 23374
# Add of existing embedding ID: 23376
# Add of existing embedding ID: 23384
# Add of existing embedding ID: 23386
# Add of existing embedding ID: 23395
# Add of existing embedding ID: 23399
# Add of existing embedding ID: 23400
# Add of existing embedding ID: 23412
# Add of existing embedding ID: 23413
# Add of existing embedding ID: 23414
# Add of existing embedding ID: 23419
# Add of existing embedding ID: 23420
# Add of existing embedding ID: 23421
# Add of existing embedding ID: 23422
# Add of existing embedding ID: 23423
# Add of existing embedding ID: 23425
# Add of existing embedding ID: 23428
# Add of existing embedding ID: 23430
# Add of existing embedding ID: 23431
# Add of existing embedding ID: 23435
# Add of existing embedding ID: 23436
# Add of existing embedding ID: 23438
# Add of existing embedding ID: 23439
# Add of existing embedding ID: 23448
# Add of existing embedding ID: 23450
# Add of existing embedding ID: 23452
# Add of existing embedding ID: 23456
# Add of existing embedding ID: 23457
# Add of existing embedding ID: 23458
# Add of existing embedding ID: 23461
# Add of existing embedding ID: 23464
# Add of existing embedding ID: 23466
# Add of existing embedding ID: 23467
# Add of existing embedding ID: 23475
# Add of existing embedding ID: 23480
# Add of existing embedding ID: 23486
# Add of existing embedding ID: 23488
# Add of existing embedding ID: 23490
# Add of existing embedding ID: 23492
# Add of existing embedding ID: 23496
# Add of existing embedding ID: 23501
# Add of existing embedding ID: 23504
# Add of existing embedding ID: 23507
# Add of existing embedding ID: 23509
# Add of existing embedding ID: 23511
# Add of existing embedding ID: 23512
# Add of existing embedding ID: 23513
# Add of existing embedding ID: 23519
# Add of existing embedding ID: 23520
# Add of existing embedding ID: 23522
# Add of existing embedding ID: 23524
# Add of existing embedding ID: 23525
# Add of existing embedding ID: 23535
# Add of existing embedding ID: 23539
# Add of existing embedding ID: 23546
# Add of existing embedding ID: 23548
# Add of existing embedding ID: 23549
# Add of existing embedding ID: 23550
# Add of existing embedding ID: 23553
# Add of existing embedding ID: 23554
# Add of existing embedding ID: 23556
# Add of existing embedding ID: 23557
# Add of existing embedding ID: 23558
# Add of existing embedding ID: 23559
# Add of existing embedding ID: 23563
# Add of existing embedding ID: 23565
# Add of existing embedding ID: 23569
# Add of existing embedding ID: 23573
# Add of existing embedding ID: 23577
# Add of existing embedding ID: 23580
# Add of existing embedding ID: 23582
# Add of existing embedding ID: 23585
# Add of existing embedding ID: 23586
# Add of existing embedding ID: 23588
# Add of existing embedding ID: 23591
# Add of existing embedding ID: 23592
# Add of existing embedding ID: 23594
# Add of existing embedding ID: 23597
# Add of existing embedding ID: 23600
# Add of existing embedding ID: 23610
# Add of existing embedding ID: 23612
# Add of existing embedding ID: 23614
# Add of existing embedding ID: 23616
# Add of existing embedding ID: 23617
# Add of existing embedding ID: 23618
# Add of existing embedding ID: 23620
# Add of existing embedding ID: 23624
# Add of existing embedding ID: 23629
# Add of existing embedding ID: 23632
# Add of existing embedding ID: 23633
# Add of existing embedding ID: 23637
# Add of existing embedding ID: 23639
# Add of existing embedding ID: 23640
# Add of existing embedding ID: 23642
# Add of existing embedding ID: 23646
# Add of existing embedding ID: 23648
# Add of existing embedding ID: 23653
# Add of existing embedding ID: 23655
# Add of existing embedding ID: 23657
# Add of existing embedding ID: 23659
# Add of existing embedding ID: 23660
# Add of existing embedding ID: 23661
# Add of existing embedding ID: 23665
# Add of existing embedding ID: 23667
# Add of existing embedding ID: 23668
# Add of existing embedding ID: 23672
# Add of existing embedding ID: 23676
# Add of existing embedding ID: 23678
# Add of existing embedding ID: 23680
# Add of existing embedding ID: 23683
# Add of existing embedding ID: 23684
# Add of existing embedding ID: 23687
# Add of existing embedding ID: 23689
# Add of existing embedding ID: 23693
# Add of existing embedding ID: 23695
# Add of existing embedding ID: 23699
# Add of existing embedding ID: 23701
# Add of existing embedding ID: 23703
# Add of existing embedding ID: 23708
# Add of existing embedding ID: 23709
# ...
# Add of existing embedding ID: 8515
# Add of existing embedding ID: 8518
# Add of existing embedding ID: 8519
# Add of existing embedding ID: 8521
# Add of existing embedding ID: 8522
# Add of existing embedding ID: 8523
# Add of existing embedding ID: 8524
# Add of existing embedding ID: 8525
# Add of existing embedding ID: 8526
# Add of existing embedding ID: 8527
# Add of existing embedding ID: 8528
# Add of existing embedding ID: 8529
# Add of existing embedding ID: 8530
# Add of existing embedding ID: 8531
# Add of existing embedding ID: 8537
# Add of existing embedding ID: 8538
# Add of existing embedding ID: 8540
# Add of existing embedding ID: 8544
# Add of existing embedding ID: 8548
# Add of existing embedding ID: 8549
# Add of existing embedding ID: 8550
# Add of existing embedding ID: 8552
# Add of existing embedding ID: 8553
# Add of existing embedding ID: 8555
# Add of existing embedding ID: 8561
# Add of existing embedding ID: 8563
# Add of existing embedding ID: 8564
# Add of existing embedding ID: 8566
# Add of existing embedding ID: 8569
# Add of existing embedding ID: 8570
# Add of existing embedding ID: 8571
# Add of existing embedding ID: 8575
# Add of existing embedding ID: 8577
# Add of existing embedding ID: 8578
# Add of existing embedding ID: 8583
# Add of existing embedding ID: 8585
# Add of existing embedding ID: 8589
# Add of existing embedding ID: 8590
# Add of existing embedding ID: 8594
# Add of existing embedding ID: 8596
# Add of existing embedding ID: 8598
# Add of existing embedding ID: 8600
# Add of existing embedding ID: 8602
# Add of existing embedding ID: 8603
# Add of existing embedding ID: 8604
# Add of existing embedding ID: 8606
# Add of existing embedding ID: 8607
# Add of existing embedding ID: 8610
# Add of existing embedding ID: 8611
# Add of existing embedding ID: 8612
# Add of existing embedding ID: 8614
# Add of existing embedding ID: 8615
# Add of existing embedding ID: 8616
# Add of existing embedding ID: 8618
# Add of existing embedding ID: 8620
# Add of existing embedding ID: 8622
# Add of existing embedding ID: 8623
# Add of existing embedding ID: 8624
# Add of existing embedding ID: 8625
# Add of existing embedding ID: 8626
# Add of existing embedding ID: 8628
# Add of existing embedding ID: 8630
# Add of existing embedding ID: 8632
# Add of existing embedding ID: 8634
# Add of existing embedding ID: 8635
# Add of existing embedding ID: 8636
# Add of existing embedding ID: 8637
# Add of existing embedding ID: 8638
# Add of existing embedding ID: 8639
# Add of existing embedding ID: 8640
# Add of existing embedding ID: 8642
# Add of existing embedding ID: 8644
# Add of existing embedding ID: 8646
# Add of existing embedding ID: 8648
# Add of existing embedding ID: 8650
# Add of existing embedding ID: 8651
# Add of existing embedding ID: 8653
# Add of existing embedding ID: 8654
# Add of existing embedding ID: 8660
# Add of existing embedding ID: 8661
# Add of existing embedding ID: 8668
# Add of existing embedding ID: 8671
# Add of existing embedding ID: 8673
# Add of existing embedding ID: 8677
# Add of existing embedding ID: 8678
# Add of existing embedding ID: 8683
# Add of existing embedding ID: 8688
# Add of existing embedding ID: 8689
# Add of existing embedding ID: 8690
# Add of existing embedding ID: 8693
# Add of existing embedding ID: 8695
# Add of existing embedding ID: 8697
# Add of existing embedding ID: 8699
# Add of existing embedding ID: 8706
# Add of existing embedding ID: 8715
# Add of existing embedding ID: 8716
# Add of existing embedding ID: 8718
# Add of existing embedding ID: 8720
# Add of existing embedding ID: 8723
# Add of existing embedding ID: 8730
# Add of existing embedding ID: 8732
# Add of existing embedding ID: 8734
# Add of existing embedding ID: 8736
# Add of existing embedding ID: 8746
# Add of existing embedding ID: 8751
# Add of existing embedding ID: 8754
# Add of existing embedding ID: 8757
# Add of existing embedding ID: 8758
# Add of existing embedding ID: 8762
# Add of existing embedding ID: 8765
# Add of existing embedding ID: 8767
# Add of existing embedding ID: 8769
# Add of existing embedding ID: 8771
# Add of existing embedding ID: 8776
# Add of existing embedding ID: 8782
# Add of existing embedding ID: 8783
# Add of existing embedding ID: 8785
# Add of existing embedding ID: 8787
# Add of existing embedding ID: 8789
# Add of existing embedding ID: 8792
# Add of existing embedding ID: 8794
# Add of existing embedding ID: 8797
# Add of existing embedding ID: 8799
# Add of existing embedding ID: 8801
# Add of existing embedding ID: 8802
# Add of existing embedding ID: 8805
# Add of existing embedding ID: 8806
# Add of existing embedding ID: 8807
# Add of existing embedding ID: 8808
# Add of existing embedding ID: 8810
# Add of existing embedding ID: 8811
# Add of existing embedding ID: 8812
# Add of existing embedding ID: 8813
# Add of existing embedding ID: 8815
# Add of existing embedding ID: 8816
# Add of existing embedding ID: 8821
# Add of existing embedding ID: 8824
# Add of existing embedding ID: 8826
# Add of existing embedding ID: 8828
# Add of existing embedding ID: 8830
# Add of existing embedding ID: 8832
# Add of existing embedding ID: 8833
# Add of existing embedding ID: 8835
# Add of existing embedding ID: 8836
# Add of existing embedding ID: 8837
# Add of existing embedding ID: 8838
# Add of existing embedding ID: 8843
# Add of existing embedding ID: 8847
# Add of existing embedding ID: 8848
# Add of existing embedding ID: 8850
# Add of existing embedding ID: 8852
# Add of existing embedding ID: 8853
# Add of existing embedding ID: 8856
# Add of existing embedding ID: 8858
# Add of existing embedding ID: 8860
# Add of existing embedding ID: 8861
# Add of existing embedding ID: 8863
# Add of existing embedding ID: 8864
# Add of existing embedding ID: 8865
# Add of existing embedding ID: 8871
# Add of existing embedding ID: 8872
# Add of existing embedding ID: 8877
# Add of existing embedding ID: 8878
# Add of existing embedding ID: 8885
# Add of existing embedding ID: 8891
# Add of existing embedding ID: 8892
# Add of existing embedding ID: 8919
# Add of existing embedding ID: 8929
# Add of existing embedding ID: 8931
# Add of existing embedding ID: 8932
# Add of existing embedding ID: 8934
# Add of existing embedding ID: 8935
# Add of existing embedding ID: 8937
# Add of existing embedding ID: 8938
# Add of existing embedding ID: 8939
# Add of existing embedding ID: 8940
# Add of existing embedding ID: 8941
# Add of existing embedding ID: 8942
# Add of existing embedding ID: 8944
# Add of existing embedding ID: 8946
# Add of existing embedding ID: 8947
# Add of existing embedding ID: 8949
# Add of existing embedding ID: 8951
# Add of existing embedding ID: 8953
# Add of existing embedding ID: 8954
# Add of existing embedding ID: 8956
# Add of existing embedding ID: 8958
# Add of existing embedding ID: 8960
# Add of existing embedding ID: 8961
# Add of existing embedding ID: 8963
# Add of existing embedding ID: 8966
# Add of existing embedding ID: 8968
# Add of existing embedding ID: 8969
# Add of existing embedding ID: 8970
# Add of existing embedding ID: 8976
# Add of existing embedding ID: 8977
# Add of existing embedding ID: 8981
# Add of existing embedding ID: 8982
# Add of existing embedding ID: 8984
# Add of existing embedding ID: 8985
# Add of existing embedding ID: 8988
# Add of existing embedding ID: 8989
# Add of existing embedding ID: 8990
# Add of existing embedding ID: 8992
# Add of existing embedding ID: 8994
# Add of existing embedding ID: 8996
# Add of existing embedding ID: 8997
# Add of existing embedding ID: 8998
# Add of existing embedding ID: 9000
# Add of existing embedding ID: 9002
# Add of existing embedding ID: 9004
# Add of existing embedding ID: 9006
# Add of existing embedding ID: 9013
# Add of existing embedding ID: 9016
# Add of existing embedding ID: 9019
# Add of existing embedding ID: 9020
# Add of existing embedding ID: 9022
# Add of existing embedding ID: 9023
# Add of existing embedding ID: 9024
# Add of existing embedding ID: 9026
# Add of existing embedding ID: 9028
# Add of existing embedding ID: 9029
# Add of existing embedding ID: 9031
# Add of existing embedding ID: 9032
# Add of existing embedding ID: 9033
# Add of existing embedding ID: 9034
# Add of existing embedding ID: 9038
# Add of existing embedding ID: 9041
# Add of existing embedding ID: 9042
# Add of existing embedding ID: 9043
# Add of existing embedding ID: 9045
# Add of existing embedding ID: 9046
# Add of existing embedding ID: 9049
# Add of existing embedding ID: 9053
# Add of existing embedding ID: 9054
# Add of existing embedding ID: 9057
# Add of existing embedding ID: 9058
# Add of existing embedding ID: 9059
# Add of existing embedding ID: 9063
# Add of existing embedding ID: 9066
# Add of existing embedding ID: 9070
# Add of existing embedding ID: 9072
# Add of existing embedding ID: 9073
# Add of existing embedding ID: 9075
# Add of existing embedding ID: 9076
# Add of existing embedding ID: 9081
# Add of existing embedding ID: 9083
# Add of existing embedding ID: 9084
# Add of existing embedding ID: 23922
# Add of existing embedding ID: 24380
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 8.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for gpt-3.5-turbo-0301 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Run the asynchronous function and get all the responses
# ----> 2 all_responses = await process_all_emails(df_messages_deduped.head(100))
#       4 # Append the responses to the original dataframe
#       5 df_messages_deduped['responses'] = all_responses
#
# Cell In[23], line 4, in process_all_emails(df)
#       2 responses = []
#       3 for index, row in df.iterrows():
# ----> 4     response = await get_email_response_personalized(row['sender'], row['replier'], row['message'], df, openai_api_key, chroma_client)
#       5     responses.append(response)
#       6 return responses
#
# Cell In[22], line 37, in get_email_response_personalized(sender_id, replier_id, sender_email, email_dataset, api_key, vector_db_client)
#      32 user_vector_store = Chroma(
#      33     client=vector_db_client,
#      34     collection_name='user'+str(replier_id),
#      35     embedding_function=OpenAIEmbeddings())
#      36     # Getting ranked responses using MMR
# ---> 37 found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
#      38 list_rel_emails=[]
#      39 for i, doc in enumerate(found_rel_emails):
#
# File /opt/conda/lib/python3.10/site-packages/langchain/schema/vectorstore.py:389, in VectorStore.amax_marginal_relevance_search(self, query, k, fetch_k, lambda_mult, **kwargs)
#     378 # This is a temporary workaround to make the similarity search
#     379 # asynchronous. The proper solution is to make the similarity search
#     380 # asynchronous in the vector store implementations.
#     381 func = partial(
#     382     self.max_marginal_relevance_search,
#     383     query,
#    (...)
#     387     **kwargs,
#     388 )
# --> 389 return await asyncio.get_event_loop().run_in_executor(None, func)
#
# CancelledError:

# %%
df_messages_deduped
# Out:
#    Unnamed: 0  Email_ID                       time   subject  thread sender  \
# 0           0         0  1999-06-09 04:18:00-07:00  RE: test       2   5552
# 4           4         4  1999-06-09 08:06:00-07:00  RE: test       2  40034
#
#   repliers  \
# 0  [40034]
# 4   [5552]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                               message  \
# 0  How about this Friday ? Julie has not left yet. She was 2 days away from leaving to start school on June 7th when she, quite by accident, looked at the school schedule for the first time in several weeks. Now mind you she had lined up a babysitter ,lined up a place to stay, arranged to get a key to start the 7th. The schedule says the school starts the 14th. Pretty funny. How many years will it take her to live this down?. Enron Capital & Trade Resources Corp.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                  when? how are you and your family? is julie gone?
#
#                   reply_time replier reply_recipient  \
# 0  1999-06-09 08:06:00-07:00   40034          [5552]
# 4  1999-11-23 03:58:00-08:00    5552         [40034]
#
#                                         reply_message  \
# 0  when? how are you and your family? is julie gone?
# 4                        Tues.is good. I'll call you.
#
#                                                                                                                                                      Sender_Receiver_Emails  \
# 0                                                                                                                                                                       NaN
# 4  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs."]
#
#                                                                                                                                           Sender_Receiver_Emails_list  \
# 0                                                                                                                                                                  []
# 4  [Today is bad. Tommorrow I will call you., Do you have lunch plans today?, Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs.]
#
#   sender_replier_thread  \
# 0            5552-40034
# 4            40034-5552
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              responses
# 0  Hey there!\n\nThanks for reaching out. How about this Friday for what exactly? Sorry, I'm a bit confused.\n\nMy family and I are doing well, thanks for asking. Is Julie still around? I heard about her school schedule mishap, that's quite funny. I'm sure she'll be able to laugh about it eventually.\n\nTake care!\n\n[Previous emails between the two users:\n\nUser 1: Hey, are you free this weekend?\n\nUser 2: Hey! Yeah, I should be. What's up?\n\nUser 1: Just wanted to catch up and maybe grab l...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                     Thanks for asking, we're doing well. Julie is no longer with us.
