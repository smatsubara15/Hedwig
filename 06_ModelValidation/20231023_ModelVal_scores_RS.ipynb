# %% [markdown]
# # **Model Validation**

# %%
import openai
import os
import getpass

os.environ['OPENAI_API_KEY'] = getpass.getpass('OpenAI API Key:')
# Out:
# OpenAI API Key: ········

# %%
if 'OPENAI_API_KEY' in os.environ:
    openai_api_key = os.environ['OPENAI_API_KEY']
    print("OpenAI API Key is set")
else:
    print("OPENAI_API_KEY environment variable is not set.")
# Out:
# OpenAI API Key is set

# %%
# account for deprecation of LLM model
import datetime
# Get the current date
current_date = datetime.datetime.now().date()

# Define the date after which the model should be set to "gpt-3.5-turbo"
target_date = datetime.date(2024, 6, 12)

# Set the model variable based on the current date
if current_date > target_date:
    llm_model = "gpt-3.5-turbo"
else:
    llm_model = "gpt-3.5-turbo-0301"

# %%
import pandas as pd
import numpy as np
import ast  # Import the ast module for literal evaluation
import seaborn as sns

pd.set_option('display.max_colwidth', 100)
# %pip install pandarallel
import multiprocessing

num_processors = multiprocessing.cpu_count()
print(f'Available CPUs: {num_processors}')

import pandarallel
from pandarallel import pandarallel
pandarallel.initialize(nb_workers=num_processors-1, use_memory_fs=False)
# Out:
# Available CPUs: 8
# INFO: Pandarallel will run on 7 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %% [markdown]
# -----
# ## Retrieval Dataframe

# %%
df_messages=pd.read_csv('gs://user-scripts-msca310019-capstone-49b3/data/20231019_Emails_with_Sender_Reply.csv', parse_dates=['time'])
df_messages.head(5)
# Out:
#    Unnamed: 0  Email_ID                       time   subject  thread  sender  \
# 0           0         0  1999-06-09 04:18:00-07:00  RE: test       2    5552
# 1           1         1  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 2           2         2  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 3           3         3  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 4           4         4  1999-06-09 08:06:00-07:00  RE: test       2   40034
#
#   recipient  \
# 0   [40034]
# 1    [5552]
# 2    [5552]
# 3    [5552]
# 4    [5552]
#
#                                                                                                message  \
# 0  How about this Friday ? Julie has not left yet. She was 2 days away from leaving to start school...
# 1                                                   when? how are you and your family? is julie gone?
# 2                                                   when? how are you and your family? is julie gone?
# 3                                                   when? how are you and your family? is julie gone?
# 4                                                   when? how are you and your family? is julie gone?
#
#                   reply_time  reply_sender reply_recipient  \
# 0  1999-06-09 08:06:00-07:00         40034          [5552]
# 1  1999-06-10 03:54:00-07:00          5552         [40034]
# 2  1999-11-23 01:38:00-08:00          5552         [40034]
# 3  1999-11-23 03:13:00-08:00          5552         [40034]
# 4  1999-11-23 03:58:00-08:00          5552         [40034]
#
#                                                                             reply_message  \
# 0                                      when? how are you and your family? is julie gone?
# 1                                                Today is bad. Tommorrow I will call you.
# 2                                                          Do you have lunch plans today?
# 3  Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs.
# 4                                                            Tues.is good. I'll call you.
#
#                                                                                 Sender_Receiver_Emails
# 0                                                                                                  NaN
# 1  ['Do you have lunch plans today?', "Really? I'd feel like a mooch. Lets have lunch next week. An...
# 2  ['Today is bad. Tommorrow I will call you.', "Really? I'd feel like a mooch. Lets have lunch nex...
# 3  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Tues.is good. I'...
# 4  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Really? I'd feel...

# %%
df_messages['Sender_Receiver_Emails_list'] = df_messages['Sender_Receiver_Emails'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])

# %%
# df_messages['num_relevant_emails']=df_messages['Sender_Receiver_Emails'].apply(lambda x: len(x))
df_messages['num_relevant_emails'] = df_messages['Sender_Receiver_Emails_list'].apply(lambda x: len(x) if isinstance(x, list) else np.nan)
df_messages.head()
# Out:
#    Unnamed: 0  Email_ID                       time   subject  thread  sender  \
# 0           0         0  1999-06-09 04:18:00-07:00  RE: test       2    5552
# 1           1         1  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 2           2         2  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 3           3         3  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 4           4         4  1999-06-09 08:06:00-07:00  RE: test       2   40034
#
#   recipient  \
# 0   [40034]
# 1    [5552]
# 2    [5552]
# 3    [5552]
# 4    [5552]
#
#                                                                                                message  \
# 0  How about this Friday ? Julie has not left yet. She was 2 days away from leaving to start school...
# 1                                                   when? how are you and your family? is julie gone?
# 2                                                   when? how are you and your family? is julie gone?
# 3                                                   when? how are you and your family? is julie gone?
# 4                                                   when? how are you and your family? is julie gone?
#
#                   reply_time  reply_sender reply_recipient  \
# 0  1999-06-09 08:06:00-07:00         40034          [5552]
# 1  1999-06-10 03:54:00-07:00          5552         [40034]
# 2  1999-11-23 01:38:00-08:00          5552         [40034]
# 3  1999-11-23 03:13:00-08:00          5552         [40034]
# 4  1999-11-23 03:58:00-08:00          5552         [40034]
#
#                                                                             reply_message  \
# 0                                      when? how are you and your family? is julie gone?
# 1                                                Today is bad. Tommorrow I will call you.
# 2                                                          Do you have lunch plans today?
# 3  Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs.
# 4                                                            Tues.is good. I'll call you.
#
#                                                                                 Sender_Receiver_Emails  \
# 0                                                                                                  NaN
# 1  ['Do you have lunch plans today?', "Really? I'd feel like a mooch. Lets have lunch next week. An...
# 2  ['Today is bad. Tommorrow I will call you.', "Really? I'd feel like a mooch. Lets have lunch nex...
# 3  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Tues.is good. I'...
# 4  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Really? I'd feel...
#
#                                                                            Sender_Receiver_Emails_list  \
# 0                                                                                                   []
# 1  [Do you have lunch plans today?, Really? I'd feel like a mooch. Lets have lunch next week. Any d...
# 2  [Today is bad. Tommorrow I will call you., Really? I'd feel like a mooch. Lets have lunch next w...
# 3  [Today is bad. Tommorrow I will call you., Do you have lunch plans today?, Tues.is good. I'll ca...
# 4  [Today is bad. Tommorrow I will call you., Do you have lunch plans today?, Really? I'd feel like...
#
#    num_relevant_emails
# 0                    0
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %%
df_messages['sender']=df_messages['sender'].astype('str')
df_messages['reply_sender']=df_messages['reply_sender'].astype('str')

# %%
df_messages['sender_replier_thread'] = df_messages['sender'].str.cat(df_messages['reply_sender'], sep='-')
# df_messages['sender_receiver_thread'] = df_messages['sender_receiver_thread'].str.cat(df_messages['thread'], sep='-')

# %%
df_messages['num_relevant_emails'] = df_messages['Sender_Receiver_Emails_list'].apply(lambda x: len(x) if isinstance(x, list) else np.nan)

# %%
pd.set_option('display.max_colwidth', 500)
df_messages.Sender_Receiver_Emails_list.head(30)
df_messages[['sender_replier_thread','Sender_Receiver_Emails','num_relevant_emails']].iloc[15]
# Out:
# sender_replier_thread                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                37911-43
# Sender_Receiver_Emails    ['try having no work to do for two months and then having to stick around and "appear" busy  i know what you mean, in some ways its harder when you\'re not used to not doing things. i\'ve gotten good at finding things to do with my time, but when i first had nothing to do, i was going crazy. fridays are always slow around here and i\'m guessing its the same there, although i don\'t know cnrl specifcally, oil and gas producer/marketer? in terms of what i do, before enron went under, i was the...
# num_relevant_emails                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         5
# Name: 15, dtype: object

# %% [markdown]
# ### De-Duplication for Retrieval ##

# %%
df_messages_deduped=df_messages.drop_duplicates(subset='sender_replier_thread', keep='last')

# %% [markdown]
# -----
# ## Ranking Framework

# %%
# Importing Packages
import chromadb
from chromadb.utils import embedding_functions

import langchain
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain

# %%
# Setting Up Client
chroma_client = chromadb.PersistentClient(path="vectorstores")
chroma_client.heartbeat()
# Out:
# 1698353804144243871

# %%
# Defining the Embedding Function
openai_ef = embedding_functions.OpenAIEmbeddingFunction(api_key = openai_api_key,
                                                        model_name="text-embedding-ada-002")
openai_ef

# %% [markdown]
# ----
# ## Langchain Function v2

# %%
# Email Environment
sender_id='171'
replier_id='414'
sender_email='Where is my gift?'
email_dataset=df_messages_deduped
vector_db_client=chroma_client

# %%
async def get_email_response_personalized(sender_id=sender_id,
                                    replier_id=replier_id,
                                    sender_email=sender_email,
                                    email_dataset=df_messages_deduped,
                                    api_key=openai_api_key,
                                    vector_db_client=chroma_client,
                                    embedding_function=OpenAIEmbeddings()):
    
    # First getting retrieved emails to understand conversation --------
    sender_replier_id='-'.join([sender_id, replier_id])
    previous_emails=(email_dataset[email_dataset.sender_replier_thread==sender_replier_id]['Sender_Receiver_Emails_list']).to_list()[0][-10:]
    previous_emails
    # Second, getting ranked responses as per context ------------------
        
        # Building the Langchain vectorstore using chroma collections
    user_vector_store = Chroma(
        client=vector_db_client, 
        collection_name='user'+str(replier_id),
        embedding_function=OpenAIEmbeddings())
        # Getting ranked responses using MMR
    found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
    list_rel_emails=[]
    for i, doc in enumerate(found_rel_emails):
        list_rel_emails.append(doc.page_content)
    list_rel_emails
        
    # Setting up LangChain
    llm=ChatOpenAI(temperature=0.1, model=llm_model, openai_api_key=openai_api_key)
    template_string="""Create a response to the following email {sender_email}, deriving context from these relevant emails {relevant_emails} ,using a conversation style similar to following past emails between these 2 users {prev_emails}"""
    prompt_template = ChatPromptTemplate.from_template(template=template_string)    
    llm_chain=LLMChain(llm=llm, prompt=prompt_template)
    print(llm_chain.run(sender_email=sender_email, prev_emails=previous_emails, relevant_emails=list_rel_emails))

# %%
# results = await get_email_response_personalized(sender_id=sender_id,
#                                     replier_id=replier_id,
#                                     sender_email=sender_email,
#                                     email_dataset=df_messages_deduped,
#                                     api_key=openai_api_key,
#                                     vector_db_client=chroma_client,
#                                     embedding_function=OpenAIEmbeddings())
# print(results)

# %%
import pandas as pd
import ast
import chromadb
from chromadb.utils import embedding_functions
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
import asyncio

# Load the data
df_messages=pd.read_csv('gs://user-scripts-msca310019-capstone-49b3/data/20231019_Emails_with_Sender_Reply.csv', parse_dates=['time'])
df_messages['Sender_Receiver_Emails_list'] = df_messages['Sender_Receiver_Emails'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])
df_messages['sender'] = df_messages['sender'].astype('str')
df_messages['reply_sender'] = df_messages['reply_sender'].astype('str')
df_messages['sender_replier_thread'] = df_messages['sender'].str.cat(df_messages['reply_sender'], sep='-')
df_messages_deduped = df_messages.drop_duplicates(subset='sender_replier_thread', keep='last')

# Setting up the chroma client
chroma_client = chromadb.PersistentClient(path="vectorstores")
openai_api_key = openai_api_key

async def get_email_response_personalized(sender_id, replier_id, sender_email, email_dataset, api_key, vector_db_client):    
    # First getting retrieved emails to understand conversation --------
    sender_replier_id='-'.join([sender_id, replier_id])
    previous_emails=(email_dataset[email_dataset.sender_replier_thread==sender_replier_id]['Sender_Receiver_Emails_list']).to_list()[0][-10:]
    previous_emails
    # Second, getting ranked responses as per context ------------------
        
        # Building the Langchain vectorstore using chroma collections
    user_vector_store = Chroma(
        client=vector_db_client, 
        collection_name='user'+str(replier_id),
        embedding_function=OpenAIEmbeddings())
        # Getting ranked responses using MMR
    found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
    list_rel_emails=[]
    for i, doc in enumerate(found_rel_emails):
        list_rel_emails.append(doc.page_content)
    list_rel_emails
        
    # Setting up LangChain
    llm=ChatOpenAI(temperature=0.1, model=llm_model, openai_api_key=openai_api_key)
    template_string="""You are an employee of Enron and receiver of this email: {sender_email},
    Reply to the email as the receiver,
    deriving the context from these relevant emails : {relevant_emails}
    and copying the writing style of the receiver's past emails : {prev_emails}"""
    prompt_template = ChatPromptTemplate.from_template(template=template_string)    
    llm_chain=LLMChain(llm=llm, prompt=prompt_template)
    return (llm_chain.run(sender_email=sender_email, prev_emails=previous_emails, relevant_emails=list_rel_emails))

# %% [markdown]
# # For no budget cap

# %%
# async def process_all_emails(df):
#     responses = []
#     for index, (idx, row) in enumerate(df.iterrows()):  # enumerate to get index
#         response = await get_email_response_personalized(row['sender'], row['reply_sender'], row['message'], df, openai_api_key, chroma_client)
#         responses.append(response)
#         if (index + 1) % 2 == 0:  # Add sleep after every 2 calls
#             await asyncio.sleep(60)  # Using async sleep
#     return responses
## Run the asynchronous function and get all the responses
# all_responses = await process_all_emails(df_messages_deduped.head(50))

# %% [markdown]
# # Storing in parquet till error

# %%
async def process_all_emails(df, start_index=0, parquet_file='responses.parquet'):
    responses = []
    
    # Load existing data from the Parquet file if it exists
    if os.path.exists(parquet_file):
        responses_df = pd.read_parquet(parquet_file)
        responses = responses_df.to_dict('records')
    
    for idx, row in df.iloc[start_index:].iterrows():  # Using iloc to skip rows
        try:
            response = await get_email_response_personalized(row['sender'], row['reply_sender'], row['message'], df, openai_api_key, chroma_client)
            responses.append({'index': idx, 'response': response})  # save DataFrame index and response
            
            if (idx + 1) % 2 == 0:  # Add sleep after every 2 calls
                await asyncio.sleep(60)
                
            # Save interim results to the Parquet file
            pd.DataFrame(responses).to_parquet(parquet_file, index=False)
            
        except YourApiLimitError:  # replace YourApiLimitError with the actual exception
            print(f"API limit reached at index {idx}. Stopping execution.")
            break
            
    return responses

# Execute the function
all_responses = await process_all_emails(df_messages_deduped.head(50), start_index=0)
# Out:
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 0
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 4611
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 7630
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 7686
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8093
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9249
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9294
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9390
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9397
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12262
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12263
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12293
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12304
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12329
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12334
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13059
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 16187
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 16188
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 18535
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 19926
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 19948
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 19949
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22024
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22049
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22050
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22217
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22224
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22225
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22228
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22231
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22237
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22240
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22244
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22245
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22262
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22268
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22269
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22272
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22273
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22274
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22279
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22281
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22290
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22297
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22299
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22309
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22314
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 1
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 4
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 4611
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 7630
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 7686
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8093
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9249
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9294
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9390
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9397
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12262
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12263
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12293
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12304
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12329
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12334
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13059
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 16187
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 16188
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 18535
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 19926
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 19948
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 19949
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22024
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22049
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22050
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22217
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22224
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22225
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22228
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22231
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22237
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22240
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22244
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22245
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22262
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22268
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22269
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22272
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22273
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22274
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22279
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22281
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22290
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22297
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22299
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22309
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22314
# WARNING:langchain.embeddings.openai:Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 60
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 81
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 96
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 233
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 2849
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3653
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3656
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3692
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3730
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3781
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3783
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3863
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3875
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 3998
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 4022
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 4356
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 4358
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 4376
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 4885
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 5351
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 6237
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 6239
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 6254
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 6508
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 6510
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 6573
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 6786
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9279
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9293
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9500
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9636
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9856
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 10392
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 10555
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 11483
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 11485
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 11640
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12008
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12205
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12230
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12231
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12232
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12234
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12235
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12237
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12295
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12704
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12708
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12710
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12712
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12713
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12714
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12721
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12725
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12783
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12814
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12816
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12819
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12847
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12848
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12851
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12853
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12854
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12862
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12875
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12899
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12901
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12903
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12905
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12921
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 12933
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13055
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13116
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13520
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13627
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13694
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13727
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13792
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13795
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13802
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13829
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13842
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13845
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13934
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13936
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13947
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13949
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13951
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 13997
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14136
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14169
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14170
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14171
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14174
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14181
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14193
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14265
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14288
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14330
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14353
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14373
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14415
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14439
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14450
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14468
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14503
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14505
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14563
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14588
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14596
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14627
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14662
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14692
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14693
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14729
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14780
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14871
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14965
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 14969
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15022
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15023
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15042
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15047
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15052
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15082
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15133
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15146
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15147
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15148
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15173
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15195
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 15662
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 16777
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 16783
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 17619
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 18527
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 20684
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 21326
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 21592
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22671
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22673
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22674
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22676
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22678
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22682
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22685
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22687
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22689
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22692
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22693
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22696
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22699
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22701
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22705
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22706
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22712
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22716
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22720
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22722
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22729
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22732
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22734
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22735
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22737
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22744
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22746
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22750
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22751
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22753
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22755
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22756
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22757
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22758
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22760
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22765
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22768
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22769
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22771
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22773
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22777
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22778
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22779
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22780
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22782
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22783
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22786
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22787
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22792
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22795
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22798
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22799
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22800
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22803
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22806
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22808
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22815
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22816
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22821
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22828
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22830
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22834
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22837
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22838
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22842
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22843
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22845
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22846
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22847
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22848
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22849
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22855
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22859
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22861
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22863
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22865
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22867
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22869
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22870
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22871
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22877
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22879
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22884
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22888
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22890
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22897
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22899
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22900
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22912
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22918
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22919
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22920
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22921
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22922
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22923
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22929
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22936
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22938
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22941
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22943
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22948
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22954
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22956
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22958
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22962
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22972
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22978
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22984
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22985
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22986
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22987
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22990
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22991
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22995
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 22997
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23000
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23001
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23002
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23005
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23012
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23015
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23019
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23020
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23022
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23029
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23032
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23036
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23037
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23043
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23044
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23045
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23048
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23053
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23058
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23060
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23065
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23080
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23081
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23085
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23093
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23096
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23097
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23117
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23119
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23122
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23125
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23126
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23129
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23133
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23136
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23146
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23151
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23157
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23162
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23164
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23168
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23171
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23173
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23174
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23184
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23185
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23191
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23199
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23202
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23206
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23207
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23210
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23212
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23213
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23216
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23219
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23220
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23224
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23225
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23226
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23229
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23231
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23234
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23243
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23245
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23247
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23249
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23250
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23252
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23253
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23261
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23264
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23268
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23271
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23273
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23274
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23284
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23295
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23306
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23318
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23320
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23323
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23324
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23325
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23334
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23336
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23340
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23341
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23345
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23346
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23347
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23353
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23361
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23362
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23365
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23372
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23374
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23376
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23384
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23386
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23395
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23399
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23400
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23412
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23413
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23414
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23419
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23420
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23421
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23422
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23423
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23425
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23428
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23430
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23431
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23435
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23436
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23438
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23439
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23448
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23450
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23452
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23456
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23457
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23458
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23461
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23464
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23466
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23467
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23475
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23480
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23486
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23488
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23490
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23492
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23496
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23501
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23504
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23507
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23509
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23511
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23512
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23513
# ...
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8767
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8769
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8771
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8776
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8782
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8783
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8785
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8787
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8789
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8792
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8794
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8797
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8799
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8801
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8802
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8805
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8806
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8807
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8808
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8810
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8811
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8812
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8813
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8815
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8816
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8821
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8824
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8826
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8828
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8830
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8832
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8833
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8835
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8836
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8837
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8838
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8843
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8847
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8848
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8850
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8852
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8853
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8856
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8858
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8860
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8861
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8863
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8864
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8865
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8871
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8872
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8877
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8878
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8885
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8891
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8892
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8919
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8929
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8931
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8932
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8934
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8935
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8937
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8938
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8939
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8940
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8941
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8942
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8944
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8946
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8947
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8949
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8951
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8953
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8954
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8956
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8958
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8960
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8961
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8963
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8966
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8968
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8969
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8970
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8976
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8977
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8981
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8982
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8984
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8985
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8988
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8989
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8990
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8992
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8994
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8996
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8997
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 8998
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9000
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9002
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9004
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9006
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9013
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9016
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9019
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9020
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9022
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9023
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9024
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9026
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9028
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9029
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9031
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9032
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9033
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9034
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9038
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9041
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9042
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9043
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9045
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9046
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9049
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9053
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9054
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9057
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9058
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9059
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9063
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9066
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9070
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9072
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9073
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9075
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9076
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9081
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9083
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 9084
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 23922
# WARNING:chromadb.segment.impl.vector.local_persistent_hnsw:Add of existing embedding ID: 24380
# WARNING:langchain.embeddings.openai:Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# WARNING:langchain.embeddings.openai:Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# WARNING:langchain.embeddings.openai:Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# WARNING:langchain.embeddings.openai:Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# WARNING:langchain.embeddings.openai:Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..

# %%
for item in all_responses:
    idx = item['index']
    response = item['response']
    df_messages_deduped.loc[idx, 'responses'] = response
# Out:
# /var/tmp/ipykernel_1081167/2334431273.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_messages_deduped.loc[idx, 'responses'] = response

# %%
#all_responses

# %%
# df_messages_deduped.loc[df_messages_deduped.index[:100], 'responses'] = all_responses

# %%
# Append the responses to the original dataframe
# df_messages_deduped['responses'] = all_responses

# %%
df_messages_deduped
# Out:
#        Unnamed: 0  Email_ID                       time  \
# 0               0         0  1999-06-09 04:18:00-07:00
# 4               4         4  1999-06-09 08:06:00-07:00
# 10             10        13  2001-11-08 14:18:15-08:00
# 11             11        14  2001-11-09 09:03:31-08:00
# 12             12        15  2001-11-13 09:08:48-08:00
# ...           ...       ...                        ...
# 24635       24635     27458  2002-01-31 09:26:01-08:00
# 24636       24636     27459  2002-01-31 09:34:39-08:00
# 24637       24637     27460  2002-01-31 06:44:41-08:00
# 24638       24638     27461  2002-01-30 09:40:23-08:00
# 24639       24639     27462  2002-01-28 12:49:37-08:00
#
#                               subject  thread sender           recipient  \
# 0                            RE: test       2   5552             [40034]
# 4                            RE: test       2  40034              [5552]
# 10                               test       2  39298               [402]
# 11                           RE: test       2    402             [39298]
# 12                               test       2  39322               [402]
# ...                               ...     ...    ...                 ...
# 24635            Canadian Trader List  137631     56               [322]
# 24636        RE: Canadian Trader List  137631    322                [56]
# 24637                RE: Physical Gas  137634    322               [551]
# 24638  Estate DPR Reporting for Power  137640   3595         [3421, 322]
# 24639            Termianted Contracts  137655  13704  [13306, 9868, 322]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   message  \
# 0      How about this Friday ? Julie has not left yet. She was 2 days away from leaving to start school on June 7th when she, quite by accident, looked at the school schedule for the first time in several weeks. Now mind you she had lined up a babysitter ,lined up a place to stay, arranged to get a key to start the 7th. The schedule says the school starts the 14th. Pretty funny. How many years will it take her to live this down?. Enron Capital & Trade Resources Corp.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                      when? how are you and your family? is julie gone?
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                              test Dave
# 11                                                                                                                                                                                                                                                                                                                                         Dave, Take a look at this before you pass it on. I haven't looked at it in a while. Let me know if you get it and how it looks. Thanks, Kevin
# 12                                                                                                                                                                                                                                                                                                                                                                                              test   Do You Yahoo!? Find the one for you at Yahoo! Personals http://personals.yahoo.com
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 24635      John, Please review the list below and let me know if there are any changes for Stack Manager access. Ryan WattRWATTAECO Cash Trader Mike CowanMCOWANAECO Cash Trader Chris LambieCLAMBIEAECO Term Trader Stephane BrodeurSBRODEURBC Cash Trader Chad ClarkCCLARK5BC Cash Trader Chris DorlandCDORLANBC Term Trader Lon DraperLDRAPEROptions Trader Cooper RicheyCRICHEYPower Trader John ZufferliJZUFFERVP Canada Trading Thank you, Stephanie Sever EnronOnline 713 853 3465
# 24636                                                                                                                                                                                                                                                            Stephane Brodeur should be removed from the list. I am not sure about Chris Lambie, whether he is joining the company. Garrett Trip should be added as the Ontario Power trader (that market won't open until May 2002)
# 24637                                                                                                                                                                                                                                                                                                                                                                that was our plan but I am not sure whether UBS has the proper Canadian corporate structure to allow to do that yet
# 24638                                                       Peggy & John The estate's DPR reporting requirement to risk controls in Houston is going to be twice a week. Consistent with this I would also like to change our internal DPR reporting process for ECC Power Estate from DAILY to twice per week. Note that curves and an official calc will still be required daily. I would like to make this change starting Feb 1. Please let me know if you are okay with this. Kathy
# 24639                                                             Further to our meeting today, please find attached the list of contracts ECC is taking the view are properly terminated and the dates of such termination (in ECC's opinion). This list was last updated on January 9, 2002 before I went away, so Bryan, if there are any other counterparties that should be added to the list, can you please let Kyle, Eric, John and myself know as soon as possible? Thanks Greg
#
#                       reply_time reply_sender reply_recipient  \
# 0      1999-06-09 08:06:00-07:00        40034          [5552]
# 4      1999-11-23 03:58:00-08:00         5552         [40034]
# 10     2001-11-09 09:03:31-08:00          402         [39298]
# 11     2001-11-09 12:06:40-08:00        39298           [402]
# 12     2001-11-15 09:27:59-08:00          402         [39322]
# ...                          ...          ...             ...
# 24635  2002-01-31 09:34:39-08:00          322            [56]
# 24636  2002-01-31 10:35:06-08:00           56           [322]
# 24637  2002-01-31 06:49:52-08:00          551           [322]
# 24638  2002-01-30 10:09:47-08:00          322          [3595]
# 24639  2002-01-28 12:57:25-08:00          322         [13704]
#
#                                                                                                                                                                                                                                                                       reply_message  \
# 0                                                                                                                                                                                                                                when? how are you and your family? is julie gone?
# 4                                                                                                                                                                                                                                                      Tues.is good. I'll call you.
# 10                                                                                                                                   Dave, Take a look at this before you pass it on. I haven't looked at it in a while. Let me know if you get it and how it looks. Thanks, Kevin
# 11      looks good. Metz says it looks fine too. You'll probably get more questions about Pub Ventures than trading. A lady named Susan Mills should be calling you either tonight or this weekend at home. She'll set up your interview. Everything looks good from this end. Dave
# 12                                                                                                                                                                                                 sorry, but i didn't get your message until late. i'll call you at home tonight.
# ...                                                                                                                                                                                                                                                                             ...
# 24635                                                      Stephane Brodeur should be removed from the list. I am not sure about Chris Lambie, whether he is joining the company. Garrett Trip should be added as the Ontario Power trader (that market won't open until May 2002)
# 24636                                                                                                                                                                                                    Thank you. Please let me know about Chris Lambie if he does not join UBS.
# 24637                                  John, I understand Peter Keohane is here today and through the weekend if necessary to complete contracts for Canada with UBS legal. I am hoping that completion of contracts includes identification of corporate entity (vain hope?) Dave
# 24638                                                                                                                                                                                                                                                                           ok
# 24639                                                          according to the packet that was distributed in the meeting today with BC, it appears that Calpine, El Paso, Williams, AEC Marketing, AEC Storage are all FEB 1, this doesn't jive with what you just sent, wassup?
#
#                                                                                                                                                          Sender_Receiver_Emails  \
# 0                                                                                                                                                                           NaN
# 4      ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs."]
# 10                                                                                                                                                                          NaN
# 11                                                                                                                                                                          NaN
# 12                                                                                                                                                                          NaN
# ...                                                                                                                                                                         ...
# 24635                                                                                 ['you should request this from eric ledain or derek davies, they have the current list ']
# 24636                                                                                                                                                                       NaN
# 24637                                                                                                                                                                       NaN
# 24638                                                                                                                                                                       NaN
# 24639                                                                                                                                                                       NaN
#
#                                                                                                                                               Sender_Receiver_Emails_list  \
# 0                                                                                                                                                                      []
# 4      [Today is bad. Tommorrow I will call you., Do you have lunch plans today?, Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs.]
# 10                                                                                                                                                                     []
# 11                                                                                                                                                                     []
# 12                                                                                                                                                                     []
# ...                                                                                                                                                                   ...
# 24635                                                                             [you should request this from eric ledain or derek davies, they have the current list ]
# 24636                                                                                                                                                                  []
# 24637                                                                                                                                                                  []
# 24638                                                                                                                                                                  []
# 24639                                                                                                                                                                  []
#
#        num_relevant_emails sender_replier_thread
# 0                        0            5552-40034
# 4                        3            40034-5552
# 10                       0             39298-402
# 11                       0             402-39298
# 12                       0             39322-402
# ...                    ...                   ...
# 24635                    1                56-322
# 24636                    0                322-56
# 24637                    0               322-551
# 24638                    0              3595-322
# 24639                    0             13704-322
#
# [10381 rows x 16 columns]

# %%
df_messages_deduped= pd.read_parquet("responses.parquet")

# %%
df_messages_deduped
# Out:
#     index  \
# 0       0
# 1       4
# 2      10
# 3      11
# 4      12
# ..    ...
# 95    200
# 96    201
# 97    204
# 98    207
# 99    212
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                response
# 0                       Hi there,\n\nThanks for reaching out. In response to your email, I'm doing well, thank you for asking. As for Julie, she hasn't left yet and it seems like there was a bit of a mix-up with her school schedule. It's definitely a funny situation, but I'm sure she'll be able to laugh it off eventually.\n\nIn terms of scheduling, you mentioned Friday - are you referring to a specific meeting or event? Let me know and I'll do my best to accommodate.\n\nBest regards,\n\n[Your Name]
# 1                                Dear Sender,\n\nThank you for your email. My family and I are doing well, thank you for asking. As for Julie, I am not sure who you are referring to as there are multiple people with that name in the company. \n\nIn regards to your previous emails, I apologize for not responding sooner. I have been quite busy with work. As for lunch plans, I am available next week on any day except for Monday or Thursday. \n\nThank you for reaching out.\n\nBest regards,\n[Your Name]
# 2                                                                                                                                                                                                         Hi Dave,\n\nI hope this email finds you well. I received your message and wanted to let you know that I have looked at the document you sent me. It seems to be in good shape, but I haven't reviewed it thoroughly yet. I will let you know if I have any further comments or suggestions.\n\nThanks,\nKevin
# 3                                                                                                                                                                                                        Dear Kevin,\n\nI received your email and took a look at the document you sent. It appears to be outdated and I'm not sure if it's still relevant to our current projects. Can you provide me with more context on why you sent it and if there's anything specific you want me to do with it?\n\nThanks,\nDave
# 4                                                                                                                                                                                                         Hi Kevin,\n\nThanks for the email. Unfortunately, I'm not sure what you're referring to with just the word "test." In any case, I hope everything is going well with you. I haven't found a group in Houston yet, but I'm still searching. I'll be sure to tell Matt you said hi. \n\nTake care,\n[Your Name]
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 95                                                                                                                                                                                                                                                                                                                                      Hi Ben,\n\nThanks for letting me know. I appreciate your prompt response. Looking forward to hearing back from you on Thursday with the results. \n\nBest regards,\n[Your Name]
# 96  Dear Dad,\n\nI hope you're doing well. I received your email and it's great to hear that the meetings with Mike M went well. I think the deal would be beneficial for both companies. Megan and I will be in NYC this weekend for a wedding, so I'll try to give you a call soon to talk about a couple of things.\n\nRegarding my role at Cinergy, I appreciate your thoughts on the matter. I agree that involvement in the DG area would be a great opportunity for me to grow and develop as an executive. I...
# 97                                                                                                                                                                                                                                                                                                          Hi Ben,\n\nThanks for reaching out. I'm not entirely sure what you're referring to in your email. Could you please provide me with some additional context or information? \n\nBest regards,\n\n[Your Name]
# 98                                                                                                                                                                                                                    Dear Sender,\n\nThank you for reaching out regarding lunch. I appreciate the invitation and am looking forward to it. As for the timing, I understand that Cindy is out this week and will be happy to wait for her to figure out a date that works for everyone.\n\nBest regards,\n\n[Your Name]
# 99  Dear Sender,\n\nI hope this email finds you well. Thank you for your message regarding the talent at Enron. I couldn't agree more that brilliance begets brilliance, and it's always a joy to work with such a talented group of individuals. \n\nI'm glad to hear that you can make it and that you're willing to put your mind to it. You're a gem and I have no doubt that you'll contribute greatly to the team. \n\nI also heard that the recent event was very good, even if the speech wasn't quite as sh...
#
# [100 rows x 2 columns]

# %%
import os
file_path = "Hedwig/06_ModelValidation/responses.parquet"
file_exists = os.path.exists(file_path)
print(f"File exists: {file_exists}")
# Out:
# File exists: False

# %%
# !pip install rouge-score
from rouge_score import rouge_scorer
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# %%
def calculate_bleu_score(reference, candidate):
    smoothing_function = SmoothingFunction().method1
    return sentence_bleu([reference], candidate, smoothing_function=smoothing_function)

# %%
from rouge_score import rouge_scorer
from nltk.translate.bleu_score import sentence_bleu

def calculate_scores(actual, generated):
    # Check if either actual or generated is None, and return None if either is None
    if actual is None or generated is None:
        return {'rouge1': None, 'rougeL': None, 'bleu': None}
    
    # Calculating ROUGE scores
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)
    rouge_scores = scorer.score(actual, generated)
    
    # Calculating BLEU score
    bleu_score = sentence_bleu([actual.split()], generated.split())
    
    return {'rouge1': rouge_scores['rouge1'], 'rougeL': rouge_scores['rougeL'], 'bleu': bleu_score}

# Applying the scoring function to rows with non-null responses
df_messages_deduped['evaluation_scores'] = df_messages_deduped.apply(
    lambda row: calculate_scores(str(row['reply_message']), str(row['responses'])) 
    if pd.notnull(row['responses']) and pd.notnull(row['reply_message']) else {'rouge1': None, 'rougeL': None, 'bleu': None}, axis=1
)

# Split the evaluation scores into separate columns
df_messages_deduped[['rouge1_score', 'rougeL_score', 'bleu_score']] = pd.DataFrame(df_messages_deduped['evaluation_scores'].tolist(), index=df_messages_deduped.index)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'responses'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 19
#      16     return {'rouge1': rouge_scores['rouge1'], 'rougeL': rouge_scores['rougeL'], 'bleu': bleu_score}
#      18 # Applying the scoring function to rows with non-null responses
# ---> 19 df_messages_deduped['evaluation_scores'] = df_messages_deduped.apply(
#      20     lambda row: calculate_scores(str(row['reply_message']), str(row['responses']))
#      21     if pd.notnull(row['responses']) and pd.notnull(row['reply_message']) else {'rouge1': None, 'rougeL': None, 'bleu': None}, axis=1
#      22 )
#      24 # Split the evaluation scores into separate columns
#      25 df_messages_deduped[['rouge1_score', 'rougeL_score', 'bleu_score']] = pd.DataFrame(df_messages_deduped['evaluation_scores'].tolist(), index=df_messages_deduped.index)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Cell In[35], line 21, in <lambda>(row)
#      16     return {'rouge1': rouge_scores['rouge1'], 'rougeL': rouge_scores['rougeL'], 'bleu': bleu_score}
#      18 # Applying the scoring function to rows with non-null responses
#      19 df_messages_deduped['evaluation_scores'] = df_messages_deduped.apply(
#      20     lambda row: calculate_scores(str(row['reply_message']), str(row['responses']))
# ---> 21     if pd.notnull(row['responses']) and pd.notnull(row['reply_message']) else {'rouge1': None, 'rougeL': None, 'bleu': None}, axis=1
#      22 )
#      24 # Split the evaluation scores into separate columns
#      25 df_messages_deduped[['rouge1_score', 'rougeL_score', 'bleu_score']] = pd.DataFrame(df_messages_deduped['evaluation_scores'].tolist(), index=df_messages_deduped.index)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'responses'

# %%
# Applying the scoring function to rows with non-null responses
df_messages_deduped['evaluation_scores'] = df_messages_deduped.apply(
    lambda row: calculate_scores(str(row['reply_message']), str(row['responses'])) 
    if pd.notnull(row['responses']) and pd.notnull(row['reply_message']) else None, axis=1
)
# Out:
# /var/tmp/ipykernel_1081167/1080931012.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_messages_deduped['evaluation_scores'] = df_messages_deduped.apply(

# %%
df_messages_deduped.head(10)
# Out:
#     Unnamed: 0  Email_ID                       time    subject  thread sender  \
# 0            0         0  1999-06-09 04:18:00-07:00   RE: test       2   5552
# 4            4         4  1999-06-09 08:06:00-07:00   RE: test       2  40034
# 10          10        13  2001-11-08 14:18:15-08:00       test       2  39298
# 11          11        14  2001-11-09 09:03:31-08:00   RE: test       2    402
# 12          12        15  2001-11-13 09:08:48-08:00       test       2  39322
# 27          27        31  2001-10-29 14:01:05-08:00  RE: Hello       3  17189
# 28          28        32  2001-11-01 08:48:56-08:00  RE: Hello       3   5409
# 29          29        33  2001-11-08 08:24:47-08:00  RE: Hello       3    189
# 35          35        39  2001-11-08 08:41:11-08:00  RE: Hello       3  51569
# 38          38        42  2002-02-03 17:56:51-08:00  RE: Hello       3    307
#
#    recipient  \
# 0    [40034]
# 4     [5552]
# 10     [402]
# 11   [39298]
# 12     [402]
# 27    [5409]
# 28   [17189]
# 29   [51569]
# 35     [189]
# 38   [27130]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                message  \
# 0   How about this Friday ? Julie has not left yet. She was 2 days away from leaving to start school on June 7th when she, quite by accident, looked at the school schedule for the first time in several weeks. Now mind you she had lined up a babysitter ,lined up a place to stay, arranged to get a key to start the 7th. The schedule says the school starts the 14th. Pretty funny. How many years will it take her to live this down?. Enron Capital & Trade Resources Corp.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                   when? how are you and your family? is julie gone?
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                           test Dave
# 11                                                                                                                                                                                                                                                                                                                                      Dave, Take a look at this before you pass it on. I haven't looked at it in a while. Let me know if you get it and how it looks. Thanks, Kevin
# 12                                                                                                                                                                                                                                                                                                                                                                                           test   Do You Yahoo!? Find the one for you at Yahoo! Personals http://personals.yahoo.com
# 27                                                                                                                                                                                                                                                                                                                                                                                                                          great send it tommorrow, and I will pass it on to Maria.
# 28                                                                                                                                                                                                                                                                                               I sent this from home Tuesday night. I'm sending it again because the phone service at my apartment complex is out due to construction so I can't tell if you received it. Thanks cg
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                           I think Enron and my career are finished.
# 35                                                                                                       give me a call if you can talk? 212 469 7839 n.   This e mail may contain confidential and/or privileged information. If you are not the intended recipient (or have received this e mail in error) please notify the sender immediately and destroy this e mail. Any unauthorized copying, disclosure or distribution of the material in this e mail is strictly forbidden.
# 38                                                                                                                                                                                                                                                        Hello Glad you got yourself sorted with a new job. Things here are getting better   we have nearly closed with UBS, so I hope to have a new job next week. Still in Houston. Are you trading   if so what? Take care Louise
#
#                    reply_time reply_sender reply_recipient  \
# 0   1999-06-09 08:06:00-07:00        40034          [5552]
# 4   1999-11-23 03:58:00-08:00         5552         [40034]
# 10  2001-11-09 09:03:31-08:00          402         [39298]
# 11  2001-11-09 12:06:40-08:00        39298           [402]
# 12  2001-11-15 09:27:59-08:00          402         [39322]
# 27  2001-11-01 08:48:56-08:00         5409         [17189]
# 28  2001-11-01 08:54:29-08:00        17189          [5409]
# 29  2001-11-08 08:41:11-08:00        51569           [189]
# 35  2002-01-22 11:21:05-08:00          189         [51569]
# 38  2002-02-04 01:15:22-08:00        27130           [307]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           reply_message  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                    when? how are you and your family? is julie gone?
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Tues.is good. I'll call you.
# 10                                                                                                                                                                                                                                                                                                                                                                       Dave, Take a look at this before you pass it on. I haven't looked at it in a while. Let me know if you get it and how it looks. Thanks, Kevin
# 11                                                                                                                                                                                                                                          looks good. Metz says it looks fine too. You'll probably get more questions about Pub Ventures than trading. A lady named Susan Mills should be calling you either tonight or this weekend at home. She'll set up your interview. Everything looks good from this end. Dave
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                     sorry, but i didn't get your message until late. i'll call you at home tonight.
# 27                                                                                                                                                                                                                                                                                                                                I sent this from home Tuesday night. I'm sending it again because the phone service at my apartment complex is out due to construction so I can't tell if you received it. Thanks cg
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        I will pass it on to Maria.
# 29                                                                                                                                        give me a call if you can talk? 212 469 7839 n.   This e mail may contain confidential and/or privileged information. If you are not the intended recipient (or have received this e mail in error) please notify the sender immediately and destroy this e mail. Any unauthorized copying, disclosure or distribution of the material in this e mail is strictly forbidden.
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                       i don't really know yet check back with me in a weeks time. az
# 38   Setting up oil n products options book. Nice people alot of ex enron. It feels very much like enron used to be b4 we grew out of control. But there is a guy here with equally bad shirt taste as Marcello  Seems a shame mark wright and a few others went to williams and that isn't lookin too rosie. I actually found out about enron's demise when i was away in honeymoon, (great wedding present ) but still sounds like the best place to be considering everyone else was in the pub  Will the UBS job...
#
#                                                                                                                                                       Sender_Receiver_Emails  \
# 0                                                                                                                                                                        NaN
# 4   ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs."]
# 10                                                                                                                                                                       NaN
# 11                                                                                                                                                                       NaN
# 12                                                                                                                                                                       NaN
# 27              ["Good morning. I'm only halfway through my resume but I should finish it this evening and I will email it to you from home or tomorrow from work. Thanks "]
# 28                                                                                                                                                                       NaN
# 29                                                                                                                                                                       NaN
# 35                                        ['Let me check on it and get back to you. I had mine done in Houston, but I can probably recommend someone. Happy New Year, Andy']
# 38                                                                                                                                                                       NaN
#
#                                                                                                                                            Sender_Receiver_Emails_list  \
# 0                                                                                                                                                                   []
# 4   [Today is bad. Tommorrow I will call you., Do you have lunch plans today?, Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs.]
# 10                                                                                                                                                                  []
# 11                                                                                                                                                                  []
# 12                                                                                                                                                                  []
# 27          [Good morning. I'm only halfway through my resume but I should finish it this evening and I will email it to you from home or tomorrow from work. Thanks ]
# 28                                                                                                                                                                  []
# 29                                                                                                                                                                  []
# 35                                    [Let me check on it and get back to you. I had mine done in Houston, but I can probably recommend someone. Happy New Year, Andy]
# 38                                                                                                                                                                  []
#
#    sender_replier_thread  \
# 0             5552-40034
# 4             40034-5552
# 10             39298-402
# 11             402-39298
# 12             39322-402
# 27            17189-5409
# 28            5409-17189
# 29             189-51569
# 35             51569-189
# 38             307-27130
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               responses  \
# 0                                                                                                                                                                                                                                                             Hi there,\n\nThanks for reaching out. In regards to your question about Julie, I'm not sure if she's left yet. Could you clarify? \n\nAlso, I hope you and your family are doing well. When were you thinking of getting together? \n\nBest,\n[Your Name]
# 4       Dear Sender,\n\nThank you for your email. My family and I are doing well, thank you for asking. As for Julie, I am not sure who you are referring to as there are multiple people with that name in the company. \n\nIn regards to the context of your email, I am not sure what you are trying to convey as it seems disconnected from our previous conversations. If there is something specific you need to discuss, please let me know and we can schedule a call or meeting.\n\nBest regards,\n[Your Name]
# 10                                                                                                                                                                                                        Hi Dave,\n\nI hope this email finds you well. I received your message and wanted to let you know that I have looked at the document you sent me. It seems to be in good shape, but I haven't reviewed it thoroughly yet. I will let you know if I have any further comments or suggestions.\n\nThanks,\nKevin
# 11                                                                                                                                                                                                                                                                                                                         Hi Kevin,\n\nThanks for sending this over. I received it and took a look. Everything seems to be in order, but I'll let you know if I have any further questions or concerns.\n\nBest,\nDave
# 12                                                                                                                                                                                                                                                                                                                  Hi Kevin,\n\nThanks for the email. Unfortunately, I'm not sure what you're referring to with the subject line "test." In any case, I hope everything is going well with you. \n\nBest,\n[Your Name]
# 27                                                                                                                                                                                                                                                      Good morning,\n\nThank you for your email. I have received it and will make sure to send it to Maria tomorrow as requested. If there are any further updates or changes, please let me know.\n\nThank you and have a great day.\n\nBest regards,\n\n[Your Name]
# 28                                                                                                                                                                                                                                                                                                  Dear cg,\n\nThank you for resending your email. I did receive it this time. I'm sorry to hear about the phone service outage at your apartment complex. I hope it gets resolved soon.\n\nBest regards,\n[Your Name]
# 29  Dear [Sender],\n\nI am sorry to hear that you feel that way about Enron and your career. However, I would like to remind you that we are a team and we can work together to overcome any challenges that we may face.\n\nI understand that recent events may have caused some uncertainty, but I believe that we can still make a positive impact in our industry. Let us focus on our strengths and continue to work towards our goals.\n\nPlease do not hesitate to reach out to me if you need any support or...
# 35                Hi there,\n\nI received your email asking me to give you a call. I'm available to talk, but I just wanted to confirm that you are the intended recipient of this email. As you may know, this email may contain confidential and/or privileged information, so I want to make sure that I'm speaking with the right person.\n\nIf everything checks out, please let me know a good time to call you back. My work phone is 713 853 6994. Looking forward to speaking with you.\n\nBest regards,\nAndy
# 38                                                                                                          Hi Louise,\n\nThanks for reaching out. Yes, I have found a new job and things are going well so far. I'm glad to hear that things are improving at Enron and that you may have a new job soon.\n\nAs for trading, I am not currently involved in any trading activities. I have moved on to a different industry altogether. How about you? Are you still involved in trading?\n\nTake care,\n\n[Your Name]
#
#                                                                                                                                                                          evaluation_scores  \
# 0                                     {'rouge1': (0.15555555555555556, 0.7, 0.2545454545454545), 'rougeL': (0.08888888888888889, 0.4, 0.14545454545454545), 'bleu': 1.245183060581128e-78}
# 4   {'rouge1': (0.043478260869565216, 0.5714285714285714, 0.08080808080808081), 'rougeL': (0.021739130434782608, 0.2857142857142857, 0.04040404040404041), 'bleu': 5.882492291217442e-232}
# 10    {'rouge1': (0.3220338983050847, 0.5757575757575758, 0.41304347826086957), 'rougeL': (0.23728813559322035, 0.42424242424242425, 0.30434782608695654), 'bleu': 5.475002426535681e-155}
# 11                  {'rouge1': (0.3055555555555556, 0.22916666666666666, 0.2619047619047619), 'rougeL': (0.16666666666666666, 0.125, 0.14285714285714288), 'bleu': 9.199649000267841e-232}
# 12                       {'rouge1': (0.11428571428571428, 0.23529411764705882, 0.15384615384615385), 'rougeL': (0.08571428571428572, 0.17647058823529413, 0.11538461538461539), 'bleu': 0}
# 27                 {'rouge1': (0.1956521739130435, 0.25, 0.21951219512195125), 'rougeL': (0.13043478260869565, 0.16666666666666666, 0.14634146341463414), 'bleu': 1.0460714921185531e-231}
# 28   {'rouge1': (0.07894736842105263, 0.42857142857142855, 0.13333333333333333), 'rougeL': (0.07894736842105263, 0.42857142857142855, 0.13333333333333333), 'bleu': 9.72161026064145e-232}
# 29     {'rouge1': (0.18269230769230768, 0.30158730158730157, 0.2275449101796407), 'rougeL': (0.10576923076923077, 0.1746031746031746, 0.1317365269461078), 'bleu': 3.431506993923134e-155}
# 35                    {'rouge1': (0.08791208791208792, 0.5333333333333333, 0.1509433962264151), 'rougeL': (0.06593406593406594, 0.4, 0.11320754716981134), 'bleu': 8.412065649527267e-232}
# 38  {'rouge1': (0.2972972972972973, 0.18032786885245902, 0.22448979591836732), 'rougeL': (0.16216216216216217, 0.09836065573770492, 0.12244897959183673), 'bleu': 1.7863546975782162e-155}
#
#                                                        rouge1_score  \
# 0                    (0.15555555555555556, 0.7, 0.2545454545454545)
# 4   (0.043478260869565216, 0.5714285714285714, 0.08080808080808081)
# 10    (0.3220338983050847, 0.5757575757575758, 0.41304347826086957)
# 11    (0.3055555555555556, 0.22916666666666666, 0.2619047619047619)
# 12  (0.11428571428571428, 0.23529411764705882, 0.15384615384615385)
# 27                  (0.1956521739130435, 0.25, 0.21951219512195125)
# 28  (0.07894736842105263, 0.42857142857142855, 0.13333333333333333)
# 29   (0.18269230769230768, 0.30158730158730157, 0.2275449101796407)
# 35    (0.08791208791208792, 0.5333333333333333, 0.1509433962264151)
# 38   (0.2972972972972973, 0.18032786885245902, 0.22448979591836732)
#
#                                                        rougeL_score  \
# 0                   (0.08888888888888889, 0.4, 0.14545454545454545)
# 4   (0.021739130434782608, 0.2857142857142857, 0.04040404040404041)
# 10  (0.23728813559322035, 0.42424242424242425, 0.30434782608695654)
# 11                (0.16666666666666666, 0.125, 0.14285714285714288)
# 12  (0.08571428571428572, 0.17647058823529413, 0.11538461538461539)
# 27  (0.13043478260869565, 0.16666666666666666, 0.14634146341463414)
# 28  (0.07894736842105263, 0.42857142857142855, 0.13333333333333333)
# 29    (0.10576923076923077, 0.1746031746031746, 0.1317365269461078)
# 35                  (0.06593406593406594, 0.4, 0.11320754716981134)
# 38  (0.16216216216216217, 0.09836065573770492, 0.12244897959183673)
#
#        bleu_score
# 0    1.245183e-78
# 4   5.882492e-232
# 10  5.475002e-155
# 11  9.199649e-232
# 12   0.000000e+00
# 27  1.046071e-231
# 28  9.721610e-232
# 29  3.431507e-155
# 35  8.412066e-232
# 38  1.786355e-155

# %%
df_messages_deduped.to_csv('gs://user-scripts-msca310019-capstone-49b3/data/20231025_replies_scores.csv')

# %%
# df_messages_deduped['responses'] = all_responses
# df_messages_deduped['evaluation_scores'] = df_messages_deduped.apply(lambda row: calculate_scores(row['reply_message'], row['responses']), axis=1)

# %%
# def calculate_rouge_scores(actual, generated):
#     scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)
#     scores = scorer.score(actual, generated)
#     return scores

# df_messages_deduped['responses'] = all_responses
# df_messages_deduped['rouge_scores'] = df_messages_deduped.apply(lambda row: calculate_rouge_scores(row['reply_message'], row['responses']), axis=1)

# %%
from rouge_score import rouge_scorer
from nltk.translate.bleu_score import sentence_bleu

def calculate_scores(actual, generated):
    # Check if either actual or generated is None, and return None if either is None
    if actual is None or generated is None:
        return {'rouge1_precision': None, 'rouge1_recall': None, 'rouge1_f1': None,
                'rougeL_precision': None, 'rougeL_recall': None, 'rougeL_f1': None,
                'bleu_score': None}
    
    # Calculating ROUGE scores
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)
    rouge_scores = scorer.score(actual, generated)
    
    # Calculating BLEU score
    bleu_score = sentence_bleu([actual.split()], generated.split())
    
    # Return separate precision, recall, and F1 for ROUGE-1 and ROUGE-L
    return {
        'rouge1_precision': rouge_scores['rouge1'].precision,
        'rouge1_recall': rouge_scores['rouge1'].recall,
        'rouge1_f1': rouge_scores['rouge1'].fmeasure,
        'rougeL_precision': rouge_scores['rougeL'].precision,
        'rougeL_recall': rouge_scores['rougeL'].recall,
        'rougeL_f1': rouge_scores['rougeL'].fmeasure,
        'bleu_score': bleu_score
    }

# Assuming you have a DataFrame df_messages_deduped with 'reply_message' and 'responses' columns

# Applying the scoring function to rows with non-null responses
df_messages_deduped['evaluation_scores'] = df_messages_deduped.apply(
    lambda row: calculate_scores(str(row['reply_message']), str(row['responses'])) 
    if pd.notnull(row['responses']) and pd.notnull(row['reply_message']) else {
        'rouge1_precision': None, 'rouge1_recall': None, 'rouge1_f1': None,
        'rougeL_precision': None, 'rougeL_recall': None, 'rougeL_f1': None,
        'bleu_score': None
    }, axis=1
)

# Split the evaluation scores into separate columns
df_messages_deduped[['rouge1_precision', 'rouge1_recall', 'rouge1_f1',
                     'rougeL_precision', 'rougeL_recall', 'rougeL_f1',
                     'bleu_score']] = pd.DataFrame(df_messages_deduped['evaluation_scores'].tolist(), index=df_messages_deduped.index)

# Calculate the average F1 score for ROUGE-L for the entire dataset
average_rouge1_f1_score = df_messages_deduped['rouge1_f1'].mean()

# Print the result
print(f"Average ROUGE-1 F1-score: {average_rouge1_f1_score:.2f}")
# Out:
# Average ROUGE-1 F1-score: 0.20
# /var/tmp/ipykernel_1081167/2299518186.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_messages_deduped['evaluation_scores'] = df_messages_deduped.apply(
# /var/tmp/ipykernel_1081167/2299518186.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_messages_deduped[['rouge1_precision', 'rouge1_recall', 'rouge1_f1',

# %%
# Print the result
print(f"Average ROUGE-L F1-score: {average_rougeL_f1_score:.2f}")
# Out:
# Average ROUGE-L F1-score: 0.14
