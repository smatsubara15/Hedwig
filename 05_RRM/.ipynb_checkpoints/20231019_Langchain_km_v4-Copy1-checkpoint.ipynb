# %% [markdown]
# # **Langchain Integration**

# %%
import openai
import os
import getpass

os.environ['OPENAI_API_KEY'] = getpass.getpass('OpenAI API Key:')
# Out:
# OpenAI API Key: ········

# %%
if 'OPENAI_API_KEY' in os.environ:
    openai_api_key = os.environ['OPENAI_API_KEY']
    print("OpenAI API Key:", openai_api_key)
else:
    print("OPENAI_API_KEY environment variable is not set.")
# Out:
# OpenAI API Key: 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

# %%
# account for deprecation of LLM model
import datetime
# Get the current date
current_date = datetime.datetime.now().date()

# Define the date after which the model should be set to "gpt-3.5-turbo"
target_date = datetime.date(2024, 6, 12)

# Set the model variable based on the current date
if current_date > target_date:
    llm_model = "gpt-3.5-turbo"
else:
    llm_model = "gpt-3.5-turbo-0301"

# %%
import pandas as pd
import numpy as np
import ast  # Import the ast module for literal evaluation
import seaborn as sns

pd.set_option('display.max_colwidth', 100)
# %pip install pandarallel
import multiprocessing

num_processors = multiprocessing.cpu_count()
print(f'Available CPUs: {num_processors}')

import pandarallel
from pandarallel import pandarallel
pandarallel.initialize(nb_workers=num_processors-1, use_memory_fs=False)
# Out:
# Available CPUs: 8
# INFO: Pandarallel will run on 7 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %% [markdown]
# -----
# ## Retrieval Dataframe

# %%
df_messages=pd.read_csv('gs://user-scripts-msca310019-capstone-49b3/data/20231009_Emails_with_Previous_as_List.csv', parse_dates=['time'])
df_messages.head(5)
# Out:
#    Unnamed: 0  Email_ID                       time   subject  thread  sender  \
# 0           0         0  1999-06-09 04:18:00-07:00  RE: test       2    5552
# 1           1         1  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 2           2         2  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 3           3         3  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 4           4         4  1999-06-09 08:06:00-07:00  RE: test       2   40034
#
#   repliers  \
# 0  [40034]
# 1   [5552]
# 2   [5552]
# 3   [5552]
# 4   [5552]
#
#                                                                                                message  \
# 0  How about this Friday ? Julie has not left yet. She was 2 days away from leaving to start school...
# 1                                                   when? how are you and your family? is julie gone?
# 2                                                   when? how are you and your family? is julie gone?
# 3                                                   when? how are you and your family? is julie gone?
# 4                                                   when? how are you and your family? is julie gone?
#
#                   reply_time  replier reply_recipient  \
# 0  1999-06-09 08:06:00-07:00    40034          [5552]
# 1  1999-06-10 03:54:00-07:00     5552         [40034]
# 2  1999-11-23 01:38:00-08:00     5552         [40034]
# 3  1999-11-23 03:13:00-08:00     5552         [40034]
# 4  1999-11-23 03:58:00-08:00     5552         [40034]
#
#                                                                             reply_message  \
# 0                                      when? how are you and your family? is julie gone?
# 1                                                Today is bad. Tommorrow I will call you.
# 2                                                          Do you have lunch plans today?
# 3  Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs.
# 4                                                            Tues.is good. I'll call you.
#
#                                                                                 Sender_Receiver_Emails
# 0                                                                                                  NaN
# 1  ['Do you have lunch plans today?', "Really? I'd feel like a mooch. Lets have lunch next week. An...
# 2  ['Today is bad. Tommorrow I will call you.', "Really? I'd feel like a mooch. Lets have lunch nex...
# 3  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Tues.is good. I'...
# 4  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Really? I'd feel...

# %%
df_messages['Sender_Receiver_Emails_list'] = df_messages['Sender_Receiver_Emails'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])

# %%
# df_messages['num_relevant_emails']=df_messages['Sender_Receiver_Emails'].apply(lambda x: len(x))
df_messages['num_relevant_emails'] = df_messages['Sender_Receiver_Emails_list'].apply(lambda x: len(x) if isinstance(x, list) else np.nan)
df_messages.head()
# Out:
#    Unnamed: 0  Email_ID                       time   subject  thread  sender  \
# 0           0         0  1999-06-09 04:18:00-07:00  RE: test       2    5552
# 1           1         1  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 2           2         2  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 3           3         3  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 4           4         4  1999-06-09 08:06:00-07:00  RE: test       2   40034
#
#   repliers  \
# 0  [40034]
# 1   [5552]
# 2   [5552]
# 3   [5552]
# 4   [5552]
#
#                                                                                                message  \
# 0  How about this Friday ? Julie has not left yet. She was 2 days away from leaving to start school...
# 1                                                   when? how are you and your family? is julie gone?
# 2                                                   when? how are you and your family? is julie gone?
# 3                                                   when? how are you and your family? is julie gone?
# 4                                                   when? how are you and your family? is julie gone?
#
#                   reply_time  replier reply_recipient  \
# 0  1999-06-09 08:06:00-07:00    40034          [5552]
# 1  1999-06-10 03:54:00-07:00     5552         [40034]
# 2  1999-11-23 01:38:00-08:00     5552         [40034]
# 3  1999-11-23 03:13:00-08:00     5552         [40034]
# 4  1999-11-23 03:58:00-08:00     5552         [40034]
#
#                                                                             reply_message  \
# 0                                      when? how are you and your family? is julie gone?
# 1                                                Today is bad. Tommorrow I will call you.
# 2                                                          Do you have lunch plans today?
# 3  Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs.
# 4                                                            Tues.is good. I'll call you.
#
#                                                                                 Sender_Receiver_Emails  \
# 0                                                                                                  NaN
# 1  ['Do you have lunch plans today?', "Really? I'd feel like a mooch. Lets have lunch next week. An...
# 2  ['Today is bad. Tommorrow I will call you.', "Really? I'd feel like a mooch. Lets have lunch nex...
# 3  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Tues.is good. I'...
# 4  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Really? I'd feel...
#
#                                                                            Sender_Receiver_Emails_list  \
# 0                                                                                                   []
# 1  [Do you have lunch plans today?, Really? I'd feel like a mooch. Lets have lunch next week. Any d...
# 2  [Today is bad. Tommorrow I will call you., Really? I'd feel like a mooch. Lets have lunch next w...
# 3  [Today is bad. Tommorrow I will call you., Do you have lunch plans today?, Tues.is good. I'll ca...
# 4  [Today is bad. Tommorrow I will call you., Do you have lunch plans today?, Really? I'd feel like...
#
#    num_relevant_emails
# 0                    0
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %%
df_messages['sender']=df_messages['sender'].astype('str')
df_messages['replier']=df_messages['replier'].astype('str')

# %%
df_messages['sender_replier_thread'] = df_messages['sender'].str.cat(df_messages['replier'], sep='-')
# df_messages['sender_receiver_thread'] = df_messages['sender_receiver_thread'].str.cat(df_messages['thread'], sep='-')

# %%
pd.set_option('display.max_colwidth', 500)
df_messages.Sender_Receiver_Emails_list.head(30)
df_messages[['sender_replier_thread','Sender_Receiver_Emails','num_relevant_emails']].iloc[15]
# Out:
# sender_replier_thread                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                37911-43
# Sender_Receiver_Emails    ['try having no work to do for two months and then having to stick around and "appear" busy  i know what you mean, in some ways its harder when you\'re not used to not doing things. i\'ve gotten good at finding things to do with my time, but when i first had nothing to do, i was going crazy. fridays are always slow around here and i\'m guessing its the same there, although i don\'t know cnrl specifcally, oil and gas producer/marketer? in terms of what i do, before enron went under, i was the...
# num_relevant_emails                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         5
# Name: 15, dtype: object

# %% [markdown]
# ### De-Duplication for Retrieval ##

# %%
df_messages_deduped=df_messages.drop_duplicates(subset='sender_replier_thread', keep='last')

# %% [markdown]
# -----
# ## Ranking Framework

# %%
# Importing Packages
import chromadb
from chromadb.utils import embedding_functions

import langchain
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain

# %%
# Setting Up Client
chroma_client = chromadb.PersistentClient(path="vectorstores")
chroma_client.heartbeat()
# Out:
# 1697749006686654913

# %%
# Defining the Embedding Function
openai_ef = embedding_functions.OpenAIEmbeddingFunction(api_key = openai_api_key,
                                                        model_name="text-embedding-ada-002")
openai_ef

# %% [markdown]
# ----
# ## Langchain Function v2

# %%
# Email Environment
sender_id='171'
replier_id='414'
sender_email='Where is my gift?'
email_dataset=df_messages_deduped
vector_db_client=chroma_client

# %%
async def get_email_response_personalized(sender_id=sender_id,
                                    replier_id=replier_id,
                                    sender_email=sender_email,
                                    email_dataset=df_messages_deduped,
                                    api_key=openai_api_key,
                                    vector_db_client=chroma_client,
                                    embedding_function=OpenAIEmbeddings()):
    
    # First getting retrieved emails to understand conversation --------
    sender_replier_id='-'.join([sender_id, replier_id])
    previous_emails=(email_dataset[email_dataset.sender_replier_thread==sender_replier_id]['Sender_Receiver_Emails_list']).to_list()[0][-10:]
    previous_emails
    # Second, getting ranked responses as per context ------------------
        
        # Building the Langchain vectorstore using chroma collections
    user_vector_store = Chroma(
        client=vector_db_client, 
        collection_name='user'+str(replier_id),
        embedding_function=OpenAIEmbeddings())
        # Getting ranked responses using MMR
    found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
    list_rel_emails=[]
    for i, doc in enumerate(found_rel_emails):
        list_rel_emails.append(doc.page_content)
    list_rel_emails
        
    # Setting up LangChain
    llm=ChatOpenAI(temperature=0.1, model=llm_model, openai_api_key=openai_api_key)
    template_string="""Create a response to the following email {sender_email}, deriving context from these relevant emails {relevant_emails} ,using a conversation style similar to following past emails between these 2 users {prev_emails}"""
    prompt_template = ChatPromptTemplate.from_template(template=template_string)    
    llm_chain=LLMChain(llm=llm, prompt=prompt_template)
    print(llm_chain.run(sender_email=sender_email, prev_emails=previous_emails, relevant_emails=list_rel_emails))

# %%
results = await get_email_response_personalized(sender_id=sender_id,
                                    replier_id=replier_id,
                                    sender_email=sender_email,
                                    email_dataset=df_messages_deduped,
                                    api_key=openai_api_key,
                                    vector_db_client=chroma_client,
                                    embedding_function=OpenAIEmbeddings())
print(results)

# %%
import pandas as pd
import ast
import chromadb
from chromadb.utils import embedding_functions
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
import asyncio

# Load the data
df_messages=pd.read_csv('gs://user-scripts-msca310019-capstone-49b3/data/20231009_Emails_with_Previous_as_List.csv', parse_dates=['time'])
df_messages['Sender_Receiver_Emails_list'] = df_messages['Sender_Receiver_Emails'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])
df_messages['sender'] = df_messages['sender'].astype('str')
df_messages['replier'] = df_messages['replier'].astype('str')
df_messages['sender_replier_thread'] = df_messages['sender'].str.cat(df_messages['replier'], sep='-')
df_messages_deduped = df_messages.drop_duplicates(subset='sender_replier_thread', keep='last')

# Setting up the chroma client
chroma_client = chromadb.PersistentClient(path="vectorstores")
openai_api_key = openai_api_key

async def get_email_response_personalized(sender_id, replier_id, sender_email, email_dataset, api_key, vector_db_client):    
    # First getting retrieved emails to understand conversation --------
    sender_replier_id='-'.join([sender_id, replier_id])
    previous_emails=(email_dataset[email_dataset.sender_replier_thread==sender_replier_id]['Sender_Receiver_Emails_list']).to_list()[0][-10:]
    previous_emails
    # Second, getting ranked responses as per context ------------------
        
        # Building the Langchain vectorstore using chroma collections
    user_vector_store = Chroma(
        client=vector_db_client, 
        collection_name='user'+str(replier_id),
        embedding_function=OpenAIEmbeddings())
        # Getting ranked responses using MMR
    found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
    list_rel_emails=[]
    for i, doc in enumerate(found_rel_emails):
        list_rel_emails.append(doc.page_content)
    list_rel_emails
        
    # Setting up LangChain
    llm=ChatOpenAI(temperature=0.1, model=llm_model, openai_api_key=openai_api_key)
    template_string="""Create a response to the following email {sender_email}, deriving context from these relevant emails {relevant_emails} ,using a conversation style similar to following past emails between these 2 users {prev_emails}"""
    prompt_template = ChatPromptTemplate.from_template(template=template_string)    
    llm_chain=LLMChain(llm=llm, prompt=prompt_template)
    return (llm_chain.run(sender_email=sender_email, prev_emails=previous_emails, relevant_emails=list_rel_emails))
    

async def process_all_emails(df):
    responses = []
    for index, row in df.iterrows():
        response = await get_email_response_personalized(row['sender'], row['replier'], row['message'], df, openai_api_key, chroma_client)
        responses.append(response)
    return responses

# Run the asynchronous function and get all the responses
all_responses = await process_all_emails(df_messages_deduped)

# Append the responses to the original dataframe
df_messages_deduped['responses'] = all_responses
# Out:
# Add of existing embedding ID: 0
# Number of requested results 10 is greater than number of elements in index 1, updating n_results = 1
# Add of existing embedding ID: 1
# Add of existing embedding ID: 2
# Add of existing embedding ID: 3
# Add of existing embedding ID: 4
# Add of existing embedding ID: 4611
# Add of existing embedding ID: 7630
# Add of existing embedding ID: 7686
# Add of existing embedding ID: 8093
# Add of existing embedding ID: 9249
# Add of existing embedding ID: 9294
# Add of existing embedding ID: 9390
# Add of existing embedding ID: 9397
# Add of existing embedding ID: 12262
# Add of existing embedding ID: 12263
# Add of existing embedding ID: 12293
# Add of existing embedding ID: 12304
# Add of existing embedding ID: 12329
# Add of existing embedding ID: 12334
# Add of existing embedding ID: 13059
# Add of existing embedding ID: 16187
# Add of existing embedding ID: 16188
# Add of existing embedding ID: 18535
# Add of existing embedding ID: 19926
# Add of existing embedding ID: 19948
# Add of existing embedding ID: 19949
# Add of existing embedding ID: 22024
# Add of existing embedding ID: 22049
# Add of existing embedding ID: 22050
# Add of existing embedding ID: 22217
# Add of existing embedding ID: 22224
# Add of existing embedding ID: 22225
# Add of existing embedding ID: 22228
# Add of existing embedding ID: 22231
# Add of existing embedding ID: 22237
# Add of existing embedding ID: 22240
# Add of existing embedding ID: 22244
# Add of existing embedding ID: 22245
# Add of existing embedding ID: 22262
# Add of existing embedding ID: 22268
# Add of existing embedding ID: 22269
# Add of existing embedding ID: 22272
# Add of existing embedding ID: 22273
# Add of existing embedding ID: 22274
# Add of existing embedding ID: 22279
# Add of existing embedding ID: 22281
# Add of existing embedding ID: 22290
# Add of existing embedding ID: 22297
# Add of existing embedding ID: 22299
# Add of existing embedding ID: 22309
# Add of existing embedding ID: 22314
# Add of existing embedding ID: 1
# Add of existing embedding ID: 2
# Add of existing embedding ID: 3
# Add of existing embedding ID: 4
# Add of existing embedding ID: 4611
# Add of existing embedding ID: 7630
# Add of existing embedding ID: 7686
# Add of existing embedding ID: 8093
# Add of existing embedding ID: 9249
# Add of existing embedding ID: 9294
# Add of existing embedding ID: 9390
# Add of existing embedding ID: 9397
# Add of existing embedding ID: 12262
# Add of existing embedding ID: 12263
# Add of existing embedding ID: 12293
# Add of existing embedding ID: 12304
# Add of existing embedding ID: 12329
# Add of existing embedding ID: 12334
# Add of existing embedding ID: 13059
# Add of existing embedding ID: 16187
# Add of existing embedding ID: 16188
# Add of existing embedding ID: 18535
# Add of existing embedding ID: 19926
# Add of existing embedding ID: 19948
# Add of existing embedding ID: 19949
# Add of existing embedding ID: 22024
# Add of existing embedding ID: 22049
# Add of existing embedding ID: 22050
# Add of existing embedding ID: 22217
# Add of existing embedding ID: 22224
# Add of existing embedding ID: 22225
# Add of existing embedding ID: 22228
# Add of existing embedding ID: 22231
# Add of existing embedding ID: 22237
# Add of existing embedding ID: 22240
# Add of existing embedding ID: 22244
# Add of existing embedding ID: 22245
# Add of existing embedding ID: 22262
# Add of existing embedding ID: 22268
# Add of existing embedding ID: 22269
# Add of existing embedding ID: 22272
# Add of existing embedding ID: 22273
# Add of existing embedding ID: 22274
# Add of existing embedding ID: 22279
# Add of existing embedding ID: 22281
# Add of existing embedding ID: 22290
# Add of existing embedding ID: 22297
# Add of existing embedding ID: 22299
# Add of existing embedding ID: 22309
# Add of existing embedding ID: 22314
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Add of existing embedding ID: 17
# Add of existing embedding ID: 251
# Add of existing embedding ID: 382
# Add of existing embedding ID: 1642
# Add of existing embedding ID: 1645
# Add of existing embedding ID: 1953
# Add of existing embedding ID: 2122
# Add of existing embedding ID: 2144
# Add of existing embedding ID: 2150
# Add of existing embedding ID: 2844
# Add of existing embedding ID: 3251
# Add of existing embedding ID: 3481
# Add of existing embedding ID: 3533
# Add of existing embedding ID: 4004
# Add of existing embedding ID: 4045
# Add of existing embedding ID: 4084
# Add of existing embedding ID: 4085
# Add of existing embedding ID: 4095
# Add of existing embedding ID: 4389
# Add of existing embedding ID: 4390
# Add of existing embedding ID: 4392
# Add of existing embedding ID: 4395
# Add of existing embedding ID: 4398
# Add of existing embedding ID: 4401
# Add of existing embedding ID: 4402
# Add of existing embedding ID: 4510
# Add of existing embedding ID: 4535
# Add of existing embedding ID: 4981
# Add of existing embedding ID: 5511
# Add of existing embedding ID: 5619
# Add of existing embedding ID: 5899
# Add of existing embedding ID: 5900
# Add of existing embedding ID: 5901
# Add of existing embedding ID: 6754
# Add of existing embedding ID: 6757
# Add of existing embedding ID: 8139
# Add of existing embedding ID: 8141
# Add of existing embedding ID: 9251
# Add of existing embedding ID: 10923
# Add of existing embedding ID: 10925
# Add of existing embedding ID: 11234
# Add of existing embedding ID: 11236
# Add of existing embedding ID: 11239
# Add of existing embedding ID: 11243
# Add of existing embedding ID: 11284
# Add of existing embedding ID: 11287
# Add of existing embedding ID: 11288
# Add of existing embedding ID: 11300
# Add of existing embedding ID: 11575
# Add of existing embedding ID: 11584
# Add of existing embedding ID: 13313
# Add of existing embedding ID: 13467
# Add of existing embedding ID: 13471
# Add of existing embedding ID: 13472
# Add of existing embedding ID: 13567
# Add of existing embedding ID: 14230
# Add of existing embedding ID: 15945
# Add of existing embedding ID: 16633
# Add of existing embedding ID: 16636
# Add of existing embedding ID: 17029
# Add of existing embedding ID: 17842
# Add of existing embedding ID: 17844
# Add of existing embedding ID: 17846
# Add of existing embedding ID: 17848
# Add of existing embedding ID: 17849
# Add of existing embedding ID: 17850
# Add of existing embedding ID: 17851
# Add of existing embedding ID: 17852
# Add of existing embedding ID: 17853
# Add of existing embedding ID: 17855
# Add of existing embedding ID: 17857
# Add of existing embedding ID: 17858
# Add of existing embedding ID: 17860
# Add of existing embedding ID: 17862
# Add of existing embedding ID: 17871
# Add of existing embedding ID: 17875
# Add of existing embedding ID: 17877
# Add of existing embedding ID: 17878
# Add of existing embedding ID: 17880
# Add of existing embedding ID: 17882
# Add of existing embedding ID: 17888
# Add of existing embedding ID: 17890
# Add of existing embedding ID: 17892
# Add of existing embedding ID: 17896
# Add of existing embedding ID: 17900
# Add of existing embedding ID: 17901
# Add of existing embedding ID: 17904
# Add of existing embedding ID: 17907
# Add of existing embedding ID: 17908
# Add of existing embedding ID: 17909
# Add of existing embedding ID: 17914
# Add of existing embedding ID: 17915
# Add of existing embedding ID: 17921
# Add of existing embedding ID: 17923
# Add of existing embedding ID: 17924
# Add of existing embedding ID: 17928
# Add of existing embedding ID: 17930
# Add of existing embedding ID: 17933
# Add of existing embedding ID: 17934
# Add of existing embedding ID: 17935
# Add of existing embedding ID: 17936
# Add of existing embedding ID: 17937
# Add of existing embedding ID: 17938
# Add of existing embedding ID: 17941
# Add of existing embedding ID: 17943
# Add of existing embedding ID: 17945
# Add of existing embedding ID: 17946
# Add of existing embedding ID: 17950
# Add of existing embedding ID: 17952
# Add of existing embedding ID: 17953
# Add of existing embedding ID: 17955
# Add of existing embedding ID: 17956
# Add of existing embedding ID: 17958
# Add of existing embedding ID: 17959
# Add of existing embedding ID: 17961
# Add of existing embedding ID: 17962
# Add of existing embedding ID: 17963
# Add of existing embedding ID: 17968
# Add of existing embedding ID: 17970
# Add of existing embedding ID: 17972
# Add of existing embedding ID: 17973
# Add of existing embedding ID: 17975
# Add of existing embedding ID: 17977
# Add of existing embedding ID: 17979
# Add of existing embedding ID: 17982
# Add of existing embedding ID: 17983
# Add of existing embedding ID: 17986
# Add of existing embedding ID: 17988
# Add of existing embedding ID: 17989
# Add of existing embedding ID: 17990
# Add of existing embedding ID: 17992
# Add of existing embedding ID: 17993
# Add of existing embedding ID: 17994
# Add of existing embedding ID: 17996
# Add of existing embedding ID: 17997
# Add of existing embedding ID: 18003
# Add of existing embedding ID: 18007
# Add of existing embedding ID: 18009
# Add of existing embedding ID: 18011
# Add of existing embedding ID: 18013
# Add of existing embedding ID: 18017
# Add of existing embedding ID: 18019
# Add of existing embedding ID: 18021
# Add of existing embedding ID: 18028
# Add of existing embedding ID: 18029
# Add of existing embedding ID: 18033
# Add of existing embedding ID: 18035
# Add of existing embedding ID: 18037
# Add of existing embedding ID: 18039
# Add of existing embedding ID: 18041
# Add of existing embedding ID: 18043
# Add of existing embedding ID: 18045
# Add of existing embedding ID: 18049
# Add of existing embedding ID: 18051
# Add of existing embedding ID: 18052
# Add of existing embedding ID: 18054
# Add of existing embedding ID: 18057
# Add of existing embedding ID: 18058
# Add of existing embedding ID: 18059
# Add of existing embedding ID: 18060
# Add of existing embedding ID: 18062
# Add of existing embedding ID: 18064
# Add of existing embedding ID: 18066
# Add of existing embedding ID: 18067
# Add of existing embedding ID: 18068
# Add of existing embedding ID: 18069
# Add of existing embedding ID: 18070
# Add of existing embedding ID: 18073
# Add of existing embedding ID: 18075
# Add of existing embedding ID: 18077
# Add of existing embedding ID: 18079
# Add of existing embedding ID: 18081
# Add of existing embedding ID: 18082
# Add of existing embedding ID: 18084
# Add of existing embedding ID: 18087
# Add of existing embedding ID: 18089
# Add of existing embedding ID: 18090
# Add of existing embedding ID: 18095
# Add of existing embedding ID: 18097
# Add of existing embedding ID: 18098
# Add of existing embedding ID: 18100
# Add of existing embedding ID: 18103
# Add of existing embedding ID: 18104
# Add of existing embedding ID: 18106
# Add of existing embedding ID: 18108
# Add of existing embedding ID: 18110
# Add of existing embedding ID: 18111
# Add of existing embedding ID: 18114
# Add of existing embedding ID: 18117
# Add of existing embedding ID: 18118
# Add of existing embedding ID: 18120
# Add of existing embedding ID: 18121
# Add of existing embedding ID: 18122
# Add of existing embedding ID: 18127
# Add of existing embedding ID: 18129
# Add of existing embedding ID: 18130
# Add of existing embedding ID: 18133
# Add of existing embedding ID: 18135
# Add of existing embedding ID: 18137
# Add of existing embedding ID: 18138
# Add of existing embedding ID: 18139
# Add of existing embedding ID: 18140
# Add of existing embedding ID: 18143
# Add of existing embedding ID: 18144
# Add of existing embedding ID: 18145
# Add of existing embedding ID: 18147
# Add of existing embedding ID: 18149
# Add of existing embedding ID: 18151
# Add of existing embedding ID: 18152
# Add of existing embedding ID: 18156
# Add of existing embedding ID: 18157
# Add of existing embedding ID: 18158
# Add of existing embedding ID: 18160
# Add of existing embedding ID: 18163
# Add of existing embedding ID: 18165
# Add of existing embedding ID: 18167
# Add of existing embedding ID: 18168
# Add of existing embedding ID: 18171
# Add of existing embedding ID: 18174
# Add of existing embedding ID: 18175
# Add of existing embedding ID: 18179
# Add of existing embedding ID: 18181
# Add of existing embedding ID: 18182
# Add of existing embedding ID: 18184
# Add of existing embedding ID: 18191
# Add of existing embedding ID: 18193
# Add of existing embedding ID: 18198
# Add of existing embedding ID: 18199
# Add of existing embedding ID: 18201
# Add of existing embedding ID: 18203
# Add of existing embedding ID: 18205
# Add of existing embedding ID: 18208
# Add of existing embedding ID: 18210
# Add of existing embedding ID: 18211
# Add of existing embedding ID: 18213
# Add of existing embedding ID: 18215
# Add of existing embedding ID: 18217
# Add of existing embedding ID: 18218
# Add of existing embedding ID: 18219
# Add of existing embedding ID: 18220
# Add of existing embedding ID: 18222
# Add of existing embedding ID: 18225
# Add of existing embedding ID: 18226
# Add of existing embedding ID: 18227
# Add of existing embedding ID: 18229
# Add of existing embedding ID: 18230
# Add of existing embedding ID: 18232
# Add of existing embedding ID: 18233
# Add of existing embedding ID: 18235
# Add of existing embedding ID: 18238
# Add of existing embedding ID: 18240
# Add of existing embedding ID: 18241
# Add of existing embedding ID: 18243
# Add of existing embedding ID: 18244
# Add of existing embedding ID: 18247
# Add of existing embedding ID: 18249
# Add of existing embedding ID: 18251
# Add of existing embedding ID: 18253
# Add of existing embedding ID: 18254
# Add of existing embedding ID: 18257
# Add of existing embedding ID: 18261
# Add of existing embedding ID: 18264
# Add of existing embedding ID: 18268
# Add of existing embedding ID: 18270
# Add of existing embedding ID: 18271
# Add of existing embedding ID: 18277
# Add of existing embedding ID: 18278
# Add of existing embedding ID: 18281
# Add of existing embedding ID: 18284
# Add of existing embedding ID: 18286
# Add of existing embedding ID: 18289
# Add of existing embedding ID: 18291
# Add of existing embedding ID: 18293
# Add of existing embedding ID: 18299
# Add of existing embedding ID: 18301
# Add of existing embedding ID: 18302
# Add of existing embedding ID: 18304
# Add of existing embedding ID: 18307
# Add of existing embedding ID: 18309
# Add of existing embedding ID: 18313
# Add of existing embedding ID: 18314
# Add of existing embedding ID: 18317
# Add of existing embedding ID: 18319
# Add of existing embedding ID: 18320
# Add of existing embedding ID: 18323
# Add of existing embedding ID: 18324
# Add of existing embedding ID: 18325
# Add of existing embedding ID: 18327
# Add of existing embedding ID: 18331
# Add of existing embedding ID: 18333
# Add of existing embedding ID: 18335
# Add of existing embedding ID: 18337
# Add of existing embedding ID: 18339
# Add of existing embedding ID: 18343
# Add of existing embedding ID: 18344
# Add of existing embedding ID: 18345
# Add of existing embedding ID: 18347
# Add of existing embedding ID: 18351
# Add of existing embedding ID: 18353
# Add of existing embedding ID: 18356
# Add of existing embedding ID: 18358
# Add of existing embedding ID: 18361
# Add of existing embedding ID: 18363
# Add of existing embedding ID: 18367
# Add of existing embedding ID: 18370
# Add of existing embedding ID: 18377
# Add of existing embedding ID: 18379
# Add of existing embedding ID: 18382
# Add of existing embedding ID: 18383
# Add of existing embedding ID: 18386
# Add of existing embedding ID: 18387
# Add of existing embedding ID: 18389
# Add of existing embedding ID: 18390
# Add of existing embedding ID: 18392
# Add of existing embedding ID: 18396
# Add of existing embedding ID: 18397
# Add of existing embedding ID: 18398
# Add of existing embedding ID: 18403
# Add of existing embedding ID: 18404
# Add of existing embedding ID: 18405
# Add of existing embedding ID: 18406
# Add of existing embedding ID: 18408
# Add of existing embedding ID: 18410
# Add of existing embedding ID: 18414
# Add of existing embedding ID: 18416
# Add of existing embedding ID: 18417
# Add of existing embedding ID: 18418
# Add of existing embedding ID: 18420
# Add of existing embedding ID: 18421
# Add of existing embedding ID: 18422
# Add of existing embedding ID: 18423
# Add of existing embedding ID: 18424
# Add of existing embedding ID: 18425
# Add of existing embedding ID: 18427
# Add of existing embedding ID: 18428
# Add of existing embedding ID: 18430
# Add of existing embedding ID: 18432
# Add of existing embedding ID: 18434
# Add of existing embedding ID: 18440
# Add of existing embedding ID: 18442
# Add of existing embedding ID: 18445
# Add of existing embedding ID: 18446
# Add of existing embedding ID: 18447
# Add of existing embedding ID: 18449
# Add of existing embedding ID: 18453
# Add of existing embedding ID: 18454
# Add of existing embedding ID: 18455
# Add of existing embedding ID: 18456
# Add of existing embedding ID: 18457
# Add of existing embedding ID: 18458
# Add of existing embedding ID: 18460
# Add of existing embedding ID: 18462
# Add of existing embedding ID: 18464
# Add of existing embedding ID: 18465
# Add of existing embedding ID: 18466
# Add of existing embedding ID: 18470
# Add of existing embedding ID: 18472
# Add of existing embedding ID: 18474
# Add of existing embedding ID: 18481
# Add of existing embedding ID: 18482
# Add of existing embedding ID: 18484
# Add of existing embedding ID: 18485
# Add of existing embedding ID: 18486
# Add of existing embedding ID: 18488
# Add of existing embedding ID: 18494
# Add of existing embedding ID: 18496
# Add of existing embedding ID: 18499
# Add of existing embedding ID: 18502
# Add of existing embedding ID: 18503
# Add of existing embedding ID: 18504
# Add of existing embedding ID: 18506
# Add of existing embedding ID: 18510
# Add of existing embedding ID: 18512
# Add of existing embedding ID: 18516
# Add of existing embedding ID: 18521
# Add of existing embedding ID: 18523
# Add of existing embedding ID: 18524
# Add of existing embedding ID: 18526
# Add of existing embedding ID: 18528
# Add of existing embedding ID: 18530
# Add of existing embedding ID: 18531
# Add of existing embedding ID: 18536
# Add of existing embedding ID: 18537
# Add of existing embedding ID: 18539
# Add of existing embedding ID: 18540
# Add of existing embedding ID: 18543
# Add of existing embedding ID: 18544
# Add of existing embedding ID: 18546
# Add of existing embedding ID: 18547
# Add of existing embedding ID: 18549
# Add of existing embedding ID: 18550
# Add of existing embedding ID: 18552
# Add of existing embedding ID: 18553
# Add of existing embedding ID: 18554
# Add of existing embedding ID: 18555
# Add of existing embedding ID: 18557
# Add of existing embedding ID: 18563
# Add of existing embedding ID: 18564
# Add of existing embedding ID: 18565
# Add of existing embedding ID: 18566
# Add of existing embedding ID: 18571
# Add of existing embedding ID: 18572
# Add of existing embedding ID: 18574
# Add of existing embedding ID: 18575
# Add of existing embedding ID: 18576
# Add of existing embedding ID: 18577
# Add of existing embedding ID: 18578
# Add of existing embedding ID: 18579
# Add of existing embedding ID: 18581
# Add of existing embedding ID: 18582
# Add of existing embedding ID: 18583
# Add of existing embedding ID: 18585
# Add of existing embedding ID: 18586
# Add of existing embedding ID: 18588
# Add of existing embedding ID: 18589
# Add of existing embedding ID: 18593
# Add of existing embedding ID: 18594
# Add of existing embedding ID: 18595
# Add of existing embedding ID: 18600
# Add of existing embedding ID: 18601
# Add of existing embedding ID: 18602
# Add of existing embedding ID: 18606
# Add of existing embedding ID: 18611
# Add of existing embedding ID: 18619
# Add of existing embedding ID: 18620
# Add of existing embedding ID: 18623
# Add of existing embedding ID: 18624
# Add of existing embedding ID: 18626
# Add of existing embedding ID: 18628
# Add of existing embedding ID: 18631
# Add of existing embedding ID: 18633
# Add of existing embedding ID: 18634
# Add of existing embedding ID: 18637
# Add of existing embedding ID: 18639
# Add of existing embedding ID: 18641
# Add of existing embedding ID: 18643
# Add of existing embedding ID: 18646
# Add of existing embedding ID: 18648
# Add of existing embedding ID: 18650
# Add of existing embedding ID: 18651
# Add of existing embedding ID: 18653
# Add of existing embedding ID: 18657
# Add of existing embedding ID: 18659
# Add of existing embedding ID: 18664
# Add of existing embedding ID: 18666
# Add of existing embedding ID: 18667
# Add of existing embedding ID: 18669
# Add of existing embedding ID: 18670
# Add of existing embedding ID: 18671
# Add of existing embedding ID: 18672
# Add of existing embedding ID: 18674
# Add of existing embedding ID: 18675
# Add of existing embedding ID: 18677
# Add of existing embedding ID: 18679
# Add of existing embedding ID: 18681
# Add of existing embedding ID: 18682
# Add of existing embedding ID: 18683
# Add of existing embedding ID: 18688
# Add of existing embedding ID: 18689
# Add of existing embedding ID: 18690
# Add of existing embedding ID: 18692
# Add of existing embedding ID: 18693
# Add of existing embedding ID: 18698
# Add of existing embedding ID: 18699
# Add of existing embedding ID: 18702
# Add of existing embedding ID: 18704
# Add of existing embedding ID: 18705
# Add of existing embedding ID: 18706
# Add of existing embedding ID: 18708
# Add of existing embedding ID: 18713
# Add of existing embedding ID: 18715
# Add of existing embedding ID: 18716
# Add of existing embedding ID: 18717
# Add of existing embedding ID: 18719
# Add of existing embedding ID: 18721
# Add of existing embedding ID: 18723
# Add of existing embedding ID: 18724
# Add of existing embedding ID: 18729
# Add of existing embedding ID: 18730
# Add of existing embedding ID: 18734
# Add of existing embedding ID: 18767
# Add of existing embedding ID: 18780
# Add of existing embedding ID: 18782
# Add of existing embedding ID: 18784
# Add of existing embedding ID: 18786
# Add of existing embedding ID: 18789
# Add of existing embedding ID: 18791
# Add of existing embedding ID: 18793
# Add of existing embedding ID: 18794
# Add of existing embedding ID: 18796
# Add of existing embedding ID: 18797
# Add of existing embedding ID: 18798
# Add of existing embedding ID: 18801
# Add of existing embedding ID: 18803
# Add of existing embedding ID: 18805
# Add of existing embedding ID: 18808
# Add of existing embedding ID: 18810
# Add of existing embedding ID: 18812
# Add of existing embedding ID: 18814
# Add of existing embedding ID: 18815
# Add of existing embedding ID: 18816
# Add of existing embedding ID: 18819
# Add of existing embedding ID: 18821
# Add of existing embedding ID: 18823
# Add of existing embedding ID: 18825
# Add of existing embedding ID: 18827
# Add of existing embedding ID: 18828
# Add of existing embedding ID: 18829
# Add of existing embedding ID: 18830
# Add of existing embedding ID: 18832
# Add of existing embedding ID: 18835
# Add of existing embedding ID: 18837
# Add of existing embedding ID: 18838
# Add of existing embedding ID: 18842
# Add of existing embedding ID: 18844
# Add of existing embedding ID: 18845
# Add of existing embedding ID: 18847
# Add of existing embedding ID: 18849
# Add of existing embedding ID: 18852
# Add of existing embedding ID: 18853
# Add of existing embedding ID: 18855
# Add of existing embedding ID: 18856
# Add of existing embedding ID: 18860
# Add of existing embedding ID: 18862
# Add of existing embedding ID: 18865
# Add of existing embedding ID: 18866
# Add of existing embedding ID: 18867
# Add of existing embedding ID: 18868
# Add of existing embedding ID: 18869
# Add of existing embedding ID: 18870
# Add of existing embedding ID: 18872
# Add of existing embedding ID: 18876
# Add of existing embedding ID: 18878
# Add of existing embedding ID: 18880
# Add of existing embedding ID: 18882
# Add of existing embedding ID: 18885
# Add of existing embedding ID: 18888
# Add of existing embedding ID: 18889
# Add of existing embedding ID: 18891
# Add of existing embedding ID: 18893
# Add of existing embedding ID: 18896
# Add of existing embedding ID: 18898
# Add of existing embedding ID: 18901
# Add of existing embedding ID: 18903
# Add of existing embedding ID: 18904
# Add of existing embedding ID: 18910
# Add of existing embedding ID: 18912
# Add of existing embedding ID: 18914
# Add of existing embedding ID: 18915
# Add of existing embedding ID: 18917
# Add of existing embedding ID: 18918
# Add of existing embedding ID: 18920
# Add of existing embedding ID: 18922
# Add of existing embedding ID: 18924
# Add of existing embedding ID: 18925
# Add of existing embedding ID: 18926
# Add of existing embedding ID: 18928
# Add of existing embedding ID: 18931
# Add of existing embedding ID: 18932
# Add of existing embedding ID: 18933
# Add of existing embedding ID: 18934
# Add of existing embedding ID: 18936
# Add of existing embedding ID: 21277
# Add of existing embedding ID: 23627
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 8.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..
# Retrying langchain.embeddings.openai.embed_with_retry.<locals>._embed_with_retry in 4.0 seconds as it raised RateLimitError: Rate limit reached for text-embedding-ada-002 in organization org-3uPIm3xy4QJopNFYHTe9obWT on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method..

# %%
df_messages_deduped
