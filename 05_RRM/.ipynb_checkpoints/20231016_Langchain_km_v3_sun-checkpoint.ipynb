# %% [markdown]
# ## Langchain Integration

# %%
import openai
import os
import getpass

# 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
# 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

os.environ['OPENAI_API_KEY'] = getpass.getpass('OpenAI API Key:')
# Out:
# OpenAI API Key: ········

# %%
if 'OPENAI_API_KEY' in os.environ:
    openai_api_key = os.environ['OPENAI_API_KEY']
    print("OpenAI API Key:", openai_api_key)
else:
    print("OPENAI_API_KEY environment variable is not set.")
# Out:
# OpenAI API Key: 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

# %%
# account for deprecation of LLM model
import datetime
# Get the current date
current_date = datetime.datetime.now().date()

# Define the date after which the model should be set to "gpt-3.5-turbo"
target_date = datetime.date(2024, 6, 12)

# Set the model variable based on the current date
if current_date > target_date:
    llm_model = "gpt-3.5-turbo"
else:
    llm_model = "gpt-3.5-turbo-0301"

# %%
import pandas as pd
import numpy as np
import ast  # Import the ast module for literal evaluation
import seaborn as sns

pd.set_option('display.max_colwidth', 100)
# %pip install pandarallel
import multiprocessing

num_processors = multiprocessing.cpu_count()
print(f'Available CPUs: {num_processors}')

import pandarallel
from pandarallel import pandarallel
pandarallel.initialize(nb_workers=num_processors-1, use_memory_fs=False)
# Out:
# Available CPUs: 8
# INFO: Pandarallel will run on 7 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %% [markdown]
# -----
# ## Email Environment

# %%
sender_id='171'
replier_id='414'
sender_email='Where is my gift?'

# %% [markdown]
# -----
# ## Retrieval

# %%
df_messages=pd.read_csv('gs://user-scripts-msca310019-capstone-49b3/data/20231009_Emails_with_Previous_as_List.csv', parse_dates=['time'])
df_messages.head(5)
# Out:
#    Unnamed: 0  Email_ID                       time   subject  thread  sender  \
# 0           0         0  1999-06-09 04:18:00-07:00  RE: test       2    5552
# 1           1         1  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 2           2         2  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 3           3         3  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 4           4         4  1999-06-09 08:06:00-07:00  RE: test       2   40034
#
#   repliers  \
# 0  [40034]
# 1   [5552]
# 2   [5552]
# 3   [5552]
# 4   [5552]
#
#                                                                                                message  \
# 0  How about this Friday ? Julie has not left yet. She was 2 days away from leaving to start school...
# 1                                                   when? how are you and your family? is julie gone?
# 2                                                   when? how are you and your family? is julie gone?
# 3                                                   when? how are you and your family? is julie gone?
# 4                                                   when? how are you and your family? is julie gone?
#
#                   reply_time  replier reply_recipient  \
# 0  1999-06-09 08:06:00-07:00    40034          [5552]
# 1  1999-06-10 03:54:00-07:00     5552         [40034]
# 2  1999-11-23 01:38:00-08:00     5552         [40034]
# 3  1999-11-23 03:13:00-08:00     5552         [40034]
# 4  1999-11-23 03:58:00-08:00     5552         [40034]
#
#                                                                             reply_message  \
# 0                                      when? how are you and your family? is julie gone?
# 1                                                Today is bad. Tommorrow I will call you.
# 2                                                          Do you have lunch plans today?
# 3  Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs.
# 4                                                            Tues.is good. I'll call you.
#
#                                                                                 Sender_Receiver_Emails
# 0                                                                                                  NaN
# 1  ['Do you have lunch plans today?', "Really? I'd feel like a mooch. Lets have lunch next week. An...
# 2  ['Today is bad. Tommorrow I will call you.', "Really? I'd feel like a mooch. Lets have lunch nex...
# 3  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Tues.is good. I'...
# 4  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Really? I'd feel...

# %%
df_messages['Sender_Receiver_Emails_list'] = df_messages['Sender_Receiver_Emails'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])

# %%
# df_messages['num_relevant_emails']=df_messages['Sender_Receiver_Emails'].apply(lambda x: len(x))
df_messages['num_relevant_emails'] = df_messages['Sender_Receiver_Emails_list'].apply(lambda x: len(x) if isinstance(x, list) else np.nan)
df_messages.head()
# Out:
#    Unnamed: 0  Email_ID                       time   subject  thread  sender  \
# 0           0         0  1999-06-09 04:18:00-07:00  RE: test       2    5552
# 1           1         1  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 2           2         2  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 3           3         3  1999-06-09 08:06:00-07:00  RE: test       2   40034
# 4           4         4  1999-06-09 08:06:00-07:00  RE: test       2   40034
#
#   repliers  \
# 0  [40034]
# 1   [5552]
# 2   [5552]
# 3   [5552]
# 4   [5552]
#
#                                                                                                message  \
# 0  How about this Friday ? Julie has not left yet. She was 2 days away from leaving to start school...
# 1                                                   when? how are you and your family? is julie gone?
# 2                                                   when? how are you and your family? is julie gone?
# 3                                                   when? how are you and your family? is julie gone?
# 4                                                   when? how are you and your family? is julie gone?
#
#                   reply_time  replier reply_recipient  \
# 0  1999-06-09 08:06:00-07:00    40034          [5552]
# 1  1999-06-10 03:54:00-07:00     5552         [40034]
# 2  1999-11-23 01:38:00-08:00     5552         [40034]
# 3  1999-11-23 03:13:00-08:00     5552         [40034]
# 4  1999-11-23 03:58:00-08:00     5552         [40034]
#
#                                                                             reply_message  \
# 0                                      when? how are you and your family? is julie gone?
# 1                                                Today is bad. Tommorrow I will call you.
# 2                                                          Do you have lunch plans today?
# 3  Really? I'd feel like a mooch. Lets have lunch next week. Any day but Monday or Thurs.
# 4                                                            Tues.is good. I'll call you.
#
#                                                                                 Sender_Receiver_Emails  \
# 0                                                                                                  NaN
# 1  ['Do you have lunch plans today?', "Really? I'd feel like a mooch. Lets have lunch next week. An...
# 2  ['Today is bad. Tommorrow I will call you.', "Really? I'd feel like a mooch. Lets have lunch nex...
# 3  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Tues.is good. I'...
# 4  ['Today is bad. Tommorrow I will call you.', 'Do you have lunch plans today?', "Really? I'd feel...
#
#                                                                            Sender_Receiver_Emails_list  \
# 0                                                                                                   []
# 1  [Do you have lunch plans today?, Really? I'd feel like a mooch. Lets have lunch next week. Any d...
# 2  [Today is bad. Tommorrow I will call you., Really? I'd feel like a mooch. Lets have lunch next w...
# 3  [Today is bad. Tommorrow I will call you., Do you have lunch plans today?, Tues.is good. I'll ca...
# 4  [Today is bad. Tommorrow I will call you., Do you have lunch plans today?, Really? I'd feel like...
#
#    num_relevant_emails
# 0                    0
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %%
df_messages['sender']=df_messages['sender'].astype('str')
df_messages['replier']=df_messages['replier'].astype('str')
# df_messages['thread']=df_messages['thread'].astype('str')

# %%
df_messages['sender_replier_thread'] = df_messages['sender'].str.cat(df_messages['replier'], sep='-')
# df_messages['sender_receiver_thread'] = df_messages['sender_receiver_thread'].str.cat(df_messages['thread'], sep='-')

# %%
pd.set_option('display.max_colwidth', 500)
df_messages.Sender_Receiver_Emails_list.head(30)
df_messages[['sender_replier_thread','Sender_Receiver_Emails','num_relevant_emails']].iloc[15]
# Out:
# sender_replier_thread                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                37911-43
# Sender_Receiver_Emails    ['try having no work to do for two months and then having to stick around and "appear" busy  i know what you mean, in some ways its harder when you\'re not used to not doing things. i\'ve gotten good at finding things to do with my time, but when i first had nothing to do, i was going crazy. fridays are always slow around here and i\'m guessing its the same there, although i don\'t know cnrl specifcally, oil and gas producer/marketer? in terms of what i do, before enron went under, i was the...
# num_relevant_emails                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         5
# Name: 15, dtype: object

# %% [markdown]
# ### De-Duplication for Retrieval ##

# %%
df_messages_deduped=df_messages.drop_duplicates(subset='sender_replier_thread', keep='last')

# %%
df_messages_deduped[df_messages_deduped.sender_replier_thread.str.contains('414')].head(2)
# Out:
#      Unnamed: 0  Email_ID                       time subject  thread sender  \
# 404         404       416  2001-06-06 09:00:21-07:00     RE:     208    414
# 408         408       420  2001-06-06 12:25:50-07:00     RE:     208    171
#
#     repliers               message                 reply_time replier  \
# 404    [171]           absolutely   2001-06-06 12:25:50-07:00     171
# 408    [414]  should I be scared?   2001-06-08 08:35:05-07:00     414
#
#     reply_recipient         reply_message  \
# 404           [414]  should I be scared?
# 408           [171]   much better thanks
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Sender_Receiver_Emails  \
# 404  ["Thank you! I'm glad you're pleased! ", 'What do you have in mind on picking out? ', "Do you have good taste when it comes to picking out women's clothes? ", 'Then I guess I should trust you ', 'maybe I like trouble ', 'I knew you would like that ', 'I have it ', 'very soon ', 'You never know! ', "you'll get it ", 'yes it is ', 'because I said so ', 'Yes it is ', 'Is that a threat or a promise? ', 'on what? ', 'maybe ', 'now? ', "I'M SORRY ", "Do not Whatever me  Or you won't get your prese...
# 408  ['lets go buy another but I get to pick ', 'whatever I want ', 'absolutely ', 'always ', 'that was a good comeback ', 'by the way where is my present ', 'when do I get it ', 'as in hours days or weeks? ', 'how about a hint ', 'thats not a hint ', 'how ', 'not fair ', 'you are in trouble ', 'that depends ', 'yes, when ', 'ok ', 'you suck ', 'whatever ', 'we will have to throw him out ', 'I would rather wait ', 'are you doing anything ', 'why thats no good ', 'I FIGURED ', 'going across the st...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Sender_Receiver_Emails_list  \
# 404  [Thank you! I'm glad you're pleased! , What do you have in mind on picking out? , Do you have good taste when it comes to picking out women's clothes? , Then I guess I should trust you , maybe I like trouble , I knew you would like that , I have it , very soon , You never know! , you'll get it , yes it is , because I said so , Yes it is , Is that a threat or a promise? , on what? , maybe , now? , I'M SORRY , Do not Whatever me  Or you won't get your present  I tried to get you to go have one...
# 408  [lets go buy another but I get to pick , whatever I want , absolutely , always , that was a good comeback , by the way where is my present , when do I get it , as in hours days or weeks? , how about a hint , thats not a hint , how , not fair , you are in trouble , that depends , yes, when , ok , you suck , whatever , we will have to throw him out , I would rather wait , are you doing anything , why thats no good , I FIGURED , going across the street , you are supposed to ask up or down , up ...
#
#      num_relevant_emails sender_replier_thread
# 404                   46               414-171
# 408                   42               171-414

# %% [markdown]
# -----
# ## Ranking Framework

# %%
import chromadb
from chromadb.utils import embedding_functions

import langchain
from langchain.document_loaders import TextLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma

# %%
# !chroma run --path /vectorstores

# %%
# Setting Up Client
chroma_client = chromadb.PersistentClient(path="vectorstores")

# %%
chroma_client.heartbeat()
# Out:
# 1697516757569215546

# %%
# Defining the Embedding Function
openai_ef = embedding_functions.OpenAIEmbeddingFunction(api_key = openai_api_key,
                                                        model_name="text-embedding-ada-002")
openai_ef

# %%
print('user'+str(replier_id))
chroma_client.get_collection('user'+str(replier_id)).count()
# Out:
# user414
# 592

# %%
# Building the Langchain vectorstore using chroma collections
user_vector_store = Chroma(
    client=chroma_client,
    collection_name='user'+str(replier_id),
    embedding_function=OpenAIEmbeddings(),
)
user_vector_store

# %%
# Running similarity search between vector store and incoming message
embedding_vector=OpenAIEmbeddings().embed_query(sender_email)
relevant_emails=user_vector_store.similarity_search_by_vector(embedding_vector)
relevant_emails
# Out:
# Add of existing embedding ID: 275
# Add of existing embedding ID: 277
# Add of existing embedding ID: 279
# Add of existing embedding ID: 281
# Add of existing embedding ID: 285
# Add of existing embedding ID: 287
# Add of existing embedding ID: 289
# Add of existing embedding ID: 291
# Add of existing embedding ID: 293
# Add of existing embedding ID: 295
# Add of existing embedding ID: 297
# Add of existing embedding ID: 299
# Add of existing embedding ID: 301
# Add of existing embedding ID: 303
# Add of existing embedding ID: 306
# Add of existing embedding ID: 308
# Add of existing embedding ID: 309
# Add of existing embedding ID: 311
# Add of existing embedding ID: 313
# Add of existing embedding ID: 318
# Add of existing embedding ID: 332
# Add of existing embedding ID: 334
# Add of existing embedding ID: 336
# Add of existing embedding ID: 348
# Add of existing embedding ID: 350
# Add of existing embedding ID: 352
# Add of existing embedding ID: 354
# Add of existing embedding ID: 357
# Add of existing embedding ID: 359
# Add of existing embedding ID: 361
# Add of existing embedding ID: 365
# Add of existing embedding ID: 373
# Add of existing embedding ID: 375
# Add of existing embedding ID: 383
# Add of existing embedding ID: 385
# Add of existing embedding ID: 401
# Add of existing embedding ID: 404
# Add of existing embedding ID: 406
# Add of existing embedding ID: 409
# Add of existing embedding ID: 412
# Add of existing embedding ID: 414
# Add of existing embedding ID: 417
# Add of existing embedding ID: 420
# Add of existing embedding ID: 677
# Add of existing embedding ID: 679
# Add of existing embedding ID: 681
# Add of existing embedding ID: 769
# Add of existing embedding ID: 808
# Add of existing embedding ID: 810
# Add of existing embedding ID: 812
# Add of existing embedding ID: 816
# Add of existing embedding ID: 819
# Add of existing embedding ID: 821
# Add of existing embedding ID: 823
# Add of existing embedding ID: 826
# Add of existing embedding ID: 924
# Add of existing embedding ID: 926
# Add of existing embedding ID: 928
# Add of existing embedding ID: 964
# Add of existing embedding ID: 966
# Add of existing embedding ID: 968
# Add of existing embedding ID: 970
# Add of existing embedding ID: 972
# Add of existing embedding ID: 975
# Add of existing embedding ID: 977
# Add of existing embedding ID: 1015
# Add of existing embedding ID: 1018
# Add of existing embedding ID: 1020
# Add of existing embedding ID: 1022
# Add of existing embedding ID: 1024
# Add of existing embedding ID: 1027
# Add of existing embedding ID: 1029
# Add of existing embedding ID: 1031
# Add of existing embedding ID: 1034
# Add of existing embedding ID: 1038
# Add of existing embedding ID: 1040
# Add of existing embedding ID: 1043
# Add of existing embedding ID: 1045
# Add of existing embedding ID: 1047
# Add of existing embedding ID: 1048
# Add of existing embedding ID: 1050
# Add of existing embedding ID: 1052
# Add of existing embedding ID: 1054
# Add of existing embedding ID: 1057
# Add of existing embedding ID: 1059
# Add of existing embedding ID: 1316
# Add of existing embedding ID: 1318
# Add of existing embedding ID: 1321
# Add of existing embedding ID: 1323
# Add of existing embedding ID: 1325
# Add of existing embedding ID: 1328
# Add of existing embedding ID: 1330
# Add of existing embedding ID: 1333
# Add of existing embedding ID: 1335
# Add of existing embedding ID: 1337
# Add of existing embedding ID: 1339
# Add of existing embedding ID: 1341
# Add of existing embedding ID: 1342
# Add of existing embedding ID: 1345
# Add of existing embedding ID: 1346
# Add of existing embedding ID: 1349
# Add of existing embedding ID: 1351
# Add of existing embedding ID: 1353
# Add of existing embedding ID: 1356
# Add of existing embedding ID: 1359
# Add of existing embedding ID: 1361
# Add of existing embedding ID: 1363
# Add of existing embedding ID: 1367
# Add of existing embedding ID: 1369
# Add of existing embedding ID: 1372
# Add of existing embedding ID: 1374
# Add of existing embedding ID: 1376
# Add of existing embedding ID: 1378
# Add of existing embedding ID: 1380
# Add of existing embedding ID: 1382
# Add of existing embedding ID: 1384
# Add of existing embedding ID: 1387
# Add of existing embedding ID: 1389
# Add of existing embedding ID: 1392
# Add of existing embedding ID: 1394
# Add of existing embedding ID: 1396
# Add of existing embedding ID: 1398
# Add of existing embedding ID: 1400
# Add of existing embedding ID: 1402
# Add of existing embedding ID: 1404
# Add of existing embedding ID: 1406
# Add of existing embedding ID: 1408
# Add of existing embedding ID: 1410
# Add of existing embedding ID: 1412
# Add of existing embedding ID: 1415
# Add of existing embedding ID: 1417
# Add of existing embedding ID: 1419
# Add of existing embedding ID: 1421
# Add of existing embedding ID: 1423
# Add of existing embedding ID: 1425
# Add of existing embedding ID: 1427
# Add of existing embedding ID: 1430
# Add of existing embedding ID: 1431
# Add of existing embedding ID: 1434
# Add of existing embedding ID: 1438
# Add of existing embedding ID: 1441
# Add of existing embedding ID: 1444
# Add of existing embedding ID: 1446
# Add of existing embedding ID: 1448
# Add of existing embedding ID: 1450
# Add of existing embedding ID: 1452
# Add of existing embedding ID: 1454
# Add of existing embedding ID: 1459
# Add of existing embedding ID: 1462
# Add of existing embedding ID: 1464
# Add of existing embedding ID: 1466
# Add of existing embedding ID: 1468
# Add of existing embedding ID: 1473
# Add of existing embedding ID: 1475
# Add of existing embedding ID: 1480
# Add of existing embedding ID: 1481
# Add of existing embedding ID: 1482
# Add of existing embedding ID: 1485
# Add of existing embedding ID: 1488
# Add of existing embedding ID: 1489
# Add of existing embedding ID: 1491
# Add of existing embedding ID: 1496
# Add of existing embedding ID: 1497
# Add of existing embedding ID: 1499
# Add of existing embedding ID: 1501
# Add of existing embedding ID: 1505
# Add of existing embedding ID: 1511
# Add of existing embedding ID: 1515
# Add of existing embedding ID: 1518
# Add of existing embedding ID: 1521
# Add of existing embedding ID: 1524
# Add of existing embedding ID: 1531
# Add of existing embedding ID: 1533
# Add of existing embedding ID: 1536
# Add of existing embedding ID: 1541
# Add of existing embedding ID: 1542
# Add of existing embedding ID: 1544
# Add of existing embedding ID: 1551
# Add of existing embedding ID: 1561
# Add of existing embedding ID: 1571
# Add of existing embedding ID: 1573
# Add of existing embedding ID: 1578
# Add of existing embedding ID: 1580
# Add of existing embedding ID: 1588
# Add of existing embedding ID: 1590
# Add of existing embedding ID: 1592
# Add of existing embedding ID: 1594
# Add of existing embedding ID: 1596
# Add of existing embedding ID: 1598
# Add of existing embedding ID: 1600
# Add of existing embedding ID: 1602
# Add of existing embedding ID: 1604
# Add of existing embedding ID: 1606
# Add of existing embedding ID: 1608
# Add of existing embedding ID: 1609
# Add of existing embedding ID: 1611
# Add of existing embedding ID: 1613
# Add of existing embedding ID: 1615
# Add of existing embedding ID: 1617
# Add of existing embedding ID: 1619
# Add of existing embedding ID: 1621
# Add of existing embedding ID: 1623
# Add of existing embedding ID: 1625
# Add of existing embedding ID: 1627
# Add of existing embedding ID: 1629
# Add of existing embedding ID: 1631
# Add of existing embedding ID: 1636
# Add of existing embedding ID: 1646
# Add of existing embedding ID: 1653
# Add of existing embedding ID: 1654
# Add of existing embedding ID: 1656
# Add of existing embedding ID: 1658
# Add of existing embedding ID: 1659
# Add of existing embedding ID: 1661
# Add of existing embedding ID: 1669
# Add of existing embedding ID: 1671
# Add of existing embedding ID: 1673
# Add of existing embedding ID: 1676
# Add of existing embedding ID: 1679
# Add of existing embedding ID: 1681
# Add of existing embedding ID: 1688
# Add of existing embedding ID: 1690
# Add of existing embedding ID: 1692
# Add of existing embedding ID: 1694
# Add of existing embedding ID: 1696
# Add of existing embedding ID: 1698
# Add of existing embedding ID: 1700
# Add of existing embedding ID: 1702
# Add of existing embedding ID: 1704
# Add of existing embedding ID: 1706
# Add of existing embedding ID: 1714
# Add of existing embedding ID: 1718
# Add of existing embedding ID: 1720
# Add of existing embedding ID: 1722
# Add of existing embedding ID: 1723
# Add of existing embedding ID: 1726
# Add of existing embedding ID: 1728
# Add of existing embedding ID: 1730
# Add of existing embedding ID: 1731
# Add of existing embedding ID: 1734
# Add of existing embedding ID: 1736
# Add of existing embedding ID: 1738
# Add of existing embedding ID: 1741
# Add of existing embedding ID: 1743
# Add of existing embedding ID: 1745
# Add of existing embedding ID: 1747
# Add of existing embedding ID: 1750
# Add of existing embedding ID: 1752
# Add of existing embedding ID: 1756
# Add of existing embedding ID: 1757
# Add of existing embedding ID: 1760
# Add of existing embedding ID: 1761
# Add of existing embedding ID: 1762
# Add of existing embedding ID: 1766
# Add of existing embedding ID: 1767
# Add of existing embedding ID: 1770
# Add of existing embedding ID: 1772
# Add of existing embedding ID: 1774
# Add of existing embedding ID: 1776
# Add of existing embedding ID: 1780
# Add of existing embedding ID: 1782
# Add of existing embedding ID: 1784
# Add of existing embedding ID: 1786
# Add of existing embedding ID: 1788
# Add of existing embedding ID: 1791
# Add of existing embedding ID: 1793
# Add of existing embedding ID: 1794
# Add of existing embedding ID: 1796
# Add of existing embedding ID: 1799
# Add of existing embedding ID: 1801
# Add of existing embedding ID: 1803
# Add of existing embedding ID: 1805
# Add of existing embedding ID: 1807
# Add of existing embedding ID: 1821
# Add of existing embedding ID: 1823
# Add of existing embedding ID: 1828
# Add of existing embedding ID: 1832
# Add of existing embedding ID: 1834
# Add of existing embedding ID: 1837
# Add of existing embedding ID: 1840
# Add of existing embedding ID: 1842
# Add of existing embedding ID: 1843
# Add of existing embedding ID: 1846
# Add of existing embedding ID: 1847
# Add of existing embedding ID: 1851
# Add of existing embedding ID: 1852
# Add of existing embedding ID: 1855
# Add of existing embedding ID: 1858
# Add of existing embedding ID: 1859
# Add of existing embedding ID: 1861
# Add of existing embedding ID: 1866
# Add of existing embedding ID: 1870
# Add of existing embedding ID: 1872
# Add of existing embedding ID: 1874
# Add of existing embedding ID: 1876
# Add of existing embedding ID: 1880
# Add of existing embedding ID: 1884
# Add of existing embedding ID: 1887
# Add of existing embedding ID: 1891
# Add of existing embedding ID: 1893
# Add of existing embedding ID: 1895
# Add of existing embedding ID: 1897
# Add of existing embedding ID: 1899
# Add of existing embedding ID: 1902
# Add of existing embedding ID: 1903
# Add of existing embedding ID: 1906
# Add of existing embedding ID: 1909
# Add of existing embedding ID: 1911
# Add of existing embedding ID: 1912
# Add of existing embedding ID: 1914
# Add of existing embedding ID: 1917
# Add of existing embedding ID: 1919
# Add of existing embedding ID: 1920
# Add of existing embedding ID: 1923
# Add of existing embedding ID: 1926
# Add of existing embedding ID: 1929
# Add of existing embedding ID: 1931
# Add of existing embedding ID: 1932
# Add of existing embedding ID: 1935
# Add of existing embedding ID: 1937
# Add of existing embedding ID: 1944
# Add of existing embedding ID: 1946
# Add of existing embedding ID: 1948
# Add of existing embedding ID: 1950
# Add of existing embedding ID: 1954
# Add of existing embedding ID: 1957
# Add of existing embedding ID: 1959
# Add of existing embedding ID: 1961
# Add of existing embedding ID: 1983
# Add of existing embedding ID: 1985
# Add of existing embedding ID: 1987
# Add of existing embedding ID: 1989
# Add of existing embedding ID: 1991
# Add of existing embedding ID: 1993
# Add of existing embedding ID: 1995
# Add of existing embedding ID: 1997
# Add of existing embedding ID: 1999
# Add of existing embedding ID: 2002
# Add of existing embedding ID: 2005
# Add of existing embedding ID: 2007
# Add of existing embedding ID: 2009
# Add of existing embedding ID: 2011
# Add of existing embedding ID: 2013
# Add of existing embedding ID: 2015
# Add of existing embedding ID: 2017
# Add of existing embedding ID: 2019
# Add of existing embedding ID: 2022
# Add of existing embedding ID: 2024
# Add of existing embedding ID: 2027
# Add of existing embedding ID: 2029
# Add of existing embedding ID: 2031
# Add of existing embedding ID: 2036
# Add of existing embedding ID: 2038
# Add of existing embedding ID: 2040
# Add of existing embedding ID: 2046
# Add of existing embedding ID: 2048
# Add of existing embedding ID: 2052
# Add of existing embedding ID: 2054
# Add of existing embedding ID: 2057
# Add of existing embedding ID: 2059
# Add of existing embedding ID: 2061
# Add of existing embedding ID: 2063
# Add of existing embedding ID: 2068
# Add of existing embedding ID: 2071
# Add of existing embedding ID: 2072
# Add of existing embedding ID: 2076
# Add of existing embedding ID: 2078
# Add of existing embedding ID: 2080
# Add of existing embedding ID: 2082
# Add of existing embedding ID: 2160
# Add of existing embedding ID: 2161
# Add of existing embedding ID: 2162
# Add of existing embedding ID: 2163
# Add of existing embedding ID: 2164
# Add of existing embedding ID: 2165
# Add of existing embedding ID: 2166
# Add of existing embedding ID: 2167
# Add of existing embedding ID: 2168
# Add of existing embedding ID: 2169
# Add of existing embedding ID: 2170
# Add of existing embedding ID: 2171
# Add of existing embedding ID: 2172
# Add of existing embedding ID: 2174
# Add of existing embedding ID: 2175
# Add of existing embedding ID: 2176
# Add of existing embedding ID: 2177
# Add of existing embedding ID: 2178
# Add of existing embedding ID: 2179
# Add of existing embedding ID: 2180
# Add of existing embedding ID: 2181
# Add of existing embedding ID: 2182
# Add of existing embedding ID: 2183
# Add of existing embedding ID: 2184
# Add of existing embedding ID: 2185
# Add of existing embedding ID: 2186
# Add of existing embedding ID: 2187
# Add of existing embedding ID: 2188
# Add of existing embedding ID: 2189
# Add of existing embedding ID: 2190
# Add of existing embedding ID: 2191
# Add of existing embedding ID: 2192
# Add of existing embedding ID: 2193
# Add of existing embedding ID: 2194
# Add of existing embedding ID: 2195
# Add of existing embedding ID: 2196
# Add of existing embedding ID: 2197
# Add of existing embedding ID: 2198
# Add of existing embedding ID: 2199
# Add of existing embedding ID: 2200
# Add of existing embedding ID: 2202
# Add of existing embedding ID: 2204
# Add of existing embedding ID: 2206
# Add of existing embedding ID: 2207
# Add of existing embedding ID: 2208
# Add of existing embedding ID: 2209
# Add of existing embedding ID: 2210
# Add of existing embedding ID: 2211
# Add of existing embedding ID: 2212
# Add of existing embedding ID: 2213
# Add of existing embedding ID: 2214
# Add of existing embedding ID: 2215
# Add of existing embedding ID: 2216
# Add of existing embedding ID: 2217
# Add of existing embedding ID: 2218
# Add of existing embedding ID: 2219
# Add of existing embedding ID: 2220
# Add of existing embedding ID: 2221
# Add of existing embedding ID: 2222
# Add of existing embedding ID: 2223
# Add of existing embedding ID: 2224
# Add of existing embedding ID: 2225
# Add of existing embedding ID: 2226
# Add of existing embedding ID: 2227
# Add of existing embedding ID: 2228
# Add of existing embedding ID: 2229
# Add of existing embedding ID: 2230
# Add of existing embedding ID: 2231
# Add of existing embedding ID: 2232
# Add of existing embedding ID: 2233
# Add of existing embedding ID: 2234
# Add of existing embedding ID: 2235
# Add of existing embedding ID: 2236
# Add of existing embedding ID: 2238
# Add of existing embedding ID: 2245
# Add of existing embedding ID: 2246
# Add of existing embedding ID: 2247
# Add of existing embedding ID: 2248
# Add of existing embedding ID: 2249
# Add of existing embedding ID: 2250
# Add of existing embedding ID: 2251
# Add of existing embedding ID: 2252
# Add of existing embedding ID: 2253
# Add of existing embedding ID: 2254
# Add of existing embedding ID: 2255
# Add of existing embedding ID: 2256
# Add of existing embedding ID: 2257
# Add of existing embedding ID: 2258
# Add of existing embedding ID: 2259
# Add of existing embedding ID: 2260
# Add of existing embedding ID: 2261
# Add of existing embedding ID: 2263
# Add of existing embedding ID: 2266
# Add of existing embedding ID: 2268
# Add of existing embedding ID: 2274
# Add of existing embedding ID: 2276
# Add of existing embedding ID: 2294
# Add of existing embedding ID: 2298
# Add of existing embedding ID: 2299
# Add of existing embedding ID: 2301
# Add of existing embedding ID: 2303
# Add of existing embedding ID: 2305
# Add of existing embedding ID: 2307
# Add of existing embedding ID: 2309
# Add of existing embedding ID: 2313
# Add of existing embedding ID: 2315
# Add of existing embedding ID: 2317
# Add of existing embedding ID: 2319
# Add of existing embedding ID: 2320
# Add of existing embedding ID: 2322
# Add of existing embedding ID: 2324
# Add of existing embedding ID: 2326
# Add of existing embedding ID: 2329
# Add of existing embedding ID: 2332
# Add of existing embedding ID: 2334
# Add of existing embedding ID: 2337
# Add of existing embedding ID: 2339
# Add of existing embedding ID: 2341
# Add of existing embedding ID: 2342
# Add of existing embedding ID: 2344
# Add of existing embedding ID: 2347
# Add of existing embedding ID: 2355
# Add of existing embedding ID: 2357
# Add of existing embedding ID: 2359
# Add of existing embedding ID: 2361
# Add of existing embedding ID: 2365
# Add of existing embedding ID: 2367
# Add of existing embedding ID: 2369
# Add of existing embedding ID: 2371
# Add of existing embedding ID: 2373
# Add of existing embedding ID: 2375
# Add of existing embedding ID: 2377
# Add of existing embedding ID: 2380
# Add of existing embedding ID: 2381
# Add of existing embedding ID: 2384
# Add of existing embedding ID: 2385
# Add of existing embedding ID: 2387
# Add of existing embedding ID: 2389
# Add of existing embedding ID: 2391
# Add of existing embedding ID: 2393
# Add of existing embedding ID: 2395
# Add of existing embedding ID: 2397
# Add of existing embedding ID: 2399
# Add of existing embedding ID: 2403
# Add of existing embedding ID: 2405
# Add of existing embedding ID: 2407
# Add of existing embedding ID: 2409
# Add of existing embedding ID: 2411
# Add of existing embedding ID: 2413
# Add of existing embedding ID: 2415
# Add of existing embedding ID: 2418
# Add of existing embedding ID: 2419
# Add of existing embedding ID: 2421
# Add of existing embedding ID: 2423
# Add of existing embedding ID: 2428
# Add of existing embedding ID: 2429
# Add of existing embedding ID: 2431
# Add of existing embedding ID: 2433
# Add of existing embedding ID: 2435
# Add of existing embedding ID: 2437
# Add of existing embedding ID: 2439
# Add of existing embedding ID: 2441
# Add of existing embedding ID: 2443
# Add of existing embedding ID: 2445
# Add of existing embedding ID: 2447
# Add of existing embedding ID: 2449
# Add of existing embedding ID: 2451
# Add of existing embedding ID: 2453
# Add of existing embedding ID: 2484
# Add of existing embedding ID: 2485
# Add of existing embedding ID: 2487
# Add of existing embedding ID: 2489
# Add of existing embedding ID: 2504
# Add of existing embedding ID: 2506
# Add of existing embedding ID: 2508
# Add of existing embedding ID: 2510
# Add of existing embedding ID: 2512
# Add of existing embedding ID: 2514
# Add of existing embedding ID: 2516
# Add of existing embedding ID: 2518
# Add of existing embedding ID: 2520
# Add of existing embedding ID: 2522
# Add of existing embedding ID: 2524
# Add of existing embedding ID: 2526
# Add of existing embedding ID: 2528
# Add of existing embedding ID: 2530
# Add of existing embedding ID: 2540
# Add of existing embedding ID: 2542
# Add of existing embedding ID: 2544
# Add of existing embedding ID: 2546
# Add of existing embedding ID: 2548
# Add of existing embedding ID: 2550
# Add of existing embedding ID: 2552
# Add of existing embedding ID: 2559
# Add of existing embedding ID: 2561
# Add of existing embedding ID: 2563
# Add of existing embedding ID: 2566
# Add of existing embedding ID: 2571
# Add of existing embedding ID: 2573
# Add of existing embedding ID: 2575
# Add of existing embedding ID: 2577
# Add of existing embedding ID: 2582
# Add of existing embedding ID: 2584
# Add of existing embedding ID: 2586
# Add of existing embedding ID: 2588
# Add of existing embedding ID: 2597
# Add of existing embedding ID: 2601
# Add of existing embedding ID: 2602
# Add of existing embedding ID: 2605
# Add of existing embedding ID: 2608
# Add of existing embedding ID: 2610
# Add of existing embedding ID: 2612
# Add of existing embedding ID: 2614
# Add of existing embedding ID: 2617
# Add of existing embedding ID: 2619
# Add of existing embedding ID: 3494
# Add of existing embedding ID: 3496
# Add of existing embedding ID: 4074
# Add of existing embedding ID: 4076
# Add of existing embedding ID: 11796
# Add of existing embedding ID: 17836
# Add of existing embedding ID: 17838
# Add of existing embedding ID: 17840
# [Document(page_content='by the way where is my present '),
#  Document(page_content='i have a present '),
#  Document(page_content='cmon thats not true, what am i going to do withyour present '),
#  Document(page_content='when do I get it ')]

# %%
# Getting ranked responses using MMR
found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
list_rel_emails=[]
for i, doc in enumerate(found_docs):
    list_rel_emails.append(doc.page_content)

list_rel_emails

# %% [markdown]
# -----
# ## LangChain Tests

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain

# %%
# Email Environment
sender_id='171'
replier_id='414'
sender_email='Where is my gift?'
email_dataset=df_messages_deduped
vector_db_client=chroma_client

# %%
# First getting retrieved emails to understand conversation --------
sender_replier_id='-'.join([sender_id, replier_id])
previous_emails=(email_dataset[email_dataset.sender_replier_thread==sender_replier_id]['Sender_Receiver_Emails_list']).to_list()[0][-10:]
previous_emails
# Out:
# ['just going home, you? ',
#  'I dont know who that is ',
#  'no not yet ',
#  'and ',
#  'thats not allowed ',
#  'yeah you cant make it home ',
#  'why maybe ',
#  'promise ',
#  'absolutely ',
#  'very ']

# %%
chroma_client
user_vector_store = Chroma(
    client=vector_db_client, 
    collection_name='user'+str(replier_id),
    embedding_function=OpenAIEmbeddings())

user_vector_store

# %%
found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
list_rel_emails=[]
for i, doc in enumerate(found_docs):
    list_rel_emails.append(doc.page_content)
list_rel_emails
# Out:
# ['by the way where is my present ',
#  'i have a present ',
#  'cmon thats not true, what am i going to do withyour present ',
#  'when do I get it ',
#  'did you get good stuff for christmas ',
#  'no nothing, where are you ',
#  'what did you get ',
#  'how did you lose it ',
#  'no but I still have your stuff do you want to come and get it ',
#  'where are you ']

# %%
llm=ChatOpenAI(temperature=0.1, model=llm_model, openai_api_key=openai_api_key)
llm
# Out:
# ChatOpenAI(client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo-0301', temperature=0.1, openai_api_key='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', openai_api_base='', openai_organization='', openai_proxy='')

# %%
template_string="""Create a response to the following email {sender_email}, deriving context from these relevant emails {relevant_emails} ,using a conversation style similar to following past emails between these 2 users {prev_emails}"""
template_string
# Out:
# 'Create a response to the following email {sender_email}, deriving context from these relevant emails {relevant_emails} ,using a conversation style similar to following past emails between these 2 users {prev_emails}'

# %%
prompt_template = ChatPromptTemplate.from_template(template=template_string)
prompt_template
# Out:
# ChatPromptTemplate(input_variables=['prev_emails', 'relevant_emails', 'sender_email'], messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['prev_emails', 'relevant_emails', 'sender_email'], template='Create a response to the following email {sender_email}, deriving context from these relevant emails {relevant_emails} ,using a conversation style similar to following past emails between these 2 users {prev_emails}'))])

# %%
llm_chain=LLMChain(llm=llm, prompt=prompt_template)
llm_chain
# Out:
# LLMChain(prompt=ChatPromptTemplate(input_variables=['prev_emails', 'relevant_emails', 'sender_email'], messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['prev_emails', 'relevant_emails', 'sender_email'], template='Create a response to the following email {sender_email}, deriving context from these relevant emails {relevant_emails} ,using a conversation style similar to following past emails between these 2 users {prev_emails}'))]), llm=ChatOpenAI(client=<class 'openai.api_resources.chat_completion.ChatCompletion'>, model_name='gpt-3.5-turbo-0301', temperature=0.1, openai_api_key='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', openai_api_base='', openai_organization='', openai_proxy=''))

# %%
print(llm_chain.run(sender_email=sender_email, prev_emails=previous_emails, relevant_emails=list_rel_emails))
# Out:
# Hi there,
#
# I'm sorry for the delay in getting your gift to you. I've been really busy lately and haven't had a chance to send it out yet. But don't worry, I haven't forgotten about it!
#
# To answer your question, I'm currently at home. How about you? Did you have a good holiday season? I got some really nice gifts, but I'm still waiting on a few things to arrive in the mail.
#
# As for your present, I promise I'll get it to you as soon as possible. I know it's not ideal to have to wait, but I hope you can be patient with me. I haven't lost it or anything like that, I just haven't had a chance to send it out yet.
#
# In the meantime, do you still have my stuff? I might need to come and pick it up soon. Let me know where you are and we can arrange a time.
#
# Thanks for understanding,
#
# [Your Name]

# %% [markdown]
# ----
# ## Langchain Function v2

# %%
# Email Environment
sender_id='171'
replier_id='414'
sender_email='Where is my gift?'
email_dataset=df_messages_deduped
vector_db_client=chroma_client

# %%
# def process_single_thread(sender_id, replier_id, sender_email, email_dataset, api_key, vector_db_client, embedding_function):
#     # ... (The rest of your code remains unchanged.)
#     # Removing async and await for synchronous execution
#     sender_replier_id = '-'.join([sender_id, replier_id])
#     previous_emails = (email_dataset[email_dataset.sender_replier_thread == sender_replier_id]['Sender_Receiver_Emails_list']).to_list()[0][-10:]
#     # ... (Continue with the rest of your code.)
#     print("Processed thread:", sender_replier_id)  # Added a print statement to see progress

# # Looping through each thread and processing them one by one
# for index, row in df_messages_deduped.iterrows():
#     sender_id = row['sender']
#     replier_id = row['replier']
#     sender_email = "Your custom email content here"  # Modify as needed
    
#     process_single_thread(sender_id, replier_id, sender_email, df_messages_deduped, openai_api_key, chroma_client, OpenAIEmbeddings())
# Out:
#   Cell In[27], line 29
#     results = get_email_response_personalized(sender_id=sender_id,
#     ^
# IndentationError: expected an indented block after function definition on line 17

# %%
async def get_email_response_personalized(sender_id=sender_id,
                                    replier_id=replier_id,
                                    sender_email=sender_email,
                                    email_dataset=df_messages_deduped,
                                    api_key=openai_api_key,
                                    vector_db_client=chroma_client,
                                    embedding_function=OpenAIEmbeddings()):
    
    # First getting retrieved emails to understand conversation --------
    sender_replier_id='-'.join([sender_id, replier_id])
    previous_emails=(email_dataset[email_dataset.sender_replier_thread==sender_replier_id]['Sender_Receiver_Emails_list']).to_list()[0][-10:]
    previous_emails
    # Second, getting ranked responses as per context ------------------
        
        # Building the Langchain vectorstore using chroma collections
    user_vector_store = Chroma(
        client=vector_db_client, 
        collection_name='user'+str(replier_id),
        embedding_function=OpenAIEmbeddings())
        # Getting ranked responses using MMR
    found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
    list_rel_emails=[]
    for i, doc in enumerate(found_docs):
        list_rel_emails.append(doc.page_content)
    list_rel_emails
        
    # Setting up LangChain
    llm=ChatOpenAI(temperature=0.1, model=llm_model, openai_api_key=openai_api_key)
    template_string="""Create a response to the following email {sender_email}, deriving context from these relevant emails {relevant_emails} ,using a conversation style similar to following past emails between these 2 users {prev_emails}"""
    prompt_template = ChatPromptTemplate.from_template(template=template_string)    
    llm_chain=LLMChain(llm=llm, prompt=prompt_template)
    print(llm_chain.run(sender_email=sender_email, prev_emails=previous_emails, relevant_emails=list_rel_emails))

# %%
results = await get_email_response_personalized(sender_id=sender_id,
                                    replier_id=replier_id,
                                    sender_email=sender_email,
                                    email_dataset=df_messages_deduped,
                                    api_key=openai_api_key,
                                    vector_db_client=chroma_client,
                                    embedding_function=OpenAIEmbeddings())
print(results)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 results = await get_email_response_personalized(sender_id=sender_id,
#       2                                     replier_id=replier_id,
#       3                                     sender_email=sender_email,
#       4                                     email_dataset=df_messages_deduped,
#       5                                     api_key=openai_api_key,
#       6                                     vector_db_client=chroma_client,
#       7                                     embedding_function=OpenAIEmbeddings())
#       8 print(results)
#
# Cell In[28], line 21, in get_email_response_personalized(sender_id, replier_id, sender_email, email_dataset, api_key, vector_db_client, embedding_function)
#      16 user_vector_store = Chroma(
#      17     client=vector_db_client,
#      18     collection_name='user'+str(replier_id),
#      19     embedding_function=OpenAIEmbeddings())
#      20     # Getting ranked responses using MMR
# ---> 21 found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
#      22 list_rel_emails=[]
#      23 for i, doc in enumerate(found_docs):
#
# File /opt/conda/lib/python3.10/site-packages/langchain/schema/vectorstore.py:389, in VectorStore.amax_marginal_relevance_search(self, query, k, fetch_k, lambda_mult, **kwargs)
#     378 # This is a temporary workaround to make the similarity search
#     379 # asynchronous. The proper solution is to make the similarity search
#     380 # asynchronous in the vector store implementations.
#     381 func = partial(
#     382     self.max_marginal_relevance_search,
#     383     query,
#    (...)
#     387     **kwargs,
#     388 )
# --> 389 return await asyncio.get_event_loop().run_in_executor(None, func)
#
# File /opt/conda/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /opt/conda/lib/python3.10/site-packages/langchain/vectorstores/chroma.py:466, in Chroma.max_marginal_relevance_search(self, query, k, fetch_k, lambda_mult, filter, where_document, **kwargs)
#     461 if self._embedding_function is None:
#     462     raise ValueError(
#     463         "For MMR search, you must specify an embedding function on" "creation."
#     464     )
# --> 466 embedding = self._embedding_function.embed_query(query)
#     467 docs = self.max_marginal_relevance_search_by_vector(
#     468     embedding,
#     469     k,
#    (...)
#     473     where_document=where_document,
#     474 )
#     475 return docs
#
# File /opt/conda/lib/python3.10/site-packages/langchain/embeddings/openai.py:518, in OpenAIEmbeddings.embed_query(self, text)
#     509 def embed_query(self, text: str) -> List[float]:
#     510     """Call out to OpenAI's embedding endpoint for embedding query text.
#     511
#     512     Args:
#    (...)
#     516         Embedding for the text.
#     517     """
# --> 518     return self.embed_documents([text])[0]
#
# File /opt/conda/lib/python3.10/site-packages/langchain/embeddings/openai.py:490, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     478 """Call out to OpenAI's embedding endpoint for embedding search docs.
#     479
#     480 Args:
#    (...)
#     486     List of embeddings, one for each text.
#     487 """
#     488 # NOTE: to keep things simple, we assume the list may contain texts longer
#     489 #       than the maximum context and use length-safe embedding function.
# --> 490 return self._get_len_safe_embeddings(texts, engine=self.deployment)
#
# File /opt/conda/lib/python3.10/site-packages/langchain/embeddings/openai.py:374, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     371     _iter = range(0, len(tokens), _chunk_size)
#     373 for i in _iter:
# --> 374     response = embed_with_retry(
#     375         self,
#     376         input=tokens[i : i + _chunk_size],
#     377         **self._invocation_params,
#     378     )
#     379     batched_embeddings.extend(r["embedding"] for r in response["data"])
#     381 results: List[List[List[float]]] = [[] for _ in range(len(texts))]
#
# File /opt/conda/lib/python3.10/site-packages/langchain/embeddings/openai.py:107, in embed_with_retry(embeddings, **kwargs)
#     104     response = embeddings.client.create(**kwargs)
#     105     return _check_response(response, skip_empty=embeddings.skip_empty)
# --> 107 return _embed_with_retry(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /opt/conda/lib/python3.10/site-packages/langchain/embeddings/openai.py:104, in embed_with_retry.<locals>._embed_with_retry(**kwargs)
#     102 @retry_decorator
#     103 def _embed_with_retry(**kwargs: Any) -> Any:
# --> 104     response = embeddings.client.create(**kwargs)
#     105     return _check_response(response, skip_empty=embeddings.skip_empty)
#
# File /opt/conda/lib/python3.10/site-packages/openai/api_resources/embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      31 while True:
#      32     try:
# ---> 33         response = super().create(*args, **kwargs)
#      35         # If a user specifies base64, we'll just return the encoded string.
#      36         # This is only for the default case.
#      37         if not user_provided_encoding_format:
#
# File /opt/conda/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:155, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     129 @classmethod
#     130 def create(
#     131     cls,
#    (...)
#     138     **params,
#     139 ):
#     140     (
#     141         deployment_id,
#     142         engine,
#    (...)
#     152         api_key, api_base, api_type, api_version, organization, **params
#     153     )
# --> 155     response, _, api_key = requestor.request(
#     156         "post",
#     157         url,
#     158         params=params,
#     159         headers=headers,
#     160         stream=stream,
#     161         request_id=request_id,
#     162         request_timeout=request_timeout,
#     163     )
#     165     if stream:
#     166         # must be an iterator
#     167         assert not isinstance(response, OpenAIResponse)
#
# File /opt/conda/lib/python3.10/site-packages/openai/api_requestor.py:299, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     278 def request(
#     279     self,
#     280     method,
#    (...)
#     287     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     288 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     289     result = self.request_raw(
#     290         method.lower(),
#     291         url,
#    (...)
#     297         request_timeout=request_timeout,
#     298     )
# --> 299     resp, got_stream = self._interpret_response(result, stream)
#     300     return resp, got_stream, self.api_key
#
# File /opt/conda/lib/python3.10/site-packages/openai/api_requestor.py:710, in APIRequestor._interpret_response(self, result, stream)
#     702     return (
#     703         self._interpret_response_line(
#     704             line, result.status_code, result.headers, stream=True
#     705         )
#     706         for line in parse_stream(result.iter_lines())
#     707     ), True
#     708 else:
#     709     return (
# --> 710         self._interpret_response_line(
#     711             result.content.decode("utf-8"),
#     712             result.status_code,
#     713             result.headers,
#     714             stream=False,
#     715         ),
#     716         False,
#     717     )
#
# File /opt/conda/lib/python3.10/site-packages/openai/api_requestor.py:775, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     773 stream_error = stream and "error" in resp.data
#     774 if stream_error or not 200 <= rcode < 300:
# --> 775     raise self.handle_error_response(
#     776         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     777     )
#     778 return resp
#
# AuthenticationError: Incorrect API key provided: sk-2dNhL***************************************zPoQ. You can find your API key at https://platform.openai.com/account/api-keys.

# %% [markdown]
# #Added

# %%
import pandas as pd
import chromadb
from chromadb.utils import embedding_functions
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
import ast

# Loading and preparing the DataFrame
df_messages = pd.read_csv('gs://user-scripts-msca310019-capstone-49b3/data/20231009_Emails_with_Previous_as_List.csv', parse_dates=['time'])
df_messages['Sender_Receiver_Emails_list'] = df_messages['Sender_Receiver_Emails'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else [])
df_messages['sender'] = df_messages['sender'].astype('str')
df_messages['replier'] = df_messages['replier'].astype('str')
df_messages['sender_replier_thread'] = df_messages['sender'].str.cat(df_messages['replier'], sep='-')

# De-duplication
df_messages_deduped = df_messages.drop_duplicates(subset='sender_replier_thread', keep='last')

# Setting up chroma_client and other variables
chroma_client = chromadb.PersistentClient(path="vectorstores")
openai_api_key = 'YOUR_OPENAI_API_KEY'  # Please replace 'YOUR_OPENAI_API_KEY' with your actual OpenAI API key
# Out:
# /opt/conda/lib/python3.10/site-packages/sqlalchemy/orm/util.py:148: RuntimeWarning: coroutine 'process_all_threads' was never awaited
#   class _DeStringifyAnnotation(Protocol):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
async def process_all_emails(df):
    responses = []
    for index, row in df.iterrows():
        sender_id = row['sender']
        replier_id = row['replier']
        sender_email = row['message'] 
        response = await get_email_response_personalized(sender_id, replier_id, sender_email, df_messages_deduped, openai_api_key, chroma_client)
        responses.append((sender_id, replier_id, sender_email, response))
    return responses

all_responses = await process_all_emails(df_messages_deduped)

df_responses = pd.DataFrame(all_responses, columns=['sender', 'replier', 'email', 'response'])
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[31], line 11
#       8         responses.append((sender_id, replier_id, sender_email, response))
#       9     return responses
# ---> 11 all_responses = await process_all_emails(df_messages_deduped)
#      13 df_responses = pd.DataFrame(all_responses, columns=['sender', 'replier', 'email', 'response'])
#
# Cell In[31], line 7, in process_all_emails(df)
#       5     replier_id = row['replier']
#       6     sender_email = row['message']
# ----> 7     response = await get_email_response_personalized(sender_id, replier_id, sender_email, df_messages_deduped, openai_api_key, chroma_client)
#       8     responses.append((sender_id, replier_id, sender_email, response))
#       9 return responses
#
# Cell In[28], line 21, in get_email_response_personalized(sender_id, replier_id, sender_email, email_dataset, api_key, vector_db_client, embedding_function)
#      16 user_vector_store = Chroma(
#      17     client=vector_db_client,
#      18     collection_name='user'+str(replier_id),
#      19     embedding_function=OpenAIEmbeddings())
#      20     # Getting ranked responses using MMR
# ---> 21 found_rel_emails = await user_vector_store.amax_marginal_relevance_search(sender_email, k=10, fetch_k=10)
#      22 list_rel_emails=[]
#      23 for i, doc in enumerate(found_docs):
#
# File /opt/conda/lib/python3.10/site-packages/langchain/schema/vectorstore.py:389, in VectorStore.amax_marginal_relevance_search(self, query, k, fetch_k, lambda_mult, **kwargs)
#     378 # This is a temporary workaround to make the similarity search
#     379 # asynchronous. The proper solution is to make the similarity search
#     380 # asynchronous in the vector store implementations.
#     381 func = partial(
#     382     self.max_marginal_relevance_search,
#     383     query,
#    (...)
#     387     **kwargs,
#     388 )
# --> 389 return await asyncio.get_event_loop().run_in_executor(None, func)
#
# File /opt/conda/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /opt/conda/lib/python3.10/site-packages/langchain/vectorstores/chroma.py:466, in Chroma.max_marginal_relevance_search(self, query, k, fetch_k, lambda_mult, filter, where_document, **kwargs)
#     461 if self._embedding_function is None:
#     462     raise ValueError(
#     463         "For MMR search, you must specify an embedding function on" "creation."
#     464     )
# --> 466 embedding = self._embedding_function.embed_query(query)
#     467 docs = self.max_marginal_relevance_search_by_vector(
#     468     embedding,
#     469     k,
#    (...)
#     473     where_document=where_document,
#     474 )
#     475 return docs
#
# File /opt/conda/lib/python3.10/site-packages/langchain/embeddings/openai.py:518, in OpenAIEmbeddings.embed_query(self, text)
#     509 def embed_query(self, text: str) -> List[float]:
#     510     """Call out to OpenAI's embedding endpoint for embedding query text.
#     511
#     512     Args:
#    (...)
#     516         Embedding for the text.
#     517     """
# --> 518     return self.embed_documents([text])[0]
#
# File /opt/conda/lib/python3.10/site-packages/langchain/embeddings/openai.py:490, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     478 """Call out to OpenAI's embedding endpoint for embedding search docs.
#     479
#     480 Args:
#    (...)
#     486     List of embeddings, one for each text.
#     487 """
#     488 # NOTE: to keep things simple, we assume the list may contain texts longer
#     489 #       than the maximum context and use length-safe embedding function.
# --> 490 return self._get_len_safe_embeddings(texts, engine=self.deployment)
#
# File /opt/conda/lib/python3.10/site-packages/langchain/embeddings/openai.py:374, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     371     _iter = range(0, len(tokens), _chunk_size)
#     373 for i in _iter:
# --> 374     response = embed_with_retry(
#     375         self,
#     376         input=tokens[i : i + _chunk_size],
#     377         **self._invocation_params,
#     378     )
#     379     batched_embeddings.extend(r["embedding"] for r in response["data"])
#     381 results: List[List[List[float]]] = [[] for _ in range(len(texts))]
#
# File /opt/conda/lib/python3.10/site-packages/langchain/embeddings/openai.py:107, in embed_with_retry(embeddings, **kwargs)
#     104     response = embeddings.client.create(**kwargs)
#     105     return _check_response(response, skip_empty=embeddings.skip_empty)
# --> 107 return _embed_with_retry(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /opt/conda/lib/python3.10/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /opt/conda/lib/python3.10/site-packages/langchain/embeddings/openai.py:104, in embed_with_retry.<locals>._embed_with_retry(**kwargs)
#     102 @retry_decorator
#     103 def _embed_with_retry(**kwargs: Any) -> Any:
# --> 104     response = embeddings.client.create(**kwargs)
#     105     return _check_response(response, skip_empty=embeddings.skip_empty)
#
# File /opt/conda/lib/python3.10/site-packages/openai/api_resources/embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      31 while True:
#      32     try:
# ---> 33         response = super().create(*args, **kwargs)
#      35         # If a user specifies base64, we'll just return the encoded string.
#      36         # This is only for the default case.
#      37         if not user_provided_encoding_format:
#
# File /opt/conda/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:155, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     129 @classmethod
#     130 def create(
#     131     cls,
#    (...)
#     138     **params,
#     139 ):
#     140     (
#     141         deployment_id,
#     142         engine,
#    (...)
#     152         api_key, api_base, api_type, api_version, organization, **params
#     153     )
# --> 155     response, _, api_key = requestor.request(
#     156         "post",
#     157         url,
#     158         params=params,
#     159         headers=headers,
#     160         stream=stream,
#     161         request_id=request_id,
#     162         request_timeout=request_timeout,
#     163     )
#     165     if stream:
#     166         # must be an iterator
#     167         assert not isinstance(response, OpenAIResponse)
#
# File /opt/conda/lib/python3.10/site-packages/openai/api_requestor.py:299, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     278 def request(
#     279     self,
#     280     method,
#    (...)
#     287     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     288 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     289     result = self.request_raw(
#     290         method.lower(),
#     291         url,
#    (...)
#     297         request_timeout=request_timeout,
#     298     )
# --> 299     resp, got_stream = self._interpret_response(result, stream)
#     300     return resp, got_stream, self.api_key
#
# File /opt/conda/lib/python3.10/site-packages/openai/api_requestor.py:710, in APIRequestor._interpret_response(self, result, stream)
#     702     return (
#     703         self._interpret_response_line(
#     704             line, result.status_code, result.headers, stream=True
#     705         )
#     706         for line in parse_stream(result.iter_lines())
#     707     ), True
#     708 else:
#     709     return (
# --> 710         self._interpret_response_line(
#     711             result.content.decode("utf-8"),
#     712             result.status_code,
#     713             result.headers,
#     714             stream=False,
#     715         ),
#     716         False,
#     717     )
#
# File /opt/conda/lib/python3.10/site-packages/openai/api_requestor.py:775, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     773 stream_error = stream and "error" in resp.data
#     774 if stream_error or not 200 <= rcode < 300:
# --> 775     raise self.handle_error_response(
#     776         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     777     )
#     778 return resp
#
# AuthenticationError: Incorrect API key provided: sk-2dNhL***************************************zPoQ. You can find your API key at https://platform.openai.com/account/api-keys.
